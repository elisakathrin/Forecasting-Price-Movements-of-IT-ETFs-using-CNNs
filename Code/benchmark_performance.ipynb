# %%
from benchmark import sma_evaluation_short, mean_rev_evaluation
import pandas as pd
import numpy as np 
import utils
import labeling
import benchmark
import itertools
import warnings
import financial_eval

warnings.filterwarnings("ignore")

# %%
vgt_full = utils.data_loader(path="../DATA/VGT_historical data_2005.csv")
_, label_vgt, double_label = labeling.get_labels_daily(vgt_full, (1,1))
vgt_full["Y"] = label_vgt
vgt_full = vgt_full["2009-01-01":]
print(double_label)

train_size = int(0.8*len(vgt_full)) # in the preprocessing step we have to delete one row 
vgt_train = vgt_full[10:train_size]
vgt_test = vgt_full[train_size+10:]
vgt_train.head()
# Out:
# 0.0095
#             close   open   high    low    volume  change%    Y
# date
# 2009-01-16  33.47  33.68  33.84  32.64  141880.0     0.97 -1.0
# 2009-01-20  31.73  33.43  33.45  31.71  295440.0    -5.20  1.0
# 2009-01-21  33.31  32.28  33.35  32.00  308710.0     4.98  1.0
# 2009-01-22  32.59  32.53  34.55  32.00  391210.0    -2.16  0.0
# 2009-01-23  33.02  31.99  33.47  31.89  405150.0     1.32  0.0

# %%
xsd_full = utils.data_loader(path="../DATA/XSD Historical Data.csv")
_, label_xsd, double_label = labeling.get_labels_daily(xsd_full, (1,1))
xsd_full["Y"] = label_xsd
print(double_label)
xsd_full = xsd_full["2009-01-01":"2020-01-01"]

train_size = int(0.8*len(xsd_full)) 
xsd_train = xsd_full[10:train_size]
xsd_test = xsd_full[train_size+10:]
xsd_train.head()
# Out:
# 0.0083
#             close   open   high    low   volume  change%    Y
# date
# 2009-01-16  11.99  11.75  12.00  11.70  16250.0     4.35 -1.0
# 2009-01-20  11.18  11.63  11.66  11.18   1080.0    -6.76  0.0
# 2009-01-21  11.51  11.36  11.51  11.06   5800.0     2.95 -1.0
# 2009-01-22  11.26  11.21  11.38  11.00  16200.0    -2.17  1.0
# 2009-01-23  11.66  11.08  11.79  11.08  23650.0     3.55  0.0

# %%
results = pd.DataFrame(columns = ["Buy&Hold", "SMA Strategy", "SMA Parameter", "Mean-Reversion Strategy", "MR Parameter"], index=["VGT train", "VGT test", "XSD train", "XSD test"])

# %% [markdown]
# # Simulation of only Hold & Random Simulation

# %% [markdown]
# ## Random Simulation VGT

# %%
from sklearn.metrics import accuracy_score, f1_score
accuracy_list = []
f1_list_weighted = []
f1_list_macro = []

y_test= vgt_test["Y"]
_, weights = np.unique(vgt_train["Y"], return_counts=True)/np.sum(np.unique(vgt_train["Y"], return_counts=True)[1])

for i in range(10000):
    y_random = np.random.choice([-1,0,1] , size= len(y_test), p= weights)
    accuracy = accuracy_score(y_test, y_random)
    f1_score_weighted = f1_score(y_test, y_random, average='weighted')
    f1_score_macro = f1_score(y_test, y_random, average='macro')
    accuracy_list.append(accuracy)
    f1_list_weighted.append(f1_score_weighted)
    f1_list_macro.append(f1_score_macro)
print(f"Average accuracy: {np.round(np.mean(accuracy_list),4)}")
print(f"Average F1-Score weighted: {np.round(np.mean(f1_list_weighted),4)}")
print(f"Average F1-Score macro: {np.round(np.mean(f1_list_macro),4)}")
# Out:
# Average accuracy: 0.3737
# Average F1-Score weighted: 0.3747
# Average F1-Score macro: 0.3331

# %% [markdown]
# ## Random Simulation XSD

# %%
accuracy_list = []
f1_list_weighted = []
f1_list_macro = []
y_test= xsd_test["Y"]
_, weights = np.unique(xsd_train["Y"], return_counts=True)/np.sum(np.unique(xsd_train["Y"], return_counts=True)[1])

for i in range(10000):
    y_random = np.random.choice([-1,0,1] , size= len(y_test), p= weights)
    accuracy = accuracy_score(y_test, y_random)
    f1_score_weighted = f1_score(y_test, y_random, average='weighted')
    f1_score_macro = f1_score(y_test, y_random, average='macro')
    accuracy_list.append(accuracy)
    f1_list_weighted.append(f1_score_weighted)
    f1_list_macro.append(f1_score_macro)
print(f"Average accuracy: {np.round(np.mean(accuracy_list),4)}")
print(f"Average F1-Score weighted: {np.round(np.mean(f1_list_weighted),4)}")
print(f"Average F1-Score macro: {np.round(np.mean(f1_list_macro),4)}")
# Out:
# Average accuracy: 0.3712
# Average F1-Score weighted: 0.3711
# Average F1-Score macro: 0.3329

# %% [markdown]
# ## Hold only Simulation VGT

# %%
from sklearn.metrics import classification_report
hold_only = np.zeros(len(vgt_test["Y"]))
print(classification_report(vgt_test["Y"], hold_only, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#         -1.0     0.0000    0.0000    0.0000       128
#          0.0     0.5018    1.0000    0.6683       273
#          1.0     0.0000    0.0000    0.0000       143
#
#     accuracy                         0.5018       544
#    macro avg     0.1673    0.3333    0.2228       544
# weighted avg     0.2518    0.5018    0.3354       544

# %% [markdown]
# ## Hold only Simulation XSD

# %%
hold_only = np.zeros(len(xsd_test["Y"]))
print(classification_report(xsd_test["Y"], hold_only, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#         -1.0     0.0000    0.0000    0.0000       133
#          0.0     0.4926    1.0000    0.6601       268
#          1.0     0.0000    0.0000    0.0000       143
#
#     accuracy                         0.4926       544
#    macro avg     0.1642    0.3333    0.2200       544
# weighted avg     0.2427    0.4926    0.3252       544

# %% [markdown]
# # Buy & Hold

# %% [markdown]
# ## VGT

# %%
return_train, capital_train =  financial_eval.buy_hold_evaluation(vgt_train)
# Out:
# End capital: 46868.84 euros
# Total return through Buy & Hold: 369.0%

# %%
return_train, capital_train =  financial_eval.buy_hold_evaluation(vgt_train)
results["Buy&Hold"]["VGT train"] = str(round(return_train*100,4)) + ("%")
# Out:
# End capital: 46868.84 euros
# Total return through Buy & Hold: 369.0%

# %%
return_test, capital_test =  financial_eval.buy_hold_evaluation(vgt_test)
results["Buy&Hold"]["VGT test"] =   str(round(return_test*100,4)) + ("%")
# Out:
# End capital: 15005.82 euros
# Total return through Buy & Hold: 50.0%

# %% [markdown]
# ## XSD

# %%
return_train, capital_train =  financial_eval.buy_hold_evaluation(xsd_train)
results["Buy&Hold"]["XSD train"] = str(round(return_train*100,4)) + ("%")
# Out:
# End capital: 56105.09 euros
# Total return through Buy & Hold: 461.00000000000006%

# %%
return_test, capital_test =  financial_eval.buy_hold_evaluation(xsd_test)
results["Buy&Hold"]["XSD test"] =   str(round(return_test*100,4)) + ("%")
# Out:
# End capital: 15056.16 euros
# Total return through Buy & Hold: 51.0%

# %% [markdown]
# # SMA Strategy Performance evaluation

# %%
grid={"sms_s_list": [10,15,20,25,30,35,40], "sms_l_list": [50,60,70,80,90,100]}

keys, values = zip(*grid.items())
permut_grid = [dict(zip(keys, v)) for v in itertools.product(*values)]

# %% [markdown]
# ## VGT

# %%
best_total_return = 0 
best_total_final_capital = 0

for i in range(len(permut_grid)):
    sms_s, sms_l = permut_grid[i].values()
    total_return, total_final_capital = sma_evaluation_short(vgt_train, sms_s, sms_l)
    
    if total_return > best_total_return: 
        best_total_final_capital = total_final_capital
        best_total_return= total_return 
        best_vals = {"best_sms_s": sms_s, "best_sms_l": sms_l}
# Out:
# Day 49: purchase of 288.62 units for total of 9995 euros
#
# Day 259:
# Total sale:346.34 units for total of 17845.36 euros
# Closed long position: 288.62 units
# New short position: 57.72 units
#
# Day 286:
# Short position closed: repurchase of 57.72 shares.
# Long position built: 267.24 units. Total value: 14671.54 euros
#
# Day 330:
# Total sale:320.69 units for total of 17738.78 euros
# Closed long position: 267.24 units
# New short position: 53.45 units
#
# Day 380:
# Short position closed: repurchase of 53.45 shares.
# Long position built: 278.39 units. Total value: 14877.41 euros
#
# Day 399:
# Total sale:334.07 units for total of 17306.51 euros
# Closed long position: 278.39 units
# New short position: 55.68 units
#
# Day 419:
# Short position closed: repurchase of 55.68 shares.
# Long position built: 265.25 units. Total value: 14299.8 euros
#
# Day 541:
# Total sale:318.3 units for total of 20191.14 euros
# Closed long position: 265.25 units
# New short position: 53.05 units
#
# Day 573:
# Short position closed: repurchase of 53.05 shares.
# Long position built: 253.03 units. Total value: 16687.49 euros
#
# Day 594:
# Total sale:303.64 units for total of 19333.83 euros
# Closed long position: 253.03 units
# New short position: 50.61 units
#
# Day 623:
# Short position closed: repurchase of 50.61 shares.
# Long position built: 245.07 units. Total value: 16020.46 euros
#
# Day 644:
# Total sale:294.08 units for total of 16298.8 euros
# Closed long position: 245.07 units
# New short position: 49.01 units
#
# Day 689:
# Short position closed: repurchase of 49.01 shares.
# Long position built: 217.88 units. Total value: 13301.73 euros
#
# Day 723:
# Total sale:261.46 units for total of 15690.44 euros
# Closed long position: 217.88 units
# New short position: 43.58 units
#
# Day 730:
# Short position closed: repurchase of 43.58 shares.
# Long position built: 207.55 units. Total value: 12963.44 euros
#
# Day 737:
# Total sale:249.06 units for total of 14980.94 euros
# Closed long position: 207.55 units
# New short position: 41.51 units
#
# Day 752:
# Short position closed: repurchase of 41.51 shares.
# Long position built: 195.11 units. Total value: 12348.77 euros
#
# Day 825:
# Total sale:234.13 units for total of 17133.32 euros
# Closed long position: 195.11 units
# New short position: 39.02 units
#
# Day 877:
# Short position closed: repurchase of 39.02 shares.
# Long position built: 217.05 units. Total value: 14518.27 euros
#
# Day 883:
# Total sale:260.46 units for total of 18039.67 euros
# Closed long position: 217.05 units
# New short position: 43.41 units
#
# Day 884:
# Short position closed: repurchase of 43.41 shares.
# Long position built: 220.37 units. Total value: 15066.73 euros
#
# Day 885:
# Total sale:264.44 units for total of 17868.5 euros
# Closed long position: 220.37 units
# New short position: 44.07 units
#
# Day 887:
# Short position closed: repurchase of 44.07 shares.
# Long position built: 223.99 units. Total value: 14926.67 euros
#
# Day 942:
# Total sale:268.79 units for total of 19081.78 euros
# Closed long position: 223.99 units
# New short position: 44.8 units
#
# Day 987:
# Short position closed: repurchase of 44.8 shares.
# Long position built: 224.49 units. Total value: 15903.15 euros
#
# Day 1066:
# Total sale:269.39 units for total of 19113.61 euros
# Closed long position: 224.49 units
# New short position: 44.9 units
#
# Day 1080:
# Short position closed: repurchase of 44.9 shares.
# Long position built: 211.63 units. Total value: 15764.01 euros
#
# Day 1119:
# Total sale:253.96 units for total of 18782.96 euros
# Closed long position: 211.63 units
# New short position: 42.33 units
#
# Day 1128:
# Short position closed: repurchase of 42.33 shares.
# Long position built: 199.34 units. Total value: 15488.92 euros
#
# Day 1270:
# Total sale:239.21 units for total of 20550.32 euros
# Closed long position: 199.34 units
# New short position: 39.87 units
#
# Day 1278:
# Short position closed: repurchase of 39.87 shares.
# Long position built: 186.35 units. Total value: 16924.32 euros
#
# Day 1317:
# Total sale:223.62 units for total of 19622.13 euros
# Closed long position: 186.35 units
# New short position: 37.27 units
#
# Day 1344:
# Short position closed: repurchase of 37.27 shares.
# Long position built: 177.01 units. Total value: 16205.06 euros
#
# Day 1438:
# Total sale:212.41 units for total of 21097.93 euros
# Closed long position: 177.01 units
# New short position: 35.4 units
#
# Day 1460:
# Short position closed: repurchase of 35.4 shares.
# Long position built: 170.44 units. Total value: 17465.5 euros
#
# Day 1505:
# Total sale:204.53 units for total of 21278.39 euros
# Closed long position: 170.44 units
# New short position: 34.09 units
#
# Day 1529:
# Short position closed: repurchase of 34.09 shares.
# Long position built: 162.81 units. Total value: 17590.31 euros
#
# Day 1564:
# Total sale:195.37 units for total of 20807.77 euros
# Closed long position: 162.81 units
# New short position: 32.56 units
#
# Day 1575:
# Short position closed: repurchase of 32.56 shares.
# Long position built: 158.4 units. Total value: 17255.68 euros
#
# Day 1622:
# Total sale:190.08 units for total of 20147.28 euros
# Closed long position: 158.4 units
# New short position: 31.68 units
#
# Day 1640:
# Short position closed: repurchase of 31.68 shares.
# Long position built: 154.29 units. Total value: 16711.02 euros
#
# Day 1646:
# Total sale:185.15 units for total of 19989.35 euros
# Closed long position: 154.29 units
# New short position: 30.86 units
#
# Day 1696:
# Short position closed: repurchase of 30.86 shares.
# Long position built: 159.38 units. Total value: 16742.51 euros
#
# Day 1744:
# Total sale:191.26 units for total of 20670.21 euros
# Closed long position: 159.38 units
# New short position: 31.88 units
#
# Day 1793:
# Short position closed: repurchase of 31.88 shares.
# Long position built: 166.23 units. Total value: 17339.8 euros
#
# Day 1836:
# Total sale:199.48 units for total of 20663.12 euros
# Closed long position: 166.23 units
# New short position: 33.25 units
#
# Day 1855:
# Short position closed: repurchase of 33.25 shares.
# Long position built: 154.67 units. Total value: 17002.95 euros
#
# Day 1873:
# Total sale:185.6 units for total of 18915.06 euros
# Closed long position: 154.67 units
# New short position: 30.93 units
#
# Day 1883:
# Short position closed: repurchase of 30.93 shares.
# Long position built: 139.57 units. Total value: 15479.62 euros
#
# Day 1966:
# Total sale:167.48 units for total of 19972.01 euros
# Closed long position: 139.57 units
# New short position: 27.91 units
#
# Day 1976:
# Short position closed: repurchase of 27.91 shares.
# Long position built: 136.33 units. Total value: 16574.0 euros
#
# Day 2130:
# Total sale:163.6 units for total of 23085.5 euros
# Closed long position: 136.33 units
# New short position: 27.27 units
#
# Day 2139:
# Short position closed: repurchase of 27.27 shares.
# Long position built: 129.13 units. Total value: 19056.27 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 20257.21 euros
# Total return: 102.57%
# Shares held at end of period: 129.13
# Total fee spending: 265
# Day 59: purchase of 265.68 units for total of 9995 euros
#
# Day 260:
# Total sale:318.82 units for total of 16057.15 euros
# Closed long position: 265.68 units
# New short position: 53.14 units
#
# Day 286:
# Short position closed: repurchase of 53.14 shares.
# Long position built: 239.25 units. Total value: 13134.77 euros
#
# Day 332:
# Total sale:287.1 units for total of 16058.25 euros
# Closed long position: 239.25 units
# New short position: 47.85 units
#
# Day 382:
# Short position closed: repurchase of 47.85 shares.
# Long position built: 247.57 units. Total value: 13453.08 euros
#
# Day 399:
# Total sale:297.08 units for total of 15389.69 euros
# Closed long position: 247.57 units
# New short position: 49.51 units
#
# Day 418:
# Short position closed: repurchase of 49.51 shares.
# Long position built: 237.73 units. Total value: 12732.93 euros
#
# Day 543:
# Total sale:285.28 units for total of 17753.68 euros
# Closed long position: 237.73 units
# New short position: 47.55 units
#
# Day 575:
# Short position closed: repurchase of 47.55 shares.
# Long position built: 220.6 units. Total value: 14601.35 euros
#
# Day 594:
# Total sale:264.72 units for total of 16855.02 euros
# Closed long position: 220.6 units
# New short position: 44.12 units
#
# Day 624:
# Short position closed: repurchase of 44.12 shares.
# Long position built: 218.67 units. Total value: 14021.04 euros
#
# Day 643:
# Total sale:262.4 units for total of 15484.47 euros
# Closed long position: 218.67 units
# New short position: 43.73 units
#
# Day 692:
# Short position closed: repurchase of 43.73 shares.
# Long position built: 200.23 units. Total value: 12704.8 euros
#
# Day 724:
# Total sale:240.28 units for total of 15002.89 euros
# Closed long position: 200.23 units
# New short position: 40.05 units
#
# Day 728:
# Short position closed: repurchase of 40.05 shares.
# Long position built: 195.8 units. Total value: 12451.11 euros
#
# Day 739:
# Total sale:234.96 units for total of 14170.14 euros
# Closed long position: 195.8 units
# New short position: 39.16 units
#
# Day 752:
# Short position closed: repurchase of 39.16 shares.
# Long position built: 184.65 units. Total value: 11686.7 euros
#
# Day 833:
# Total sale:221.58 units for total of 15503.38 euros
# Closed long position: 184.65 units
# New short position: 36.93 units
#
# Day 890:
# Short position closed: repurchase of 36.93 shares.
# Long position built: 187.65 units. Total value: 12949.84 euros
#
# Day 945:
# Total sale:225.18 units for total of 16372.34 euros
# Closed long position: 187.65 units
# New short position: 37.53 units
#
# Day 996:
# Short position closed: repurchase of 37.53 shares.
# Long position built: 192.22 units. Total value: 13693.7 euros
#
# Day 1068:
# Total sale:230.66 units for total of 16233.46 euros
# Closed long position: 192.22 units
# New short position: 38.44 units
#
# Day 1080:
# Short position closed: repurchase of 38.44 shares.
# Long position built: 179.42 units. Total value: 13365.07 euros
#
# Day 1121:
# Total sale:215.3 units for total of 16049.92 euros
# Closed long position: 179.42 units
# New short position: 35.88 units
#
# Day 1125:
# Short position closed: repurchase of 35.88 shares.
# Long position built: 175.46 units. Total value: 13320.91 euros
#
# Day 1271:
# Total sale:210.55 units for total of 18091.77 euros
# Closed long position: 175.46 units
# New short position: 35.09 units
#
# Day 1277:
# Short position closed: repurchase of 35.09 shares.
# Long position built: 164.59 units. Total value: 14908.32 euros
#
# Day 1319:
# Total sale:197.51 units for total of 17583.27 euros
# Closed long position: 164.59 units
# New short position: 32.92 units
#
# Day 1345:
# Short position closed: repurchase of 32.92 shares.
# Long position built: 158.54 units. Total value: 14555.88 euros
#
# Day 1439:
# Total sale:190.25 units for total of 18869.7 euros
# Closed long position: 158.54 units
# New short position: 31.71 units
#
# Day 1460:
# Short position closed: repurchase of 31.71 shares.
# Long position built: 152.39 units. Total value: 15615.38 euros
#
# Day 1508:
# Total sale:182.87 units for total of 18666.03 euros
# Closed long position: 152.39 units
# New short position: 30.48 units
#
# Day 1529:
# Short position closed: repurchase of 30.48 shares.
# Long position built: 142.24 units. Total value: 15367.97 euros
#
# Day 1623:
# Total sale:170.69 units for total of 18127.4 euros
# Closed long position: 142.24 units
# New short position: 28.45 units
#
# Day 1640:
# Short position closed: repurchase of 28.45 shares.
# Long position built: 138.87 units. Total value: 15040.98 euros
#
# Day 1646:
# Total sale:166.64 units for total of 17990.45 euros
# Closed long position: 138.87 units
# New short position: 27.77 units
#
# Day 1698:
# Short position closed: repurchase of 27.77 shares.
# Long position built: 141.55 units. Total value: 15035.72 euros
#
# Day 1747:
# Total sale:169.86 units for total of 18562.4 euros
# Closed long position: 141.55 units
# New short position: 28.31 units
#
# Day 1796:
# Short position closed: repurchase of 28.31 shares.
# Long position built: 151.82 units. Total value: 15640.9 euros
#
# Day 1838:
# Total sale:182.18 units for total of 18992.73 euros
# Closed long position: 151.82 units
# New short position: 30.36 units
#
# Day 1854:
# Short position closed: repurchase of 30.36 shares.
# Long position built: 142.27 units. Total value: 15648.43 euros
#
# Day 1873:
# Total sale:170.72 units for total of 17398.2 euros
# Closed long position: 142.27 units
# New short position: 28.45 units
#
# Day 1883:
# Short position closed: repurchase of 28.45 shares.
# Long position built: 128.37 units. Total value: 14237.81 euros
#
# Day 1967:
# Total sale:154.04 units for total of 18459.77 euros
# Closed long position: 128.37 units
# New short position: 25.67 units
#
# Day 1975:
# Short position closed: repurchase of 25.67 shares.
# Long position built: 127.62 units. Total value: 15364.36 euros
#
# Day 2133:
# Total sale:153.14 units for total of 21852.67 euros
# Closed long position: 127.62 units
# New short position: 25.52 units
#
# Day 2137:
# Short position closed: repurchase of 25.52 shares.
# Long position built: 123.33 units. Total value: 18101.85 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 19346.21 euros
# Total return: 93.46%
# Shares held at end of period: 123.33
# Total fee spending: 235
# Day 69: purchase of 258.07 units for total of 9995 euros
#
# Day 261:
# Total sale:309.68 units for total of 15847.52 euros
# Closed long position: 258.07 units
# New short position: 51.61 units
#
# Day 285:
# Short position closed: repurchase of 51.61 shares.
# Long position built: 238.07 units. Total value: 13019.97 euros
#
# Day 334:
# Total sale:285.68 units for total of 15661.69 euros
# Closed long position: 238.07 units
# New short position: 47.61 units
#
# Day 387:
# Short position closed: repurchase of 47.61 shares.
# Long position built: 242.06 units. Total value: 13083.37 euros
#
# Day 397:
# Total sale:290.47 units for total of 14791.54 euros
# Closed long position: 242.06 units
# New short position: 48.41 units
#
# Day 419:
# Short position closed: repurchase of 48.41 shares.
# Long position built: 225.87 units. Total value: 12176.76 euros
#
# Day 544:
# Total sale:271.04 units for total of 16441.71 euros
# Closed long position: 225.87 units
# New short position: 45.17 units
#
# Day 575:
# Short position closed: repurchase of 45.17 shares.
# Long position built: 203.16 units. Total value: 13446.9 euros
#
# Day 593:
# Total sale:243.79 units for total of 15414.72 euros
# Closed long position: 203.16 units
# New short position: 40.63 units
#
# Day 624:
# Short position closed: repurchase of 40.63 shares.
# Long position built: 199.7 units. Total value: 12804.52 euros
#
# Day 643:
# Total sale:239.64 units for total of 14140.95 euros
# Closed long position: 199.7 units
# New short position: 39.94 units
#
# Day 693:
# Short position closed: repurchase of 39.94 shares.
# Long position built: 187.25 units. Total value: 11650.88 euros
#
# Day 741:
# Total sale:224.7 units for total of 13850.0 euros
# Closed long position: 187.25 units
# New short position: 37.45 units
#
# Day 749:
# Short position closed: repurchase of 37.45 shares.
# Long position built: 183.05 units. Total value: 11493.52 euros
#
# Day 835:
# Total sale:219.66 units for total of 15241.6 euros
# Closed long position: 183.05 units
# New short position: 36.61 units
#
# Day 894:
# Short position closed: repurchase of 36.61 shares.
# Long position built: 181.52 units. Total value: 12679.39 euros
#
# Day 948:
# Total sale:217.82 units for total of 15144.38 euros
# Closed long position: 181.52 units
# New short position: 36.3 units
#
# Day 1002:
# Short position closed: repurchase of 36.3 shares.
# Long position built: 177.59 units. Total value: 12570.07 euros
#
# Day 1069:
# Total sale:213.11 units for total of 14778.44 euros
# Closed long position: 177.59 units
# New short position: 35.52 units
#
# Day 1080:
# Short position closed: repurchase of 35.52 shares.
# Long position built: 162.81 units. Total value: 12127.56 euros
#
# Day 1272:
# Total sale:195.37 units for total of 16998.05 euros
# Closed long position: 162.81 units
# New short position: 32.56 units
#
# Day 1275:
# Short position closed: repurchase of 32.56 shares.
# Long position built: 157.41 units. Total value: 14080.56 euros
#
# Day 1319:
# Total sale:188.89 units for total of 16815.65 euros
# Closed long position: 157.41 units
# New short position: 31.48 units
#
# Day 1331:
# Short position closed: repurchase of 31.48 shares.
# Long position built: 154.19 units. Total value: 13960.46 euros
#
# Day 1333:
# Total sale:185.03 units for total of 16605.14 euros
# Closed long position: 154.19 units
# New short position: 30.84 units
#
# Day 1345:
# Short position closed: repurchase of 30.84 shares.
# Long position built: 149.97 units. Total value: 13768.72 euros
#
# Day 1441:
# Total sale:179.96 units for total of 17877.63 euros
# Closed long position: 149.97 units
# New short position: 29.99 units
#
# Day 1459:
# Short position closed: repurchase of 29.99 shares.
# Long position built: 144.55 units. Total value: 14801.65 euros
#
# Day 1510:
# Total sale:173.46 units for total of 17606.39 euros
# Closed long position: 144.55 units
# New short position: 28.91 units
#
# Day 1513:
# Short position closed: repurchase of 28.91 shares.
# Long position built: 139.65 units. Total value: 14582.61 euros
#
# Day 1514:
# Total sale:167.58 units for total of 17542.3 euros
# Closed long position: 139.65 units
# New short position: 27.93 units
#
# Day 1529:
# Short position closed: repurchase of 27.93 shares.
# Long position built: 134.39 units. Total value: 14519.74 euros
#
# Day 1625:
# Total sale:161.27 units for total of 17233.15 euros
# Closed long position: 134.39 units
# New short position: 26.88 units
#
# Day 1639:
# Short position closed: repurchase of 26.88 shares.
# Long position built: 131.09 units. Total value: 14296.62 euros
#
# Day 1646:
# Total sale:157.31 units for total of 16982.91 euros
# Closed long position: 131.09 units
# New short position: 26.22 units
#
# Day 1699:
# Short position closed: repurchase of 26.22 shares.
# Long position built: 133.18 units. Total value: 14185.21 euros
#
# Day 1754:
# Total sale:159.82 units for total of 16721.76 euros
# Closed long position: 133.18 units
# New short position: 26.64 units
#
# Day 1799:
# Short position closed: repurchase of 26.64 shares.
# Long position built: 131.71 units. Total value: 13904.38 euros
#
# Day 1841:
# Total sale:158.05 units for total of 16601.31 euros
# Closed long position: 131.71 units
# New short position: 26.34 units
#
# Day 1852:
# Short position closed: repurchase of 26.34 shares.
# Long position built: 125.68 units. Total value: 13720.78 euros
#
# Day 1873:
# Total sale:150.82 units for total of 15369.59 euros
# Closed long position: 125.68 units
# New short position: 25.14 units
#
# Day 1884:
# Short position closed: repurchase of 25.14 shares.
# Long position built: 113.49 units. Total value: 12578.32 euros
#
# Day 1969:
# Total sale:136.19 units for total of 16072.23 euros
# Closed long position: 113.49 units
# New short position: 22.7 units
#
# Day 1975:
# Short position closed: repurchase of 22.7 shares.
# Long position built: 110.76 units. Total value: 13334.38 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 17374.9 euros
# Total return: 73.75%
# Shares held at end of period: 110.76
# Total fee spending: 225
# Day 79: purchase of 254.91 units for total of 9995 euros
#
# Day 262:
# Total sale:305.89 units for total of 15788.1 euros
# Closed long position: 254.91 units
# New short position: 50.98 units
#
# Day 284:
# Short position closed: repurchase of 50.98 shares.
# Long position built: 238.94 units. Total value: 13007.75 euros
#
# Day 335:
# Total sale:286.73 units for total of 15475.55 euros
# Closed long position: 238.94 units
# New short position: 47.79 units
#
# Day 392:
# Short position closed: repurchase of 47.79 shares.
# Long position built: 238.01 units. Total value: 12883.68 euros
#
# Day 393:
# Total sale:285.61 units for total of 15240.86 euros
# Closed long position: 238.01 units
# New short position: 47.6 units
#
# Day 419:
# Short position closed: repurchase of 47.6 shares.
# Long position built: 235.02 units. Total value: 12669.75 euros
#
# Day 545:
# Total sale:282.02 units for total of 17251.8 euros
# Closed long position: 235.02 units
# New short position: 47.0 units
#
# Day 558:
# Short position closed: repurchase of 47.0 shares.
# Long position built: 223.33 units. Total value: 14248.2 euros
#
# Day 563:
# Total sale:268.0 units for total of 16887.04 euros
# Closed long position: 223.33 units
# New short position: 44.67 units
#
# Day 574:
# Short position closed: repurchase of 44.67 shares.
# Long position built: 211.27 units. Total value: 13935.61 euros
#
# Day 592:
# Total sale:253.52 units for total of 15938.87 euros
# Closed long position: 211.27 units
# New short position: 42.25 units
#
# Day 624:
# Short position closed: repurchase of 42.25 shares.
# Long position built: 206.25 units. Total value: 13224.8 euros
#
# Day 642:
# Total sale:247.5 units for total of 14738.58 euros
# Closed long position: 206.25 units
# New short position: 41.25 units
#
# Day 693:
# Short position closed: repurchase of 41.25 shares.
# Long position built: 195.55 units. Total value: 12167.0 euros
#
# Day 743:
# Total sale:234.66 units for total of 14313.95 euros
# Closed long position: 195.55 units
# New short position: 39.11 units
#
# Day 745:
# Short position closed: repurchase of 39.11 shares.
# Long position built: 194.05 units. Total value: 11908.77 euros
#
# Day 837:
# Total sale:232.86 units for total of 15990.15 euros
# Closed long position: 194.05 units
# New short position: 38.81 units
#
# Day 896:
# Short position closed: repurchase of 38.81 shares.
# Long position built: 185.95 units. Total value: 13224.99 euros
#
# Day 949:
# Total sale:223.14 units for total of 15637.11 euros
# Closed long position: 185.95 units
# New short position: 37.19 units
#
# Day 1004:
# Short position closed: repurchase of 37.19 shares.
# Long position built: 184.13 units. Total value: 13005.38 euros
#
# Day 1071:
# Total sale:220.96 units for total of 15433.48 euros
# Closed long position: 184.13 units
# New short position: 36.83 units
#
# Day 1079:
# Short position closed: repurchase of 36.83 shares.
# Long position built: 172.51 units. Total value: 12714.1 euros
#
# Day 1320:
# Total sale:207.01 units for total of 18617.62 euros
# Closed long position: 172.51 units
# New short position: 34.5 units
#
# Day 1329:
# Short position closed: repurchase of 34.5 shares.
# Long position built: 170.64 units. Total value: 15482.43 euros
#
# Day 1335:
# Total sale:204.77 units for total of 18326.01 euros
# Closed long position: 170.64 units
# New short position: 34.13 units
#
# Day 1337:
# Short position closed: repurchase of 34.13 shares.
# Long position built: 166.69 units. Total value: 15207.33 euros
#
# Day 1443:
# Total sale:200.03 units for total of 18939.84 euros
# Closed long position: 166.69 units
# New short position: 33.34 units
#
# Day 1459:
# Short position closed: repurchase of 33.34 shares.
# Long position built: 151.57 units. Total value: 15520.83 euros
#
# Day 1524:
# Total sale:181.88 units for total of 18863.23 euros
# Closed long position: 151.57 units
# New short position: 30.31 units
#
# Day 1527:
# Short position closed: repurchase of 30.31 shares.
# Long position built: 148.44 units. Total value: 15660.53 euros
#
# Day 1625:
# Total sale:178.13 units for total of 19035.32 euros
# Closed long position: 148.44 units
# New short position: 29.69 units
#
# Day 1639:
# Short position closed: repurchase of 29.69 shares.
# Long position built: 144.8 units. Total value: 15792.32 euros
#
# Day 1646:
# Total sale:173.76 units for total of 18759.34 euros
# Closed long position: 144.8 units
# New short position: 28.96 units
#
# Day 1699:
# Short position closed: repurchase of 28.96 shares.
# Long position built: 147.12 units. Total value: 15669.81 euros
#
# Day 1755:
# Total sale:176.54 units for total of 17876.74 euros
# Closed long position: 147.12 units
# New short position: 29.42 units
#
# Day 1801:
# Short position closed: repurchase of 29.42 shares.
# Long position built: 139.44 units. Total value: 14757.92 euros
#
# Day 1873:
# Total sale:167.33 units for total of 17052.62 euros
# Closed long position: 139.44 units
# New short position: 27.89 units
#
# Day 1884:
# Short position closed: repurchase of 27.89 shares.
# Long position built: 125.93 units. Total value: 13956.57 euros
#
# Day 1971:
# Total sale:151.12 units for total of 17694.17 euros
# Closed long position: 125.93 units
# New short position: 25.19 units
#
# Day 1973:
# Short position closed: repurchase of 25.19 shares.
# Long position built: 122.56 units. Total value: 14673.43 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 19226.7 euros
# Total return: 92.27%
# Shares held at end of period: 122.56
# Total fee spending: 205
# Day 89: purchase of 250.0 units for total of 9995 euros
#
# Day 263:
# Total sale:300.0 units for total of 15529.0 euros
# Closed long position: 250.0 units
# New short position: 50.0 units
#
# Day 280:
# Short position closed: repurchase of 50.0 shares.
# Long position built: 240.17 units. Total value: 12849.0 euros
#
# Day 335:
# Total sale:288.2 units for total of 15554.92 euros
# Closed long position: 240.17 units
# New short position: 48.03 units
#
# Day 419:
# Short position closed: repurchase of 48.03 shares.
# Long position built: 240.41 units. Total value: 12960.62 euros
#
# Day 546:
# Total sale:288.49 units for total of 17688.09 euros
# Closed long position: 240.41 units
# New short position: 48.08 units
#
# Day 556:
# Short position closed: repurchase of 48.08 shares.
# Long position built: 228.05 units. Total value: 14604.05 euros
#
# Day 566:
# Total sale:273.66 units for total of 17287.58 euros
# Closed long position: 228.05 units
# New short position: 45.61 units
#
# Day 573:
# Short position closed: repurchase of 45.61 shares.
# Long position built: 216.45 units. Total value: 14274.6 euros
#
# Day 592:
# Total sale:259.74 units for total of 16330.05 euros
# Closed long position: 216.45 units
# New short position: 43.29 units
#
# Day 624:
# Short position closed: repurchase of 43.29 shares.
# Long position built: 211.31 units. Total value: 13549.29 euros
#
# Day 642:
# Total sale:253.57 units for total of 15100.16 euros
# Closed long position: 211.31 units
# New short position: 42.26 units
#
# Day 693:
# Short position closed: repurchase of 42.26 shares.
# Long position built: 200.35 units. Total value: 12465.75 euros
#
# Day 838:
# Total sale:240.42 units for total of 16458.96 euros
# Closed long position: 200.35 units
# New short position: 40.07 units
#
# Day 897:
# Short position closed: repurchase of 40.07 shares.
# Long position built: 191.06 units. Total value: 13601.38 euros
#
# Day 950:
# Total sale:229.27 units for total of 15908.63 euros
# Closed long position: 191.06 units
# New short position: 38.21 units
#
# Day 1007:
# Short position closed: repurchase of 38.21 shares.
# Long position built: 185.75 units. Total value: 13190.34 euros
#
# Day 1072:
# Total sale:222.9 units for total of 15785.24 euros
# Closed long position: 185.75 units
# New short position: 37.15 units
#
# Day 1079:
# Short position closed: repurchase of 37.15 shares.
# Long position built: 176.96 units. Total value: 13042.28 euros
#
# Day 1321:
# Total sale:212.35 units for total of 19076.77 euros
# Closed long position: 176.96 units
# New short position: 35.39 units
#
# Day 1328:
# Short position closed: repurchase of 35.39 shares.
# Long position built: 175.56 units. Total value: 15872.16 euros
#
# Day 1443:
# Total sale:210.67 units for total of 19947.56 euros
# Closed long position: 175.56 units
# New short position: 35.11 units
#
# Day 1459:
# Short position closed: repurchase of 35.11 shares.
# Long position built: 159.64 units. Total value: 16347.29 euros
#
# Day 1625:
# Total sale:191.57 units for total of 20471.92 euros
# Closed long position: 159.64 units
# New short position: 31.93 units
#
# Day 1638:
# Short position closed: repurchase of 31.93 shares.
# Long position built: 155.41 units. Total value: 16978.56 euros
#
# Day 1647:
# Total sale:186.49 units for total of 20009.11 euros
# Closed long position: 155.41 units
# New short position: 31.08 units
#
# Day 1701:
# Short position closed: repurchase of 31.08 shares.
# Long position built: 156.79 units. Total value: 16694.71 euros
#
# Day 1756:
# Total sale:188.15 units for total of 18889.02 euros
# Closed long position: 156.79 units
# New short position: 31.36 units
#
# Day 1803:
# Short position closed: repurchase of 31.36 shares.
# Long position built: 144.13 units. Total value: 15509.37 euros
#
# Day 1875:
# Total sale:172.96 units for total of 18287.25 euros
# Closed long position: 144.13 units
# New short position: 28.83 units
#
# Day 1883:
# Short position closed: repurchase of 28.83 shares.
# Long position built: 136.01 units. Total value: 15084.71 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 21335.67 euros
# Total return: 113.36%
# Shares held at end of period: 136.01
# Total fee spending: 155
# Day 99: purchase of 232.71 units for total of 9995 euros
#
# Day 264:
# Total sale:279.25 units for total of 14030.1 euros
# Closed long position: 232.71 units
# New short position: 46.54 units
#
# Day 278:
# Short position closed: repurchase of 46.54 shares.
# Long position built: 220.15 units. Total value: 11577.57 euros
#
# Day 335:
# Total sale:264.18 units for total of 14258.08 euros
# Closed long position: 220.15 units
# New short position: 44.03 units
#
# Day 421:
# Short position closed: repurchase of 44.03 shares.
# Long position built: 215.16 units. Total value: 11831.87 euros
#
# Day 548:
# Total sale:258.19 units for total of 16100.89 euros
# Closed long position: 215.16 units
# New short position: 43.03 units
#
# Day 554:
# Short position closed: repurchase of 43.03 shares.
# Long position built: 207.41 units. Total value: 13330.35 euros
#
# Day 569:
# Total sale:248.89 units for total of 16026.0 euros
# Closed long position: 207.41 units
# New short position: 41.48 units
#
# Day 571:
# Short position closed: repurchase of 41.48 shares.
# Long position built: 204.43 units. Total value: 13318.58 euros
#
# Day 593:
# Total sale:245.32 units for total of 15511.49 euros
# Closed long position: 204.43 units
# New short position: 40.89 units
#
# Day 624:
# Short position closed: repurchase of 40.89 shares.
# Long position built: 200.95 units. Total value: 12884.62 euros
#
# Day 643:
# Total sale:241.14 units for total of 14229.49 euros
# Closed long position: 200.95 units
# New short position: 40.19 units
#
# Day 694:
# Short position closed: repurchase of 40.19 shares.
# Long position built: 185.81 units. Total value: 11694.94 euros
#
# Day 840:
# Total sale:222.97 units for total of 14858.18 euros
# Closed long position: 185.81 units
# New short position: 37.16 units
#
# Day 898:
# Short position closed: repurchase of 37.16 shares.
# Long position built: 170.69 units. Total value: 12197.73 euros
#
# Day 952:
# Total sale:204.83 units for total of 14107.79 euros
# Closed long position: 170.69 units
# New short position: 34.14 units
#
# Day 1010:
# Short position closed: repurchase of 34.14 shares.
# Long position built: 162.55 units. Total value: 11654.95 euros
#
# Day 1073:
# Total sale:195.06 units for total of 13883.27 euros
# Closed long position: 162.55 units
# New short position: 32.51 units
#
# Day 1078:
# Short position closed: repurchase of 32.51 shares.
# Long position built: 158.57 units. Total value: 11517.07 euros
#
# Day 1444:
# Total sale:190.28 units for total of 17793.79 euros
# Closed long position: 158.57 units
# New short position: 31.71 units
#
# Day 1459:
# Short position closed: repurchase of 31.71 shares.
# Long position built: 142.01 units. Total value: 14541.69 euros
#
# Day 1625:
# Total sale:170.41 units for total of 18210.12 euros
# Closed long position: 142.01 units
# New short position: 28.4 units
#
# Day 1638:
# Short position closed: repurchase of 28.4 shares.
# Long position built: 138.24 units. Total value: 15102.42 euros
#
# Day 1647:
# Total sale:165.89 units for total of 17798.31 euros
# Closed long position: 138.24 units
# New short position: 27.65 units
#
# Day 1703:
# Short position closed: repurchase of 27.65 shares.
# Long position built: 137.29 units. Total value: 14810.43 euros
#
# Day 1757:
# Total sale:164.75 units for total of 16619.92 euros
# Closed long position: 137.29 units
# New short position: 27.46 units
#
# Day 1805:
# Short position closed: repurchase of 27.46 shares.
# Long position built: 126.58 units. Total value: 13653.09 euros
#
# Day 1879:
# Total sale:151.9 units for total of 16228.55 euros
# Closed long position: 126.58 units
# New short position: 25.32 units
#
# Day 1883:
# Short position closed: repurchase of 25.32 shares.
# Long position built: 120.96 units. Total value: 13415.31 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 18974.48 euros
# Total return: 89.74%
# Shares held at end of period: 120.96
# Total fee spending: 145
# Day 49: purchase of 288.62 units for total of 9995 euros
#
# Day 261:
# Total sale:346.34 units for total of 17724.14 euros
# Closed long position: 288.62 units
# New short position: 57.72 units
#
# Day 287:
# Short position closed: repurchase of 57.72 shares.
# Long position built: 262.41 units. Total value: 14524.34 euros
#
# Day 333:
# Total sale:314.89 units for total of 17225.78 euros
# Closed long position: 262.41 units
# New short position: 52.48 units
#
# Day 383:
# Short position closed: repurchase of 52.48 shares.
# Long position built: 264.19 units. Total value: 14366.92 euros
#
# Day 401:
# Total sale:317.03 units for total of 16204.74 euros
# Closed long position: 264.19 units
# New short position: 52.84 units
#
# Day 422:
# Short position closed: repurchase of 52.84 shares.
# Long position built: 242.4 units. Total value: 13300.41 euros
#
# Day 542:
# Total sale:290.88 units for total of 18358.25 euros
# Closed long position: 242.4 units
# New short position: 48.48 units
#
# Day 574:
# Short position closed: repurchase of 48.48 shares.
# Long position built: 229.77 units. Total value: 15155.51 euros
#
# Day 597:
# Total sale:275.72 units for total of 17517.01 euros
# Closed long position: 229.77 units
# New short position: 45.95 units
#
# Day 627:
# Short position closed: repurchase of 45.95 shares.
# Long position built: 232.24 units. Total value: 14619.45 euros
#
# Day 645:
# Total sale:278.69 units for total of 16147.87 euros
# Closed long position: 232.24 units
# New short position: 46.45 units
#
# Day 685:
# Short position closed: repurchase of 46.45 shares.
# Long position built: 231.59 units. Total value: 13445.99 euros
#
# Day 729:
# Total sale:277.91 units for total of 17675.63 euros
# Closed long position: 231.59 units
# New short position: 46.32 units
#
# Day 754:
# Short position closed: repurchase of 46.32 shares.
# Long position built: 233.63 units. Total value: 14746.92 euros
#
# Day 828:
# Total sale:280.36 units for total of 20430.44 euros
# Closed long position: 233.63 units
# New short position: 46.73 units
#
# Day 881:
# Short position closed: repurchase of 46.73 shares.
# Long position built: 257.85 units. Total value: 17291.73 euros
#
# Day 943:
# Total sale:309.42 units for total of 21994.76 euros
# Closed long position: 257.85 units
# New short position: 51.57 units
#
# Day 987:
# Short position closed: repurchase of 51.57 shares.
# Long position built: 258.84 units. Total value: 18336.54 euros
#
# Day 1068:
# Total sale:310.61 units for total of 21861.94 euros
# Closed long position: 258.84 units
# New short position: 51.77 units
#
# Day 1083:
# Short position closed: repurchase of 51.77 shares.
# Long position built: 238.19 units. Total value: 17954.52 euros
#
# Day 1120:
# Total sale:285.83 units for total of 21303.63 euros
# Closed long position: 238.19 units
# New short position: 47.64 units
#
# Day 1131:
# Short position closed: repurchase of 47.64 shares.
# Long position built: 224.93 units. Total value: 17576.04 euros
#
# Day 1273:
# Total sale:269.92 units for total of 23810.04 euros
# Closed long position: 224.93 units
# New short position: 44.99 units
#
# Day 1281:
# Short position closed: repurchase of 44.99 shares.
# Long position built: 216.35 units. Total value: 19706.9 euros
#
# Day 1318:
# Total sale:259.62 units for total of 22992.14 euros
# Closed long position: 216.35 units
# New short position: 43.27 units
#
# Day 1346:
# Short position closed: repurchase of 43.27 shares.
# Long position built: 204.81 units. Total value: 18977.74 euros
#
# Day 1442:
# Total sale:245.77 units for total of 23991.98 euros
# Closed long position: 204.81 units
# New short position: 40.96 units
#
# Day 1463:
# Short position closed: repurchase of 40.96 shares.
# Long position built: 192.44 units. Total value: 19777.52 euros
#
# Day 1508:
# Total sale:230.93 units for total of 23572.95 euros
# Closed long position: 192.44 units
# New short position: 38.49 units
#
# Day 1531:
# Short position closed: repurchase of 38.49 shares.
# Long position built: 179.15 units. Total value: 19399.87 euros
#
# Day 1568:
# Total sale:214.98 units for total of 23077.4 euros
# Closed long position: 179.15 units
# New short position: 35.83 units
#
# Day 1578:
# Short position closed: repurchase of 35.83 shares.
# Long position built: 173.79 units. Total value: 19128.59 euros
#
# Day 1621:
# Total sale:208.55 units for total of 22620.59 euros
# Closed long position: 173.79 units
# New short position: 34.76 units
#
# Day 1645:
# Short position closed: repurchase of 34.76 shares.
# Long position built: 173.41 units. Total value: 18839.26 euros
#
# Day 1650:
# Total sale:208.09 units for total of 22329.3 euros
# Closed long position: 173.41 units
# New short position: 34.68 units
#
# Day 1700:
# Short position closed: repurchase of 34.68 shares.
# Long position built: 174.23 units. Total value: 18618.39 euros
#
# Day 1746:
# Total sale:209.08 units for total of 22859.99 euros
# Closed long position: 174.23 units
# New short position: 34.85 units
#
# Day 1795:
# Short position closed: repurchase of 34.85 shares.
# Long position built: 184.78 units. Total value: 19228.5 euros
#
# Day 1838:
# Total sale:221.74 units for total of 23118.05 euros
# Closed long position: 184.78 units
# New short position: 36.96 units
#
# Day 1858:
# Short position closed: repurchase of 36.96 shares.
# Long position built: 173.24 units. Total value: 19048.93 euros
#
# Day 1878:
# Total sale:207.89 units for total of 22091.63 euros
# Closed long position: 173.24 units
# New short position: 34.65 units
#
# Day 1884:
# Short position closed: repurchase of 34.65 shares.
# Long position built: 164.63 units. Total value: 18246.37 euros
#
# Day 1970:
# Total sale:197.56 units for total of 23459.2 euros
# Closed long position: 164.63 units
# New short position: 32.93 units
#
# Day 1979:
# Short position closed: repurchase of 32.93 shares.
# Long position built: 159.92 units. Total value: 19449.25 euros
#
# Day 2131:
# Total sale:191.9 units for total of 26836.05 euros
# Closed long position: 159.92 units
# New short position: 31.98 units
#
# Day 2141:
# Short position closed: repurchase of 31.98 shares.
# Long position built: 148.58 units. Total value: 22078.82 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 23307.57 euros
# Total return: 133.08%
# Shares held at end of period: 148.58
# Total fee spending: 235
# Day 59: purchase of 265.68 units for total of 9995 euros
#
# Day 262:
# Total sale:318.82 units for total of 16455.68 euros
# Closed long position: 265.68 units
# New short position: 53.14 units
#
# Day 287:
# Short position closed: repurchase of 53.14 shares.
# Long position built: 244.07 units. Total value: 13509.38 euros
#
# Day 335:
# Total sale:292.88 units for total of 15807.59 euros
# Closed long position: 244.07 units
# New short position: 48.81 units
#
# Day 384:
# Short position closed: repurchase of 48.81 shares.
# Long position built: 245.14 units. Total value: 13178.57 euros
#
# Day 402:
# Total sale:294.17 units for total of 14888.83 euros
# Closed long position: 245.14 units
# New short position: 49.03 units
#
# Day 421:
# Short position closed: repurchase of 49.03 shares.
# Long position built: 221.63 units. Total value: 12187.67 euros
#
# Day 544:
# Total sale:265.96 units for total of 16133.45 euros
# Closed long position: 221.63 units
# New short position: 44.33 units
#
# Day 577:
# Short position closed: repurchase of 44.33 shares.
# Long position built: 202.17 units. Total value: 13227.94 euros
#
# Day 599:
# Total sale:242.6 units for total of 15196.32 euros
# Closed long position: 202.17 units
# New short position: 40.43 units
#
# Day 629:
# Short position closed: repurchase of 40.43 shares.
# Long position built: 199.33 units. Total value: 12629.67 euros
#
# Day 645:
# Total sale:239.2 units for total of 13859.03 euros
# Closed long position: 199.33 units
# New short position: 39.87 units
#
# Day 692:
# Short position closed: repurchase of 39.87 shares.
# Long position built: 178.48 units. Total value: 11324.28 euros
#
# Day 742:
# Total sale:214.18 units for total of 13231.32 euros
# Closed long position: 178.48 units
# New short position: 35.7 units
#
# Day 755:
# Short position closed: repurchase of 35.7 shares.
# Long position built: 172.82 units. Total value: 10961.87 euros
#
# Day 833:
# Total sale:207.38 units for total of 14509.53 euros
# Closed long position: 172.82 units
# New short position: 34.56 units
#
# Day 892:
# Short position closed: repurchase of 34.56 shares.
# Long position built: 176.48 units. Total value: 12129.22 euros
#
# Day 947:
# Total sale:211.78 units for total of 15063.15 euros
# Closed long position: 176.48 units
# New short position: 35.3 units
#
# Day 996:
# Short position closed: repurchase of 35.3 shares.
# Long position built: 176.07 units. Total value: 12543.37 euros
#
# Day 1069:
# Total sale:211.28 units for total of 14651.49 euros
# Closed long position: 176.07 units
# New short position: 35.21 units
#
# Day 1082:
# Short position closed: repurchase of 35.21 shares.
# Long position built: 160.57 units. Total value: 12012.43 euros
#
# Day 1277:
# Total sale:192.68 units for total of 17447.95 euros
# Closed long position: 160.57 units
# New short position: 32.11 units
#
# Day 1278:
# Short position closed: repurchase of 32.11 shares.
# Long position built: 159.95 units. Total value: 14526.72 euros
#
# Day 1323:
# Total sale:191.94 units for total of 17426.99 euros
# Closed long position: 159.95 units
# New short position: 31.99 units
#
# Day 1347:
# Short position closed: repurchase of 31.99 shares.
# Long position built: 153.96 units. Total value: 14424.85 euros
#
# Day 1442:
# Total sale:184.75 units for total of 18033.99 euros
# Closed long position: 153.96 units
# New short position: 30.79 units
#
# Day 1463:
# Short position closed: repurchase of 30.79 shares.
# Long position built: 144.64 units. Total value: 14864.7 euros
#
# Day 1510:
# Total sale:173.57 units for total of 17617.56 euros
# Closed long position: 144.64 units
# New short position: 28.93 units
#
# Day 1532:
# Short position closed: repurchase of 28.93 shares.
# Long position built: 133.07 units. Total value: 14467.29 euros
#
# Day 1624:
# Total sale:159.68 units for total of 17048.82 euros
# Closed long position: 133.07 units
# New short position: 26.61 units
#
# Day 1701:
# Short position closed: repurchase of 26.61 shares.
# Long position built: 133.46 units. Total value: 14210.39 euros
#
# Day 1750:
# Total sale:160.15 units for total of 17579.47 euros
# Closed long position: 133.46 units
# New short position: 26.69 units
#
# Day 1798:
# Short position closed: repurchase of 26.69 shares.
# Long position built: 142.69 units. Total value: 14805.12 euros
#
# Day 1841:
# Total sale:171.23 units for total of 17986.14 euros
# Closed long position: 142.69 units
# New short position: 28.54 units
#
# Day 1857:
# Short position closed: repurchase of 28.54 shares.
# Long position built: 135.6 units. Total value: 14854.58 euros
#
# Day 1875:
# Total sale:162.72 units for total of 17204.27 euros
# Closed long position: 135.6 units
# New short position: 27.12 units
#
# Day 1884:
# Short position closed: repurchase of 27.12 shares.
# Long position built: 128.07 units. Total value: 14193.56 euros
#
# Day 1971:
# Total sale:153.68 units for total of 17994.0 euros
# Closed long position: 128.07 units
# New short position: 25.61 units
#
# Day 1978:
# Short position closed: repurchase of 25.61 shares.
# Long position built: 122.69 units. Total value: 14882.51 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 19246.65 euros
# Total return: 92.47%
# Shares held at end of period: 122.69
# Total fee spending: 195
# Day 69: purchase of 258.07 units for total of 9995 euros
#
# Day 264:
# Total sale:309.68 units for total of 15559.52 euros
# Closed long position: 258.07 units
# New short position: 51.61 units
#
# Day 286:
# Short position closed: repurchase of 51.61 shares.
# Long position built: 231.71 units. Total value: 12721.13 euros
#
# Day 337:
# Total sale:278.05 units for total of 14367.4 euros
# Closed long position: 231.71 units
# New short position: 46.34 units
#
# Day 389:
# Short position closed: repurchase of 46.34 shares.
# Long position built: 218.45 units. Total value: 11848.92 euros
#
# Day 400:
# Total sale:262.14 units for total of 13408.7 euros
# Closed long position: 218.45 units
# New short position: 43.69 units
#
# Day 422:
# Short position closed: repurchase of 43.69 shares.
# Long position built: 200.59 units. Total value: 11006.43 euros
#
# Day 546:
# Total sale:240.71 units for total of 14757.74 euros
# Closed long position: 200.59 units
# New short position: 40.12 units
#
# Day 577:
# Short position closed: repurchase of 40.12 shares.
# Long position built: 185.35 units. Total value: 12127.69 euros
#
# Day 598:
# Total sale:222.42 units for total of 14140.91 euros
# Closed long position: 185.35 units
# New short position: 37.07 units
#
# Day 629:
# Short position closed: repurchase of 37.07 shares.
# Long position built: 186.03 units. Total value: 11787.16 euros
#
# Day 644:
# Total sale:223.24 units for total of 12371.43 euros
# Closed long position: 186.03 units
# New short position: 37.21 units
#
# Day 695:
# Short position closed: repurchase of 37.21 shares.
# Long position built: 164.0 units. Total value: 10079.5 euros
#
# Day 745:
# Total sale:196.8 units for total of 12072.62 euros
# Closed long position: 164.0 units
# New short position: 32.8 units
#
# Day 752:
# Short position closed: repurchase of 32.8 shares.
# Long position built: 157.87 units. Total value: 9991.7 euros
#
# Day 835:
# Total sale:189.44 units for total of 13144.03 euros
# Closed long position: 157.87 units
# New short position: 31.57 units
#
# Day 895:
# Short position closed: repurchase of 31.57 shares.
# Long position built: 155.04 units. Total value: 10916.19 euros
#
# Day 950:
# Total sale:186.05 units for total of 12908.73 euros
# Closed long position: 155.04 units
# New short position: 31.01 units
#
# Day 1001:
# Short position closed: repurchase of 31.01 shares.
# Long position built: 152.13 units. Total value: 10718.77 euros
#
# Day 1070:
# Total sale:182.56 units for total of 12642.76 euros
# Closed long position: 152.13 units
# New short position: 30.43 units
#
# Day 1081:
# Short position closed: repurchase of 30.43 shares.
# Long position built: 138.3 units. Total value: 10358.55 euros
#
# Day 1324:
# Total sale:165.96 units for total of 14931.4 euros
# Closed long position: 138.3 units
# New short position: 27.66 units
#
# Day 1348:
# Short position closed: repurchase of 27.66 shares.
# Long position built: 132.13 units. Total value: 12342.68 euros
#
# Day 1443:
# Total sale:158.56 units for total of 15012.22 euros
# Closed long position: 132.13 units
# New short position: 26.43 units
#
# Day 1462:
# Short position closed: repurchase of 26.43 shares.
# Long position built: 119.58 units. Total value: 12290.74 euros
#
# Day 1514:
# Total sale:143.5 units for total of 15020.88 euros
# Closed long position: 119.58 units
# New short position: 23.92 units
#
# Day 1531:
# Short position closed: repurchase of 23.92 shares.
# Long position built: 114.74 units. Total value: 12425.59 euros
#
# Day 1626:
# Total sale:137.69 units for total of 14652.1 euros
# Closed long position: 114.74 units
# New short position: 22.95 units
#
# Day 1703:
# Short position closed: repurchase of 22.95 shares.
# Long position built: 112.82 units. Total value: 12171.25 euros
#
# Day 1754:
# Total sale:135.38 units for total of 14163.87 euros
# Closed long position: 112.82 units
# New short position: 22.56 units
#
# Day 1801:
# Short position closed: repurchase of 22.56 shares.
# Long position built: 111.22 units. Total value: 11771.12 euros
#
# Day 1845:
# Total sale:133.46 units for total of 13946.91 euros
# Closed long position: 111.22 units
# New short position: 22.24 units
#
# Day 1854:
# Short position closed: repurchase of 22.24 shares.
# Long position built: 104.52 units. Total value: 11495.73 euros
#
# Day 1875:
# Total sale:125.42 units for total of 13259.42 euros
# Closed long position: 104.52 units
# New short position: 20.9 units
#
# Day 1886:
# Short position closed: repurchase of 20.9 shares.
# Long position built: 98.04 units. Total value: 10925.32 euros
#
# Day 1972:
# Total sale:117.65 units for total of 13958.88 euros
# Closed long position: 98.04 units
# New short position: 19.61 units
#
# Day 1977:
# Short position closed: repurchase of 19.61 shares.
# Long position built: 95.02 units. Total value: 11566.75 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 14905.75 euros
# Total return: 49.06%
# Shares held at end of period: 95.02
# Total fee spending: 185
# Day 79: purchase of 254.91 units for total of 9995 euros
#
# Day 265:
# ...
# Long position built: 235.33 units. Total value: 14061.07 euros
#
# Day 658:
# Total sale:282.4 units for total of 16156.75 euros
# Closed long position: 235.33 units
# New short position: 47.07 units
#
# Day 696:
# Short position closed: repurchase of 47.07 shares.
# Long position built: 216.76 units. Total value: 13270.13 euros
#
# Day 745:
# Total sale:260.11 units for total of 15957.95 euros
# Closed long position: 216.76 units
# New short position: 43.35 units
#
# Day 762:
# Short position closed: repurchase of 43.35 shares.
# Long position built: 198.76 units. Total value: 13096.62 euros
#
# Day 842:
# Total sale:238.51 units for total of 16127.82 euros
# Closed long position: 198.76 units
# New short position: 39.75 units
#
# Day 892:
# Short position closed: repurchase of 39.75 shares.
# Long position built: 194.83 units. Total value: 13390.8 euros
#
# Day 957:
# Total sale:233.8 units for total of 16232.41 euros
# Closed long position: 194.83 units
# New short position: 38.97 units
#
# Day 1004:
# Short position closed: repurchase of 38.97 shares.
# Long position built: 190.78 units. Total value: 13474.96 euros
#
# Day 1141:
# Total sale:228.94 units for total of 17854.61 euros
# Closed long position: 190.78 units
# New short position: 38.16 units
#
# Day 1142:
# Short position closed: repurchase of 38.16 shares.
# Long position built: 187.98 units. Total value: 14837.64 euros
#
# Day 1332:
# Total sale:225.58 units for total of 20488.94 euros
# Closed long position: 187.98 units
# New short position: 37.6 units
#
# Day 1356:
# Short position closed: repurchase of 37.6 shares.
# Long position built: 176.91 units. Total value: 16893.52 euros
#
# Day 1454:
# Total sale:212.29 units for total of 20890.7 euros
# Closed long position: 176.91 units
# New short position: 35.38 units
#
# Day 1478:
# Short position closed: repurchase of 35.38 shares.
# Long position built: 162.08 units. Total value: 17143.56 euros
#
# Day 1518:
# Total sale:194.5 units for total of 19878.74 euros
# Closed long position: 162.08 units
# New short position: 32.42 units
#
# Day 1541:
# Short position closed: repurchase of 32.42 shares.
# Long position built: 149.87 units. Total value: 16339.31 euros
#
# Day 1581:
# Total sale:179.84 units for total of 19397.94 euros
# Closed long position: 149.87 units
# New short position: 29.97 units
#
# Day 1595:
# Short position closed: repurchase of 29.97 shares.
# Long position built: 145.28 units. Total value: 16076.46 euros
#
# Day 1633:
# Total sale:174.34 units for total of 18841.15 euros
# Closed long position: 145.28 units
# New short position: 29.06 units
#
# Day 1709:
# Short position closed: repurchase of 29.06 shares.
# Long position built: 141.46 units. Total value: 15626.19 euros
#
# Day 1756:
# Total sale:169.75 units for total of 17041.3 euros
# Closed long position: 141.46 units
# New short position: 28.29 units
#
# Day 1809:
# Short position closed: repurchase of 28.29 shares.
# Long position built: 130.85 units. Total value: 14007.85 euros
#
# Day 1855:
# Total sale:157.02 units for total of 17256.21 euros
# Closed long position: 130.85 units
# New short position: 26.17 units
#
# Day 1879:
# Short position closed: repurchase of 26.17 shares.
# Long position built: 135.25 units. Total value: 14454.42 euros
#
# Day 1987:
# Total sale:162.3 units for total of 19743.66 euros
# Closed long position: 135.25 units
# New short position: 27.05 units
#
# Day 1989:
# Short position closed: repurchase of 27.05 shares.
# Long position built: 133.4 units. Total value: 16410.97 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 20926.59 euros
# Total return: 109.27%
# Shares held at end of period: 133.4
# Total fee spending: 195
# Day 69: purchase of 258.07 units for total of 9995 euros
#
# Day 279:
# Total sale:309.68 units for total of 16299.65 euros
# Closed long position: 258.07 units
# New short position: 51.61 units
#
# Day 304:
# Short position closed: repurchase of 51.61 shares.
# Long position built: 234.56 units. Total value: 13355.98 euros
#
# Day 348:
# Total sale:281.47 units for total of 14358.41 euros
# Closed long position: 234.56 units
# New short position: 46.91 units
#
# Day 408:
# Short position closed: repurchase of 46.91 shares.
# Long position built: 243.94 units. Total value: 12038.41 euros
#
# Day 414:
# Total sale:292.73 units for total of 15196.47 euros
# Closed long position: 243.94 units
# New short position: 48.79 units
#
# Day 416:
# Short position closed: repurchase of 48.79 shares.
# Long position built: 237.63 units. Total value: 12603.65 euros
#
# Day 420:
# Total sale:285.16 units for total of 15430.71 euros
# Closed long position: 237.63 units
# New short position: 47.53 units
#
# Day 426:
# Short position closed: repurchase of 47.53 shares.
# Long position built: 229.36 units. Total value: 12777.81 euros
#
# Day 562:
# Total sale:275.23 units for total of 17513.39 euros
# Closed long position: 229.36 units
# New short position: 45.87 units
#
# Day 589:
# Short position closed: repurchase of 45.87 shares.
# Long position built: 224.86 units. Total value: 14541.98 euros
#
# Day 613:
# Total sale:269.83 units for total of 16565.26 euros
# Closed long position: 224.86 units
# New short position: 44.97 units
#
# Day 701:
# Short position closed: repurchase of 44.97 shares.
# Long position built: 210.87 units. Total value: 13649.35 euros
#
# Day 752:
# Total sale:253.04 units for total of 16009.9 euros
# Closed long position: 210.87 units
# New short position: 42.17 units
#
# Day 762:
# Short position closed: repurchase of 42.17 shares.
# Long position built: 200.73 units. Total value: 13226.32 euros
#
# Day 844:
# Total sale:240.88 units for total of 16283.31 euros
# Closed long position: 200.73 units
# New short position: 40.15 units
#
# Day 897:
# Short position closed: repurchase of 40.15 shares.
# Long position built: 188.51 units. Total value: 13420.03 euros
#
# Day 960:
# Total sale:226.21 units for total of 15171.43 euros
# Closed long position: 188.51 units
# New short position: 37.7 units
#
# Day 1007:
# Short position closed: repurchase of 37.7 shares.
# Long position built: 175.88 units. Total value: 12489.35 euros
#
# Day 1339:
# Total sale:211.06 units for total of 19114.93 euros
# Closed long position: 175.88 units
# New short position: 35.18 units
#
# Day 1357:
# Short position closed: repurchase of 35.18 shares.
# Long position built: 164.57 units. Total value: 15744.25 euros
#
# Day 1454:
# Total sale:197.48 units for total of 19432.96 euros
# Closed long position: 164.57 units
# New short position: 32.91 units
#
# Day 1479:
# Short position closed: repurchase of 32.91 shares.
# Long position built: 150.15 units. Total value: 15935.22 euros
#
# Day 1522:
# Total sale:180.18 units for total of 18573.36 euros
# Closed long position: 150.15 units
# New short position: 30.03 units
#
# Day 1542:
# Short position closed: repurchase of 30.03 shares.
# Long position built: 140.35 units. Total value: 15295.69 euros
#
# Day 1637:
# Total sale:168.42 units for total of 18657.62 euros
# Closed long position: 140.35 units
# New short position: 28.07 units
#
# Day 1711:
# Short position closed: repurchase of 28.07 shares.
# Long position built: 138.1 units. Total value: 15501.76 euros
#
# Day 1761:
# Total sale:165.72 units for total of 16252.13 euros
# Closed long position: 138.1 units
# New short position: 27.62 units
#
# Day 1813:
# Short position closed: repurchase of 27.62 shares.
# Long position built: 119.6 units. Total value: 13198.99 euros
#
# Day 1862:
# Total sale:143.52 units for total of 15655.9 euros
# Closed long position: 119.6 units
# New short position: 23.92 units
#
# Day 1882:
# Short position closed: repurchase of 23.92 shares.
# Long position built: 118.59 units. Total value: 13024.01 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 18603.86 euros
# Total return: 86.04%
# Shares held at end of period: 118.59
# Total fee spending: 155
# Day 79: purchase of 254.91 units for total of 9995 euros
#
# Day 282:
# Total sale:305.89 units for total of 16363.17 euros
# Closed long position: 254.91 units
# New short position: 50.98 units
#
# Day 303:
# Short position closed: repurchase of 50.98 shares.
# Long position built: 240.25 units. Total value: 13494.63 euros
#
# Day 351:
# Total sale:288.3 units for total of 14992.37 euros
# Closed long position: 240.25 units
# New short position: 48.05 units
#
# Day 419:
# Short position closed: repurchase of 48.05 shares.
# Long position built: 229.96 units. Total value: 12396.99 euros
#
# Day 420:
# Total sale:275.95 units for total of 14932.17 euros
# Closed long position: 229.96 units
# New short position: 45.99 units
#
# Day 426:
# Short position closed: repurchase of 45.99 shares.
# Long position built: 221.95 units. Total value: 12365.07 euros
#
# Day 429:
# Total sale:266.34 units for total of 14803.5 euros
# Closed long position: 221.95 units
# New short position: 44.39 units
#
# Day 434:
# Short position closed: repurchase of 44.39 shares.
# Long position built: 220.63 units. Total value: 12319.77 euros
#
# Day 565:
# Total sale:264.76 units for total of 16767.55 euros
# Closed long position: 220.63 units
# New short position: 44.13 units
#
# Day 598:
# Short position closed: repurchase of 44.13 shares.
# Long position built: 219.43 units. Total value: 13955.88 euros
#
# Day 610:
# Total sale:263.32 units for total of 15783.67 euros
# Closed long position: 219.43 units
# New short position: 43.89 units
#
# Day 705:
# Short position closed: repurchase of 43.89 shares.
# Long position built: 208.21 units. Total value: 13031.59 euros
#
# Day 846:
# Total sale:249.85 units for total of 16707.47 euros
# Closed long position: 208.21 units
# New short position: 41.64 units
#
# Day 902:
# Short position closed: repurchase of 41.64 shares.
# Long position built: 191.11 units. Total value: 13714.38 euros
#
# Day 963:
# Total sale:229.33 units for total of 15311.95 euros
# Closed long position: 191.11 units
# New short position: 38.22 units
#
# Day 1012:
# Short position closed: repurchase of 38.22 shares.
# Long position built: 178.13 units. Total value: 12602.89 euros
#
# Day 1345:
# Total sale:213.76 units for total of 19620.31 euros
# Closed long position: 178.13 units
# New short position: 35.63 units
#
# Day 1357:
# Short position closed: repurchase of 35.63 shares.
# Long position built: 169.4 units. Total value: 16206.58 euros
#
# Day 1456:
# Total sale:203.28 units for total of 20278.28 euros
# Closed long position: 169.4 units
# New short position: 33.88 units
#
# Day 1476:
# Short position closed: repurchase of 33.88 shares.
# Long position built: 155.96 units. Total value: 16655.23 euros
#
# Day 1536:
# Total sale:187.15 units for total of 20416.81 euros
# Closed long position: 155.96 units
# New short position: 31.19 units
#
# Day 1541:
# Short position closed: repurchase of 31.19 shares.
# Long position built: 156.04 units. Total value: 17011.47 euros
#
# Day 1641:
# Total sale:187.25 units for total of 20068.2 euros
# Closed long position: 156.04 units
# New short position: 31.21 units
#
# Day 1714:
# Short position closed: repurchase of 31.21 shares.
# Long position built: 146.69 units. Total value: 16543.34 euros
#
# Day 1764:
# Total sale:176.03 units for total of 17170.25 euros
# Closed long position: 146.69 units
# New short position: 29.34 units
#
# Day 1816:
# Short position closed: repurchase of 29.34 shares.
# Long position built: 126.95 units. Total value: 13942.83 euros
#
# Day 1868:
# Total sale:152.34 units for total of 16455.34 euros
# Closed long position: 126.95 units
# New short position: 25.39 units
#
# Day 1882:
# Short position closed: repurchase of 25.39 shares.
# Long position built: 124.4 units. Total value: 13662.01 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 19515.2 euros
# Total return: 95.15%
# Shares held at end of period: 124.4
# Total fee spending: 145
# Day 89: purchase of 250.0 units for total of 9995 euros
#
# Day 287:
# Total sale:300.0 units for total of 16600.0 euros
# Closed long position: 250.0 units
# New short position: 50.0 units
#
# Day 301:
# Short position closed: repurchase of 50.0 shares.
# Long position built: 243.61 units. Total value: 13769.0 euros
#
# Day 354:
# Total sale:292.33 units for total of 15810.05 euros
# Closed long position: 243.61 units
# New short position: 48.72 units
#
# Day 426:
# Short position closed: repurchase of 48.72 shares.
# Long position built: 234.98 units. Total value: 13090.86 euros
#
# Day 567:
# Total sale:281.98 units for total of 17649.77 euros
# Closed long position: 234.98 units
# New short position: 47.0 units
#
# Day 708:
# Short position closed: repurchase of 47.0 shares.
# Long position built: 227.67 units. Total value: 14625.49 euros
#
# Day 849:
# Total sale:273.2 units for total of 18231.1 euros
# Closed long position: 227.67 units
# New short position: 45.53 units
#
# Day 906:
# Short position closed: repurchase of 45.53 shares.
# Long position built: 203.9 units. Total value: 14899.22 euros
#
# Day 965:
# Total sale:244.68 units for total of 16072.92 euros
# Closed long position: 203.9 units
# New short position: 40.78 units
#
# Day 1018:
# Short position closed: repurchase of 40.78 shares.
# Long position built: 187.65 units. Total value: 13199.46 euros
#
# Day 1460:
# Total sale:225.18 units for total of 23069.19 euros
# Closed long position: 187.65 units
# New short position: 37.53 units
#
# Day 1474:
# Short position closed: repurchase of 37.53 shares.
# Long position built: 180.47 units. Total value: 19093.52 euros
#
# Day 1644:
# Total sale:216.56 units for total of 23626.03 euros
# Closed long position: 180.47 units
# New short position: 36.09 units
#
# Day 1715:
# Short position closed: repurchase of 36.09 shares.
# Long position built: 175.36 units. Total value: 19589.41 euros
#
# Day 1766:
# Total sale:210.43 units for total of 20789.69 euros
# Closed long position: 175.36 units
# New short position: 35.07 units
#
# Day 1818:
# Short position closed: repurchase of 35.07 shares.
# Long position built: 156.88 units. Total value: 16987.31 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 24610.27 euros
# Total return: 146.1%
# Shares held at end of period: 156.88
# Total fee spending: 85
# Day 99: purchase of 232.71 units for total of 9995 euros
#
# Day 292:
# Total sale:279.25 units for total of 15649.76 euros
# Closed long position: 232.71 units
# New short position: 46.54 units
#
# Day 296:
# Short position closed: repurchase of 46.54 shares.
# Long position built: 229.63 units. Total value: 13008.26 euros
#
# Day 356:
# Total sale:275.56 units for total of 14977.2 euros
# Closed long position: 229.63 units
# New short position: 45.93 units
#
# Day 433:
# Short position closed: repurchase of 45.93 shares.
# Long position built: 222.87 units. Total value: 12413.9 euros
#
# Day 573:
# Total sale:267.44 units for total of 17632.67 euros
# Closed long position: 222.87 units
# New short position: 44.57 units
#
# Day 584:
# Short position closed: repurchase of 44.57 shares.
# Long position built: 222.68 units. Total value: 14687.83 euros
#
# Day 599:
# Total sale:267.22 units for total of 16739.01 euros
# Closed long position: 222.68 units
# New short position: 44.54 units
#
# Day 708:
# Short position closed: repurchase of 44.54 shares.
# Long position built: 215.95 units. Total value: 13872.76 euros
#
# Day 852:
# Total sale:259.14 units for total of 17023.09 euros
# Closed long position: 215.95 units
# New short position: 43.19 units
#
# Day 909:
# Short position closed: repurchase of 43.19 shares.
# Long position built: 190.57 units. Total value: 13873.86 euros
#
# Day 966:
# Total sale:228.68 units for total of 15083.31 euros
# Closed long position: 190.57 units
# New short position: 38.11 units
#
# Day 1024:
# Short position closed: repurchase of 38.11 shares.
# Long position built: 171.92 units. Total value: 12342.39 euros
#
# Day 1646:
# Total sale:206.3 units for total of 22273.34 euros
# Closed long position: 171.92 units
# New short position: 34.38 units
#
# Day 1716:
# Short position closed: repurchase of 34.38 shares.
# Long position built: 166.43 units. Total value: 18455.94 euros
#
# Day 1768:
# Total sale:199.72 units for total of 19455.72 euros
# Closed long position: 166.43 units
# New short position: 33.29 units
#
# Day 1820:
# Short position closed: repurchase of 33.29 shares.
# Long position built: 145.88 units. Total value: 15836.75 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 22884.23 euros
# Total return: 128.84%
# Shares held at end of period: 145.88
# Total fee spending: 85

# %%
best_vals
# Out:
# {'best_sms_s': 40, 'best_sms_l': 90}

# %%
best_total_final_capital
# Out:
# 24610.267734669374

# %%
best_total_return
# Out:
# 1.4610267734669375

# %%
results["SMA Strategy"]["VGT train"] = str(round(best_total_return*100, 2))+"%"
results["SMA Parameter"]["VGT train"] = str("SMA short: " + str(best_vals["best_sms_s"]) +", SMA long: " +str(best_vals["best_sms_l"]))
results["SMA Parameter"]["VGT test"] = str("SMA short: " + str(best_vals["best_sms_s"]) +", SMA long: " +str(best_vals["best_sms_l"]))

# %%
return_test, _=sma_evaluation_short(vgt_test, best_vals["best_sms_s"], best_vals["best_sms_l"])
# Out:
# Day 89: purchase of 54.7 units for total of 9995 euros
#
# Day 128:
# Total sale:65.64 units for total of 11750.47 euros
# Closed long position: 54.7 units
# New short position: 10.94 units
#
# Day 140:
# Short position closed: repurchase of 10.94 shares.
# Long position built: 53.3 units. Total value: 9745.09 euros
#
# Day 256:
# Total sale:63.96 units for total of 12179.38 euros
# Closed long position: 53.3 units
# New short position: 10.66 units
#
# Day 330:
# Short position closed: repurchase of 10.66 shares.
# Long position built: 52.1 units. Total value: 10106.55 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 544: 12756.93 euros
# Total return: 27.57%
# Shares held at end of period: 52.1
# Total fee spending: 25

# %%
results["SMA Strategy"]["VGT test"] = str(round(return_test*100, 2))+"%"

# %% [markdown]
# ## XSD

# %%
best_total_return = -10000
best_total_final_capital = 0

for i in range(len(permut_grid)):
    sms_s, sms_l = permut_grid[i].values()
    total_return, total_final_capital = sma_evaluation_short(xsd_train, sms_s, sms_l)
    
    if total_return > best_total_return: 
        best_total_final_capital = total_final_capital
        best_total_return= total_return 
        best_vals = {"best_sms_s": sms_s, "best_sms_l": sms_l}
# Out:
# Day 49: purchase of 731.7 units for total of 9995 euros
#
# Day 197:
# Total sale:878.04 units for total of 16493.37 euros
# Closed long position: 731.7 units
# New short position: 146.34 units
#
# Day 212:
# Short position closed: repurchase of 146.34 shares.
# Long position built: 636.96 units. Total value: 13407.91 euros
#
# Day 260:
# Total sale:764.35 units for total of 16076.92 euros
# Closed long position: 636.96 units
# New short position: 127.39 units
#
# Day 278:
# Short position closed: repurchase of 127.39 shares.
# Long position built: 573.52 units. Total value: 13150.87 euros
#
# Day 329:
# Total sale:688.22 units for total of 16415.93 euros
# Closed long position: 573.52 units
# New short position: 114.7 units
#
# Day 380:
# Short position closed: repurchase of 114.7 shares.
# Long position built: 604.45 units. Total value: 13793.48 euros
#
# Day 393:
# Total sale:725.34 units for total of 15894.45 euros
# Closed long position: 604.45 units
# New short position: 120.89 units
#
# Day 425:
# Short position closed: repurchase of 120.89 shares.
# Long position built: 584.05 units. Total value: 13164.59 euros
#
# Day 540:
# Total sale:700.86 units for total of 19605.06 euros
# Closed long position: 584.05 units
# New short position: 116.81 units
#
# Day 574:
# Short position closed: repurchase of 116.81 shares.
# Long position built: 529.63 units. Total value: 16058.38 euros
#
# Day 595:
# Total sale:635.56 units for total of 18731.31 euros
# Closed long position: 529.63 units
# New short position: 105.93 units
#
# Day 693:
# Short position closed: repurchase of 105.93 shares.
# Long position built: 693.31 units. Total value: 16244.37 euros
#
# Day 719:
# Total sale:831.97 units for total of 18240.1 euros
# Closed long position: 693.31 units
# New short position: 138.66 units
#
# Day 753:
# Short position closed: repurchase of 138.66 shares.
# Long position built: 629.78 units. Total value: 14944.7 euros
#
# Day 812:
# Total sale:755.74 units for total of 18525.74 euros
# Closed long position: 629.78 units
# New short position: 125.96 units
#
# Day 896:
# Short position closed: repurchase of 125.96 shares.
# Long position built: 679.64 units. Total value: 15624.92 euros
#
# Day 934:
# Total sale:815.57 units for total of 17578.69 euros
# Closed long position: 679.64 units
# New short position: 135.93 units
#
# Day 977:
# Short position closed: repurchase of 135.93 shares.
# Long position built: 670.57 units. Total value: 14611.77 euros
#
# Day 1060:
# Total sale:804.68 units for total of 19033.73 euros
# Closed long position: 670.57 units
# New short position: 134.11 units
#
# Day 1080:
# Short position closed: repurchase of 134.11 shares.
# Long position built: 617.12 units. Total value: 15631.72 euros
#
# Day 1159:
# Total sale:740.54 units for total of 20463.53 euros
# Closed long position: 617.12 units
# New short position: 123.42 units
#
# Day 1170:
# Short position closed: repurchase of 123.42 shares.
# Long position built: 588.18 units. Total value: 16910.2 euros
#
# Day 1209:
# Total sale:705.82 units for total of 20386.14 euros
# Closed long position: 588.18 units
# New short position: 117.64 units
#
# Day 1215:
# Short position closed: repurchase of 117.64 shares.
# Long position built: 581.06 units. Total value: 16949.58 euros
#
# Day 1216:
# Total sale:697.27 units for total of 20111.24 euros
# Closed long position: 581.06 units
# New short position: 116.21 units
#
# Day 1229:
# Short position closed: repurchase of 116.21 shares.
# Long position built: 574.96 units. Total value: 16725.69 euros
#
# Day 1333:
# Total sale:689.95 units for total of 22915.14 euros
# Closed long position: 574.96 units
# New short position: 114.99 units
#
# Day 1350:
# Short position closed: repurchase of 114.99 shares.
# Long position built: 540.52 units. Total value: 18891.24 euros
#
# Day 1392:
# Total sale:648.62 units for total of 23325.86 euros
# Closed long position: 540.52 units
# New short position: 108.1 units
#
# Day 1411:
# Short position closed: repurchase of 108.1 shares.
# Long position built: 509.18 units. Total value: 19236.84 euros
#
# Day 1438:
# Total sale:611.02 units for total of 21961.17 euros
# Closed long position: 509.18 units
# New short position: 101.84 units
#
# Day 1465:
# Short position closed: repurchase of 101.84 shares.
# Long position built: 504.52 units. Total value: 18268.54 euros
#
# Day 1579:
# Total sale:605.42 units for total of 25931.19 euros
# Closed long position: 504.52 units
# New short position: 100.9 units
#
# Day 1595:
# Short position closed: repurchase of 100.9 shares.
# Long position built: 480.54 units. Total value: 21427.06 euros
#
# Day 1626:
# Total sale:576.65 units for total of 24295.03 euros
# Closed long position: 480.54 units
# New short position: 96.11 units
#
# Day 1694:
# Short position closed: repurchase of 96.11 shares.
# Long position built: 505.87 units. Total value: 20411.99 euros
#
# Day 1755:
# Total sale:607.04 units for total of 24410.15 euros
# Closed long position: 505.87 units
# New short position: 101.17 units
#
# Day 1791:
# Short position closed: repurchase of 101.17 shares.
# Long position built: 473.88 units. Total value: 20111.49 euros
#
# Day 1836:
# Total sale:568.66 units for total of 23645.57 euros
# Closed long position: 473.88 units
# New short position: 94.78 units
#
# Day 1854:
# Short position closed: repurchase of 94.78 shares.
# Long position built: 425.59 units. Total value: 19334.71 euros
#
# Day 1879:
# Total sale:510.71 units for total of 22021.92 euros
# Closed long position: 425.59 units
# New short position: 85.12 units
#
# Day 1883:
# Short position closed: repurchase of 85.12 shares.
# Long position built: 393.72 units. Total value: 18103.1 euros
#
# Day 1956:
# Total sale:472.46 units for total of 24671.59 euros
# Closed long position: 393.72 units
# New short position: 78.74 units
#
# Day 1973:
# Short position closed: repurchase of 78.74 shares.
# Long position built: 379.75 units. Total value: 20430.37 euros
#
# Day 2068:
# Total sale:455.7 units for total of 26835.73 euros
# Closed long position: 379.75 units
# New short position: 75.95 units
#
# Day 2094:
# Short position closed: repurchase of 75.95 shares.
# Long position built: 361.53 units. Total value: 22172.72 euros
#
# Day 2132:
# Total sale:433.84 units for total of 27157.72 euros
# Closed long position: 361.53 units
# New short position: 72.31 units
#
# Day 2138:
# Short position closed: repurchase of 72.31 shares.
# Long position built: 345.23 units. Total value: 22450.4 euros
#
# Day 2155:
# Total sale:414.28 units for total of 26007.64 euros
# Closed long position: 345.23 units
# New short position: 69.05 units
#
# Day 2179:
# Short position closed: repurchase of 69.05 shares.
# Long position built: 336.99 units. Total value: 21580.68 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 22669.15 euros
# Total return: 126.69%
# Shares held at end of period: 336.99
# Total fee spending: 255
# Day 59: purchase of 665.45 units for total of 9995 euros
#
# Day 198:
# Total sale:798.54 units for total of 15342.94 euros
# Closed long position: 665.45 units
# New short position: 133.09 units
#
# Day 212:
# Short position closed: repurchase of 133.09 shares.
# Long position built: 595.55 units. Total value: 12536.39 euros
#
# Day 263:
# Total sale:714.66 units for total of 15867.6 euros
# Closed long position: 595.55 units
# New short position: 119.11 units
#
# Day 276:
# Short position closed: repurchase of 119.11 shares.
# Long position built: 580.92 units. Total value: 13163.57 euros
#
# Day 330:
# Total sale:697.1 units for total of 16474.44 euros
# Closed long position: 580.92 units
# New short position: 116.18 units
#
# Day 382:
# Short position closed: repurchase of 116.18 shares.
# Long position built: 591.27 units. Total value: 13764.77 euros
#
# Day 392:
# Total sale:709.52 units for total of 15909.53 euros
# Closed long position: 591.27 units
# New short position: 118.25 units
#
# Day 425:
# Short position closed: repurchase of 118.25 shares.
# Long position built: 587.36 units. Total value: 13239.18 euros
#
# Day 542:
# Total sale:704.83 units for total of 19892.35 euros
# Closed long position: 587.36 units
# New short position: 117.47 units
#
# Day 575:
# Short position closed: repurchase of 117.47 shares.
# Long position built: 526.55 units. Total value: 16259.88 euros
#
# Day 599:
# Total sale:631.86 units for total of 17857.68 euros
# Closed long position: 526.55 units
# New short position: 105.31 units
#
# Day 694:
# Short position closed: repurchase of 105.31 shares.
# Long position built: 636.39 units. Total value: 15317.87 euros
#
# Day 720:
# Total sale:763.67 units for total of 16169.53 euros
# Closed long position: 636.39 units
# New short position: 127.28 units
#
# Day 755:
# Short position closed: repurchase of 127.28 shares.
# Long position built: 567.37 units. Total value: 13202.72 euros
#
# Day 813:
# Total sale:680.84 units for total of 16457.71 euros
# Closed long position: 567.37 units
# New short position: 113.47 units
#
# Day 896:
# Short position closed: repurchase of 113.47 shares.
# Long position built: 602.18 units. Total value: 13844.04 euros
#
# Day 935:
# Total sale:722.62 units for total of 15632.5 euros
# Closed long position: 602.18 units
# New short position: 120.44 units
#
# Day 979:
# Short position closed: repurchase of 120.44 shares.
# Long position built: 589.58 units. Total value: 12976.61 euros
#
# Day 1062:
# Total sale:707.5 units for total of 17265.08 euros
# Closed long position: 589.58 units
# New short position: 117.92 units
#
# Day 1081:
# Short position closed: repurchase of 117.92 shares.
# Long position built: 554.73 units. Total value: 14234.25 euros
#
# Day 1160:
# Total sale:665.68 units for total of 17848.54 euros
# Closed long position: 554.73 units
# New short position: 110.95 units
#
# Day 1166:
# Short position closed: repurchase of 110.95 shares.
# Long position built: 523.15 units. Total value: 14721.4 euros
#
# Day 1220:
# Total sale:627.78 units for total of 17585.4 euros
# Closed long position: 523.15 units
# New short position: 104.63 units
#
# Day 1229:
# Short position closed: repurchase of 104.63 shares.
# Long position built: 499.71 units. Total value: 14536.71 euros
#
# Day 1335:
# Total sale:599.65 units for total of 19915.37 euros
# Closed long position: 499.71 units
# New short position: 99.94 units
#
# Day 1350:
# Short position closed: repurchase of 99.94 shares.
# Long position built: 469.74 units. Total value: 16417.47 euros
#
# Day 1394:
# Total sale:563.69 units for total of 19803.07 euros
# Closed long position: 469.74 units
# New short position: 93.95 units
#
# Day 1410:
# Short position closed: repurchase of 93.95 shares.
# Long position built: 431.2 units. Total value: 16256.15 euros
#
# Day 1437:
# Total sale:517.44 units for total of 18545.22 euros
# Closed long position: 431.2 units
# New short position: 86.24 units
#
# Day 1467:
# Short position closed: repurchase of 86.24 shares.
# Long position built: 430.34 units. Total value: 15445.07 euros
#
# Day 1581:
# Total sale:516.41 units for total of 21859.8 euros
# Closed long position: 430.34 units
# New short position: 86.07 units
#
# Day 1595:
# Short position closed: repurchase of 86.07 shares.
# Long position built: 404.06 units. Total value: 18016.94 euros
#
# Day 1626:
# Total sale:484.87 units for total of 20427.42 euros
# Closed long position: 404.06 units
# New short position: 80.81 units
#
# Day 1695:
# Short position closed: repurchase of 80.81 shares.
# Long position built: 426.33 units. Total value: 17168.2 euros
#
# Day 1756:
# Total sale:511.6 units for total of 20233.9 euros
# Closed long position: 426.33 units
# New short position: 85.27 units
#
# Day 1793:
# Short position closed: repurchase of 85.27 shares.
# Long position built: 383.64 units. Total value: 16550.35 euros
#
# Day 1839:
# Total sale:460.37 units for total of 19058.92 euros
# Closed long position: 383.64 units
# New short position: 76.73 units
#
# Day 1854:
# Short position closed: repurchase of 76.73 shares.
# Long position built: 342.68 units. Total value: 15568.08 euros
#
# Day 1879:
# Total sale:411.22 units for total of 17730.92 euros
# Closed long position: 342.68 units
# New short position: 68.54 units
#
# Day 1883:
# Short position closed: repurchase of 68.54 shares.
# Long position built: 316.97 units. Total value: 14574.45 euros
#
# Day 1964:
# Total sale:380.36 units for total of 19203.18 euros
# Closed long position: 316.97 units
# New short position: 63.39 units
#
# Day 1973:
# Short position closed: repurchase of 63.39 shares.
# Long position built: 293.45 units. Total value: 15787.8 euros
#
# Day 2073:
# Total sale:352.14 units for total of 20475.46 euros
# Closed long position: 293.45 units
# New short position: 58.69 units
#
# Day 2095:
# Short position closed: repurchase of 58.69 shares.
# Long position built: 268.31 units. Total value: 16796.47 euros
#
# Day 2156:
# Total sale:321.97 units for total of 19612.63 euros
# Closed long position: 268.31 units
# New short position: 53.66 units
#
# Day 2178:
# Short position closed: repurchase of 53.66 shares.
# Long position built: 253.09 units. Total value: 16177.68 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 17025.55 euros
# Total return: 70.26%
# Shares held at end of period: 253.09
# Total fee spending: 235
# Day 69: purchase of 667.67 units for total of 9995 euros
#
# Day 199:
# Total sale:801.2 units for total of 14921.36 euros
# Closed long position: 667.67 units
# New short position: 133.53 units
#
# Day 211:
# Short position closed: repurchase of 133.53 shares.
# Long position built: 572.4 units. Total value: 12094.87 euros
#
# Day 266:
# Total sale:686.88 units for total of 14735.44 euros
# Closed long position: 572.4 units
# New short position: 114.48 units
#
# Day 274:
# Short position closed: repurchase of 114.48 shares.
# Long position built: 519.09 units. Total value: 12068.78 euros
#
# Day 332:
# Total sale:622.91 units for total of 14814.03 euros
# Closed long position: 519.09 units
# New short position: 103.82 units
#
# Day 425:
# Short position closed: repurchase of 103.82 shares.
# Long position built: 553.19 units. Total value: 12468.93 euros
#
# Day 543:
# Total sale:663.83 units for total of 18555.69 euros
# Closed long position: 553.19 units
# New short position: 110.64 units
#
# Day 576:
# Short position closed: repurchase of 110.64 shares.
# Long position built: 496.58 units. Total value: 15170.63 euros
#
# Day 594:
# Total sale:595.9 units for total of 17407.2 euros
# Closed long position: 496.58 units
# New short position: 99.32 units
#
# Day 697:
# Short position closed: repurchase of 99.32 shares.
# Long position built: 641.83 units. Total value: 15070.16 euros
#
# Day 721:
# Total sale:770.2 units for total of 16115.29 euros
# Closed long position: 641.83 units
# New short position: 128.37 units
#
# Day 755:
# Short position closed: repurchase of 128.37 shares.
# Long position built: 563.95 units. Total value: 13123.12 euros
#
# Day 815:
# Total sale:676.74 units for total of 17096.22 euros
# Closed long position: 563.95 units
# New short position: 112.79 units
#
# Day 897:
# Short position closed: repurchase of 112.79 shares.
# Long position built: 628.69 units. Total value: 14491.41 euros
#
# Day 935:
# Total sale:754.43 units for total of 16320.87 euros
# Closed long position: 628.69 units
# New short position: 125.74 units
#
# Day 981:
# Short position closed: repurchase of 125.74 shares.
# Long position built: 610.54 units. Total value: 13529.47 euros
#
# Day 1066:
# Total sale:732.65 units for total of 17600.58 euros
# Closed long position: 610.54 units
# New short position: 122.11 units
#
# Day 1067:
# Short position closed: repurchase of 122.11 shares.
# Long position built: 594.61 units. Total value: 14597.78 euros
#
# Day 1069:
# Total sale:713.53 units for total of 16441.87 euros
# Closed long position: 594.61 units
# New short position: 118.92 units
#
# Day 1080:
# Short position closed: repurchase of 118.92 shares.
# Long position built: 529.99 units. Total value: 13424.62 euros
#
# Day 1340:
# Total sale:635.99 units for total of 20874.55 euros
# Closed long position: 529.99 units
# New short position: 106.0 units
#
# Day 1349:
# Short position closed: repurchase of 106.0 shares.
# Long position built: 490.61 units. Total value: 17161.67 euros
#
# Day 1396:
# Total sale:588.73 units for total of 20712.41 euros
# Closed long position: 490.61 units
# New short position: 98.12 units
#
# Day 1408:
# Short position closed: repurchase of 98.12 shares.
# Long position built: 449.7 units. Total value: 16998.47 euros
#
# Day 1437:
# Total sale:539.64 units for total of 19341.09 euros
# Closed long position: 449.7 units
# New short position: 89.94 units
#
# Day 1467:
# Short position closed: repurchase of 89.94 shares.
# Long position built: 448.82 units. Total value: 16108.15 euros
#
# Day 1584:
# Total sale:538.58 units for total of 22868.49 euros
# Closed long position: 448.82 units
# New short position: 89.76 units
#
# Day 1594:
# Short position closed: repurchase of 89.76 shares.
# Long position built: 423.1 units. Total value: 18861.99 euros
#
# Day 1626:
# Total sale:507.72 units for total of 21390.32 euros
# Closed long position: 423.1 units
# New short position: 84.62 units
#
# Day 1696:
# Short position closed: repurchase of 84.62 shares.
# Long position built: 448.95 units. Total value: 17993.75 euros
#
# Day 1757:
# Total sale:538.74 units for total of 21436.85 euros
# Closed long position: 448.95 units
# New short position: 89.79 units
#
# Day 1794:
# Short position closed: repurchase of 89.79 shares.
# Long position built: 404.6 units. Total value: 17539.46 euros
#
# Day 1841:
# Total sale:485.52 units for total of 20377.13 euros
# Closed long position: 404.6 units
# New short position: 80.92 units
#
# Day 1853:
# Short position closed: repurchase of 80.92 shares.
# Long position built: 371.09 units. Total value: 16725.07 euros
#
# Day 1879:
# Total sale:445.31 units for total of 19201.22 euros
# Closed long position: 371.09 units
# New short position: 74.22 units
#
# Day 1883:
# Short position closed: repurchase of 74.22 shares.
# Long position built: 343.27 units. Total value: 15783.58 euros
#
# Day 1966:
# Total sale:411.92 units for total of 21114.14 euros
# Closed long position: 343.27 units
# New short position: 68.65 units
#
# Day 1972:
# Short position closed: repurchase of 68.65 shares.
# Long position built: 328.74 units. Total value: 17462.45 euros
#
# Day 2074:
# Total sale:394.49 units for total of 22749.18 euros
# Closed long position: 328.74 units
# New short position: 65.75 units
#
# Day 2085:
# Short position closed: repurchase of 65.75 shares.
# Long position built: 314.91 units. Total value: 18815.62 euros
#
# Day 2088:
# Total sale:377.89 units for total of 22154.47 euros
# Closed long position: 314.91 units
# New short position: 62.98 units
#
# Day 2094:
# Short position closed: repurchase of 62.98 shares.
# Long position built: 298.17 units. Total value: 18286.91 euros
#
# Day 2157:
# Total sale:357.8 units for total of 21949.61 euros
# Closed long position: 298.17 units
# New short position: 59.63 units
#
# Day 2179:
# Short position closed: repurchase of 59.63 shares.
# Long position built: 283.04 units. Total value: 18125.9 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 19040.12 euros
# Total return: 90.4%
# Shares held at end of period: 283.04
# Total fee spending: 225
# Day 79: purchase of 675.79 units for total of 9995 euros
#
# Day 200:
# Total sale:810.95 units for total of 15094.89 euros
# Closed long position: 675.79 units
# New short position: 135.16 units
#
# Day 211:
# Short position closed: repurchase of 135.16 shares.
# Long position built: 578.99 units. Total value: 12233.96 euros
#
# Day 333:
# Total sale:694.79 units for total of 16051.6 euros
# Closed long position: 578.99 units
# New short position: 115.8 units
#
# Day 426:
# Short position closed: repurchase of 115.8 shares.
# Long position built: 598.02 units. Total value: 13443.41 euros
#
# Day 545:
# Total sale:717.62 units for total of 19815.66 euros
# Closed long position: 598.02 units
# New short position: 119.6 units
#
# Day 575:
# Short position closed: repurchase of 119.6 shares.
# Long position built: 521.94 units. Total value: 16117.42 euros
#
# Day 593:
# Total sale:626.33 units for total of 18070.88 euros
# Closed long position: 521.94 units
# New short position: 104.39 units
#
# Day 701:
# Short position closed: repurchase of 104.39 shares.
# Long position built: 606.87 units. Total value: 15414.38 euros
#
# Day 721:
# Total sale:728.24 units for total of 15237.06 euros
# Closed long position: 606.87 units
# New short position: 121.37 units
#
# Day 754:
# Short position closed: repurchase of 121.37 shares.
# Long position built: 536.32 units. Total value: 12421.13 euros
#
# Day 817:
# Total sale:643.58 units for total of 15794.89 euros
# Closed long position: 536.32 units
# New short position: 107.26 units
#
# Day 898:
# Short position closed: repurchase of 107.26 shares.
# Long position built: 571.88 units. Total value: 13296.09 euros
#
# Day 936:
# Total sale:686.26 units for total of 14742.73 euros
# Closed long position: 571.88 units
# New short position: 114.38 units
#
# Day 982:
# Short position closed: repurchase of 114.38 shares.
# Long position built: 532.86 units. Total value: 12133.29 euros
#
# Day 1071:
# Total sale:639.43 units for total of 14880.93 euros
# Closed long position: 532.86 units
# New short position: 106.57 units
#
# Day 1080:
# Short position closed: repurchase of 106.57 shares.
# Long position built: 480.72 units. Total value: 12176.51 euros
#
# Day 1397:
# Total sale:576.86 units for total of 20410.08 euros
# Closed long position: 480.72 units
# New short position: 96.14 units
#
# Day 1406:
# Short position closed: repurchase of 96.14 shares.
# Long position built: 455.8 units. Total value: 16850.78 euros
#
# Day 1437:
# Total sale:546.96 units for total of 19603.52 euros
# Closed long position: 455.8 units
# New short position: 91.16 units
#
# Day 1466:
# Short position closed: repurchase of 91.16 shares.
# Long position built: 449.34 units. Total value: 16293.05 euros
#
# Day 1626:
# Total sale:539.21 units for total of 22717.31 euros
# Closed long position: 449.34 units
# New short position: 89.87 units
#
# Day 1697:
# Short position closed: repurchase of 89.87 shares.
# Long position built: 457.41 units. Total value: 18982.7 euros
#
# Day 1758:
# Total sale:548.89 units for total of 22010.98 euros
# Closed long position: 457.41 units
# New short position: 91.48 units
#
# Day 1795:
# Short position closed: repurchase of 91.48 shares.
# Long position built: 416.74 units. Total value: 18044.89 euros
#
# Day 1842:
# Total sale:500.09 units for total of 20458.68 euros
# Closed long position: 416.74 units
# New short position: 83.35 units
#
# Day 1851:
# Short position closed: repurchase of 83.35 shares.
# Long position built: 377.32 units. Total value: 16752.94 euros
#
# Day 1879:
# Total sale:452.78 units for total of 19523.4 euros
# Closed long position: 377.32 units
# New short position: 75.46 units
#
# Day 1883:
# Short position closed: repurchase of 75.46 shares.
# Long position built: 349.04 units. Total value: 16048.75 euros
#
# Day 1969:
# Total sale:418.85 units for total of 21121.79 euros
# Closed long position: 349.04 units
# New short position: 69.81 units
#
# Day 1970:
# Short position closed: repurchase of 69.81 shares.
# Long position built: 335.42 units. Total value: 17478.99 euros
#
# Day 2076:
# Total sale:402.5 units for total of 23641.88 euros
# Closed long position: 335.42 units
# New short position: 67.08 units
#
# Day 2083:
# Short position closed: repurchase of 67.08 shares.
# Long position built: 322.65 units. Total value: 19568.47 euros
#
# Day 2091:
# Total sale:387.18 units for total of 23299.36 euros
# Closed long position: 322.65 units
# New short position: 64.53 units
#
# Day 2092:
# Short position closed: repurchase of 64.53 shares.
# Long position built: 316.22 units. Total value: 19346.42 euros
#
# Day 2158:
# Total sale:379.46 units for total of 23821.29 euros
# Closed long position: 316.22 units
# New short position: 63.24 units
#
# Day 2180:
# Short position closed: repurchase of 63.24 shares.
# Long position built: 306.69 units. Total value: 19744.9 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 20631.25 euros
# Total return: 106.31%
# Shares held at end of period: 306.69
# Total fee spending: 185
# Day 89: purchase of 613.94 units for total of 9995 euros
#
# Day 201:
# Total sale:736.73 units for total of 13705.55 euros
# Closed long position: 613.94 units
# New short position: 122.79 units
#
# Day 210:
# Short position closed: repurchase of 122.79 shares.
# Long position built: 529.31 units. Total value: 11120.73 euros
#
# Day 334:
# Total sale:635.17 units for total of 14870.68 euros
# Closed long position: 529.31 units
# New short position: 105.86 units
#
# Day 427:
# Short position closed: repurchase of 105.86 shares.
# Long position built: 544.43 units. Total value: 12445.72 euros
#
# Day 546:
# Total sale:653.32 units for total of 18039.7 euros
# Closed long position: 544.43 units
# New short position: 108.89 units
#
# Day 556:
# Short position closed: repurchase of 108.89 shares.
# Long position built: 515.36 units. Total value: 14888.87 euros
#
# Day 564:
# Total sale:618.43 units for total of 17632.62 euros
# Closed long position: 515.36 units
# New short position: 103.07 units
#
# Day 574:
# Short position closed: repurchase of 103.07 shares.
# Long position built: 478.32 units. Total value: 14502.54 euros
#
# Day 593:
# Total sale:573.98 units for total of 16560.06 euros
# Closed long position: 478.32 units
# New short position: 95.66 units
#
# Day 703:
# Short position closed: repurchase of 95.66 shares.
# Long position built: 576.22 units. Total value: 14198.0 euros
#
# Day 719:
# Total sale:691.46 units for total of 15158.72 euros
# Closed long position: 576.22 units
# New short position: 115.24 units
#
# Day 755:
# Short position closed: repurchase of 115.24 shares.
# Long position built: 535.97 units. Total value: 12472.08 euros
#
# Day 820:
# Total sale:643.16 units for total of 15906.78 euros
# Closed long position: 535.97 units
# New short position: 107.19 units
#
# Day 900:
# Short position closed: repurchase of 107.19 shares.
# Long position built: 578.23 units. Total value: 13414.97 euros
#
# Day 936:
# Total sale:693.88 units for total of 14906.48 euros
# Closed long position: 578.23 units
# New short position: 115.65 units
#
# Day 983:
# Short position closed: repurchase of 115.65 shares.
# Long position built: 541.96 units. Total value: 12280.85 euros
#
# Day 1073:
# Total sale:650.35 units for total of 15629.41 euros
# Closed long position: 541.96 units
# New short position: 108.39 units
#
# Day 1079:
# Short position closed: repurchase of 108.39 shares.
# Long position built: 521.88 units. Total value: 12937.43 euros
#
# Day 1398:
# Total sale:626.26 units for total of 21857.74 euros
# Closed long position: 521.88 units
# New short position: 104.38 units
#
# Day 1404:
# Short position closed: repurchase of 104.38 shares.
# Long position built: 500.46 units. Total value: 18081.49 euros
#
# Day 1438:
# Total sale:600.55 units for total of 21584.77 euros
# Closed long position: 500.46 units
# New short position: 100.09 units
#
# Day 1467:
# Short position closed: repurchase of 100.09 shares.
# Long position built: 501.19 units. Total value: 17987.54 euros
#
# Day 1626:
# Total sale:601.43 units for total of 25339.26 euros
# Closed long position: 501.19 units
# New short position: 100.24 units
#
# Day 1699:
# Short position closed: repurchase of 100.24 shares.
# Long position built: 504.4 units. Total value: 21134.2 euros
#
# Day 1759:
# Total sale:605.28 units for total of 23564.6 euros
# Closed long position: 504.4 units
# New short position: 100.88 units
#
# Day 1795:
# Short position closed: repurchase of 100.88 shares.
# Long position built: 443.22 units. Total value: 19191.5 euros
#
# Day 1843:
# Total sale:531.86 units for total of 21918.27 euros
# Closed long position: 443.22 units
# New short position: 88.64 units
#
# Day 1849:
# Short position closed: repurchase of 88.64 shares.
# Long position built: 418.61 units. Total value: 18084.02 euros
#
# Day 1879:
# Total sale:502.33 units for total of 21660.49 euros
# Closed long position: 418.61 units
# New short position: 83.72 units
#
# Day 1883:
# Short position closed: repurchase of 83.72 shares.
# Long position built: 387.26 units. Total value: 17806.05 euros
#
# Day 2160:
# Total sale:464.71 units for total of 29271.73 euros
# Closed long position: 387.26 units
# New short position: 77.45 units
#
# Day 2177:
# Short position closed: repurchase of 77.45 shares.
# Long position built: 383.08 units. Total value: 24344.78 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 25769.84 euros
# Total return: 157.7%
# Shares held at end of period: 383.08
# Total fee spending: 165
# Day 99: purchase of 556.82 units for total of 9995 euros
#
# Day 203:
# Total sale:668.18 units for total of 12930.96 euros
# Closed long position: 556.82 units
# New short position: 111.36 units
#
# Day 208:
# Short position closed: repurchase of 111.36 shares.
# Long position built: 525.39 units. Total value: 10665.36 euros
#
# Day 334:
# Total sale:630.47 units for total of 14760.61 euros
# Closed long position: 525.39 units
# New short position: 105.08 units
#
# Day 428:
# Short position closed: repurchase of 105.08 shares.
# Long position built: 538.99 units. Total value: 12348.22 euros
#
# Day 548:
# Total sale:646.79 units for total of 18150.4 euros
# Closed long position: 538.99 units
# New short position: 107.8 units
#
# Day 553:
# Short position closed: repurchase of 107.8 shares.
# Long position built: 510.23 units. Total value: 14980.39 euros
#
# Day 567:
# Total sale:612.28 units for total of 17230.68 euros
# Closed long position: 510.23 units
# New short position: 102.05 units
#
# Day 573:
# Short position closed: repurchase of 102.05 shares.
# Long position built: 466.08 units. Total value: 14131.53 euros
#
# Day 593:
# Total sale:559.3 units for total of 16136.4 euros
# Closed long position: 466.08 units
# New short position: 93.22 units
#
# Day 706:
# Short position closed: repurchase of 93.22 shares.
# Long position built: 560.14 units. Total value: 13829.8 euros
#
# Day 717:
# Total sale:672.17 units for total of 15360.81 euros
# Closed long position: 560.14 units
# New short position: 112.03 units
#
# Day 754:
# Short position closed: repurchase of 112.03 shares.
# Long position built: 551.0 units. Total value: 12761.19 euros
#
# Day 822:
# Total sale:661.2 units for total of 15506.75 euros
# Closed long position: 551.0 units
# New short position: 110.2 units
#
# Day 902:
# Short position closed: repurchase of 110.2 shares.
# Long position built: 560.58 units. Total value: 12955.03 euros
#
# Day 936:
# Total sale:672.7 units for total of 14451.32 euros
# Closed long position: 560.58 units
# New short position: 112.12 units
#
# Day 982:
# Short position closed: repurchase of 112.12 shares.
# Long position built: 522.33 units. Total value: 11893.35 euros
#
# Day 1398:
# Total sale:626.8 units for total of 21876.59 euros
# Closed long position: 522.33 units
# New short position: 104.47 units
#
# Day 1400:
# Short position closed: repurchase of 104.47 shares.
# Long position built: 506.64 units. Total value: 18132.61 euros
#
# Day 1401:
# Total sale:607.97 units for total of 21650.89 euros
# Closed long position: 506.64 units
# New short position: 101.33 units
#
# Day 1403:
# Short position closed: repurchase of 101.33 shares.
# Long position built: 500.28 units. Total value: 18000.04 euros
#
# Day 1439:
# Total sale:600.34 units for total of 21241.03 euros
# Closed long position: 500.28 units
# New short position: 100.06 units
#
# Day 1473:
# Short position closed: repurchase of 100.06 shares.
# Long position built: 475.91 units. Total value: 17546.82 euros
#
# Day 1626:
# Total sale:571.09 units for total of 24060.73 euros
# Closed long position: 475.91 units
# New short position: 95.18 units
#
# Day 1700:
# Short position closed: repurchase of 95.18 shares.
# Long position built: 475.4 units. Total value: 20042.94 euros
#
# Day 1760:
# Total sale:570.48 units for total of 22449.09 euros
# Closed long position: 475.4 units
# New short position: 95.08 units
#
# Day 1795:
# Short position closed: repurchase of 95.08 shares.
# Long position built: 423.26 units. Total value: 18327.13 euros
#
# Day 1842:
# Total sale:507.91 units for total of 20778.68 euros
# Closed long position: 423.26 units
# New short position: 84.65 units
#
# Day 1849:
# Short position closed: repurchase of 84.65 shares.
# Long position built: 396.22 units. Total value: 17116.8 euros
#
# Day 1881:
# Total sale:475.46 units for total of 21343.15 euros
# Closed long position: 396.22 units
# New short position: 79.24 units
#
# Day 1882:
# Short position closed: repurchase of 79.24 shares.
# Long position built: 391.59 units. Total value: 17747.0 euros
#
# Day 2162:
# Total sale:469.91 units for total of 28748.79 euros
# Closed long position: 391.59 units
# New short position: 78.32 units
#
# Day 2173:
# Short position closed: repurchase of 78.32 shares.
# Long position built: 373.13 units. Total value: 23757.16 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 25100.42 euros
# Total return: 151.0%
# Shares held at end of period: 373.13
# Total fee spending: 165
# Day 49: purchase of 731.7 units for total of 9995 euros
#
# Day 199:
# Total sale:878.04 units for total of 16352.89 euros
# Closed long position: 731.7 units
# New short position: 146.34 units
#
# Day 216:
# Short position closed: repurchase of 146.34 shares.
# Long position built: 646.48 units. Total value: 13330.35 euros
#
# Day 263:
# Total sale:775.78 units for total of 17225.07 euros
# Closed long position: 646.48 units
# New short position: 129.3 units
#
# Day 282:
# Short position closed: repurchase of 129.3 shares.
# Long position built: 605.66 units. Total value: 14190.57 euros
#
# Day 332:
# Total sale:726.79 units for total of 17285.33 euros
# Closed long position: 605.66 units
# New short position: 121.13 units
#
# Day 382:
# Short position closed: repurchase of 121.13 shares.
# Long position built: 621.15 units. Total value: 14460.43 euros
#
# Day 395:
# Total sale:745.38 units for total of 15461.64 euros
# Closed long position: 621.15 units
# New short position: 124.23 units
#
# Day 427:
# Short position closed: repurchase of 124.23 shares.
# Long position built: 551.91 units. Total value: 12616.74 euros
#
# Day 542:
# Total sale:662.29 units for total of 18691.45 euros
# Closed long position: 551.91 units
# New short position: 110.38 units
#
# Day 575:
# Short position closed: repurchase of 110.38 shares.
# Long position built: 494.75 units. Total value: 15277.91 euros
#
# Day 599:
# Total sale:593.7 units for total of 16778.9 euros
# Closed long position: 494.75 units
# New short position: 98.95 units
#
# Day 697:
# Short position closed: repurchase of 98.95 shares.
# Long position built: 615.44 units. Total value: 14450.55 euros
#
# Day 722:
# Total sale:738.53 units for total of 15962.02 euros
# Closed long position: 615.44 units
# New short position: 123.09 units
#
# Day 755:
# Short position closed: repurchase of 123.09 shares.
# Long position built: 562.64 units. Total value: 13092.71 euros
#
# Day 801:
# Total sale:675.17 units for total of 17569.68 euros
# Closed long position: 562.64 units
# New short position: 112.53 units
#
# Day 803:
# Short position closed: repurchase of 112.53 shares.
# Long position built: 549.29 units. Total value: 14578.13 euros
#
# Day 813:
# Total sale:659.15 units for total of 15933.25 euros
# Closed long position: 549.29 units
# New short position: 109.86 units
#
# Day 898:
# Short position closed: repurchase of 109.86 shares.
# Long position built: 575.23 units. Total value: 13374.0 euros
#
# Day 936:
# Total sale:690.28 units for total of 14829.12 euros
# Closed long position: 575.23 units
# New short position: 115.05 units
#
# Day 979:
# Short position closed: repurchase of 115.05 shares.
# Long position built: 558.47 units. Total value: 12291.87 euros
#
# Day 1061:
# Total sale:670.16 units for total of 16038.63 euros
# Closed long position: 558.47 units
# New short position: 111.69 units
#
# Day 1083:
# Short position closed: repurchase of 111.69 shares.
# Long position built: 507.85 units. Total value: 13143.09 euros
#
# Day 1160:
# Total sale:609.42 units for total of 16339.64 euros
# Closed long position: 507.85 units
# New short position: 101.57 units
#
# Day 1172:
# Short position closed: repurchase of 101.57 shares.
# Long position built: 469.37 units. Total value: 13428.73 euros
#
# Day 1213:
# Total sale:563.24 units for total of 16075.5 euros
# Closed long position: 469.37 units
# New short position: 93.87 units
#
# Day 1231:
# Short position closed: repurchase of 93.87 shares.
# Long position built: 453.12 units. Total value: 13312.6 euros
#
# Day 1329:
# Total sale:543.74 units for total of 18221.16 euros
# Closed long position: 453.12 units
# New short position: 90.62 units
#
# Day 1351:
# Short position closed: repurchase of 90.62 shares.
# Long position built: 431.18 units. Total value: 15052.62 euros
#
# Day 1393:
# Total sale:517.42 units for total of 18037.44 euros
# Closed long position: 431.18 units
# New short position: 86.24 units
#
# Day 1413:
# Short position closed: repurchase of 86.24 shares.
# Long position built: 389.05 units. Total value: 14760.49 euros
#
# Day 1440:
# Total sale:466.86 units for total of 16087.66 euros
# Closed long position: 389.05 units
# New short position: 77.81 units
#
# Day 1468:
# Short position closed: repurchase of 77.81 shares.
# Long position built: 366.83 units. Total value: 13268.28 euros
#
# Day 1579:
# Total sale:440.2 units for total of 18853.17 euros
# Closed long position: 366.83 units
# New short position: 73.37 units
#
# Day 1598:
# Short position closed: repurchase of 73.37 shares.
# Long position built: 351.14 units. Total value: 15590.54 euros
#
# Day 1628:
# Total sale:421.37 units for total of 17203.75 euros
# Closed long position: 351.14 units
# New short position: 70.23 units
#
# Day 1697:
# Short position closed: repurchase of 70.23 shares.
# Long position built: 344.2 units. Total value: 14284.21 euros
#
# Day 1755:
# Total sale:413.04 units for total of 16607.47 euros
# Closed long position: 344.2 units
# New short position: 68.84 units
#
# Day 1794:
# Short position closed: repurchase of 68.84 shares.
# Long position built: 314.15 units. Total value: 13618.25 euros
#
# Day 1836:
# Total sale:376.98 units for total of 15673.6 euros
# Closed long position: 314.15 units
# New short position: 62.83 units
#
# Day 1857:
# Short position closed: repurchase of 62.83 shares.
# Long position built: 281.99 units. Total value: 12813.6 euros
#
# Day 1960:
# Total sale:338.39 units for total of 17195.36 euros
# Closed long position: 281.99 units
# New short position: 56.4 units
#
# Day 1974:
# Short position closed: repurchase of 56.4 shares.
# Long position built: 259.08 units. Total value: 14117.13 euros
#
# Day 2069:
# Total sale:310.9 units for total of 18403.39 euros
# Closed long position: 259.08 units
# New short position: 51.82 units
#
# Day 2092:
# Short position closed: repurchase of 51.82 shares.
# Long position built: 248.91 units. Total value: 15228.04 euros
#
# Day 2138:
# Total sale:298.69 units for total of 19418.81 euros
# Closed long position: 248.91 units
# New short position: 49.78 units
#
# Day 2140:
# Short position closed: repurchase of 49.78 shares.
# Long position built: 244.01 units. Total value: 16124.35 euros
#
# Day 2158:
# Total sale:292.81 units for total of 18380.54 euros
# Closed long position: 244.01 units
# New short position: 48.8 units
#
# Day 2182:
# Short position closed: repurchase of 48.8 shares.
# Long position built: 231.23 units. Total value: 15173.28 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 15554.81 euros
# Total return: 55.55%
# Shares held at end of period: 231.23
# Total fee spending: 245
# Day 59: purchase of 665.45 units for total of 9995 euros
#
# Day 200:
# Total sale:798.54 units for total of 14863.81 euros
# Closed long position: 665.45 units
# New short position: 133.09 units
#
# Day 217:
# Short position closed: repurchase of 133.09 shares.
# Long position built: 586.12 units. Total value: 12109.18 euros
#
# Day 265:
# Total sale:703.34 units for total of 15116.81 euros
# Closed long position: 586.12 units
# New short position: 117.22 units
#
# Day 281:
# Short position closed: repurchase of 117.22 shares.
# Long position built: 523.38 units. Total value: 12346.59 euros
#
# Day 333:
# Total sale:628.06 units for total of 14509.47 euros
# Closed long position: 523.38 units
# New short position: 104.68 units
#
# Day 384:
# Short position closed: repurchase of 104.68 shares.
# Long position built: 535.13 units. Total value: 12131.37 euros
#
# Day 395:
# Total sale:642.16 units for total of 13319.82 euros
# Closed long position: 535.13 units
# New short position: 107.03 units
#
# Day 427:
# Short position closed: repurchase of 107.03 shares.
# Long position built: 475.42 units. Total value: 10868.11 euros
#
# Day 544:
# Total sale:570.5 units for total of 15683.75 euros
# Closed long position: 475.42 units
# New short position: 95.08 units
#
# Day 578:
# Short position closed: repurchase of 95.08 shares.
# Long position built: 430.88 units. Total value: 12844.42 euros
#
# Day 600:
# Total sale:517.06 units for total of 14477.85 euros
# Closed long position: 430.88 units
# New short position: 86.18 units
#
# Day 698:
# Short position closed: repurchase of 86.18 shares.
# Long position built: 503.83 units. Total value: 12358.86 euros
#
# Day 722:
# Total sale:604.6 units for total of 13066.45 euros
# Closed long position: 503.83 units
# New short position: 100.77 units
#
# Day 757:
# Short position closed: repurchase of 100.77 shares.
# Long position built: 422.74 units. Total value: 10547.24 euros
#
# Day 814:
# Total sale:507.29 units for total of 12509.84 euros
# Closed long position: 422.74 units
# New short position: 84.55 units
#
# Day 898:
# Short position closed: repurchase of 84.55 shares.
# Long position built: 453.29 units. Total value: 10539.06 euros
#
# Day 938:
# Total sale:543.95 units for total of 11728.0 euros
# Closed long position: 453.29 units
# New short position: 90.66 units
#
# Day 982:
# Short position closed: repurchase of 90.66 shares.
# Long position built: 424.18 units. Total value: 9658.67 euros
#
# Day 1068:
# Total sale:509.02 units for total of 11962.06 euros
# Closed long position: 424.18 units
# New short position: 84.84 units
#
# Day 1083:
# Short position closed: repurchase of 84.84 shares.
# Long position built: 377.18 units. Total value: 9761.4 euros
#
# Day 1164:
# Total sale:452.62 units for total of 12337.95 euros
# Closed long position: 377.18 units
# New short position: 75.44 units
#
# Day 1168:
# Short position closed: repurchase of 75.44 shares.
# Long position built: 358.97 units. Total value: 10191.21 euros
#
# Day 1222:
# Total sale:430.76 units for total of 12340.58 euros
# Closed long position: 358.97 units
# New short position: 71.79 units
#
# Day 1232:
# Short position closed: repurchase of 71.79 shares.
# Long position built: 348.65 units. Total value: 10229.26 euros
#
# Day 1338:
# Total sale:418.38 units for total of 14106.96 euros
# Closed long position: 348.65 units
# New short position: 69.73 units
#
# Day 1351:
# Short position closed: repurchase of 69.73 shares.
# Long position built: 334.22 units. Total value: 11667.68 euros
#
# Day 1397:
# Total sale:401.06 units for total of 14188.51 euros
# Closed long position: 334.22 units
# New short position: 66.84 units
#
# Day 1414:
# Short position closed: repurchase of 66.84 shares.
# Long position built: 300.99 units. Total value: 11606.16 euros
#
# Day 1440:
# Total sale:361.19 units for total of 12445.22 euros
# Closed long position: 300.99 units
# New short position: 60.2 units
#
# Day 1471:
# Short position closed: repurchase of 60.2 shares.
# Long position built: 283.55 units. Total value: 10261.58 euros
#
# Day 1583:
# Total sale:340.26 units for total of 14741.87 euros
# Closed long position: 283.55 units
# New short position: 56.71 units
#
# Day 1599:
# Short position closed: repurchase of 56.71 shares.
# Long position built: 263.24 units. Total value: 12124.81 euros
#
# Day 1628:
# Total sale:315.89 units for total of 12895.95 euros
# Closed long position: 263.24 units
# New short position: 52.65 units
#
# Day 1697:
# Short position closed: repurchase of 52.65 shares.
# Long position built: 257.98 units. Total value: 10705.97 euros
#
# Day 1756:
# Total sale:309.58 units for total of 12241.98 euros
# Closed long position: 257.98 units
# New short position: 51.6 units
#
# Day 1795:
# Short position closed: repurchase of 51.6 shares.
# Long position built: 231.01 units. Total value: 10002.7 euros
#
# Day 1840:
# Total sale:277.21 units for total of 11654.45 euros
# Closed long position: 231.01 units
# New short position: 46.2 units
#
# Day 1857:
# Short position closed: repurchase of 46.2 shares.
# Long position built: 210.17 units. Total value: 9550.12 euros
#
# Day 1963:
# Total sale:252.2 units for total of 12736.14 euros
# Closed long position: 210.17 units
# New short position: 42.03 units
#
# Day 1974:
# Short position closed: repurchase of 42.03 shares.
# Long position built: 191.61 units. Total value: 10440.93 euros
#
# Day 2074:
# Total sale:229.93 units for total of 13257.36 euros
# Closed long position: 191.61 units
# New short position: 38.32 units
#
# Day 2094:
# Short position closed: repurchase of 38.32 shares.
# Long position built: 177.76 units. Total value: 10902.2 euros
#
# Day 2158:
# Total sale:213.31 units for total of 13388.73 euros
# Closed long position: 177.76 units
# New short position: 35.55 units
#
# Day 2181:
# Short position closed: repurchase of 35.55 shares.
# Long position built: 169.38 units. Total value: 11061.96 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 11393.94 euros
# Total return: 13.94%
# Shares held at end of period: 169.38
# Total fee spending: 225
# Day 69: purchase of 667.67 units for total of 9995 euros
#
# Day 201:
# Total sale:801.2 units for total of 14905.33 euros
# Closed long position: 667.67 units
# New short position: 133.53 units
#
# Day 216:
# Short position closed: repurchase of 133.53 shares.
# Long position built: 589.09 units. Total value: 12146.94 euros
#
# Day 269:
# Total sale:706.91 units for total of 15730.82 euros
# Closed long position: 589.09 units
# New short position: 117.82 units
#
# Day 275:
# Short position closed: repurchase of 117.82 shares.
# Long position built: 559.14 units. Total value: 12988.86 euros
#
# Day 335:
# Total sale:670.97 units for total of 15212.6 euros
# Closed long position: 559.14 units
# New short position: 111.83 units
#
# Day 428:
# Short position closed: repurchase of 111.83 shares.
# Long position built: 551.97 units. Total value: 12645.57 euros
#
# Day 546:
# Total sale:662.36 units for total of 18289.38 euros
# Closed long position: 551.97 units
# New short position: 110.39 units
#
# Day 579:
# Short position closed: repurchase of 110.39 shares.
# Long position built: 500.72 units. Total value: 14981.51 euros
#
# Day 599:
# Total sale:600.86 units for total of 16981.31 euros
# Closed long position: 500.72 units
# New short position: 100.14 units
#
# Day 700:
# Short position closed: repurchase of 100.14 shares.
# Long position built: 596.75 units. Total value: 14536.9 euros
#
# Day 723:
# Total sale:716.1 units for total of 15376.83 euros
# Closed long position: 596.75 units
# New short position: 119.35 units
#
# Day 757:
# Short position closed: repurchase of 119.35 shares.
# Long position built: 496.76 units. Total value: 12394.05 euros
#
# Day 817:
# Total sale:596.11 units for total of 14629.5 euros
# Closed long position: 496.76 units
# New short position: 99.35 units
#
# Day 899:
# Short position closed: repurchase of 99.35 shares.
# Long position built: 527.24 units. Total value: 12305.67 euros
#
# Day 939:
# Total sale:632.69 units for total of 13439.66 euros
# Closed long position: 527.24 units
# New short position: 105.45 units
#
# Day 983:
# Short position closed: repurchase of 105.45 shares.
# Long position built: 487.43 units. Total value: 11045.17 euros
#
# Day 1069:
# Total sale:584.92 units for total of 13477.41 euros
# Closed long position: 487.43 units
# New short position: 97.49 units
#
# Day 1083:
# Short position closed: repurchase of 97.49 shares.
# Long position built: 423.08 units. Total value: 10949.36 euros
#
# Day 1341:
# Total sale:507.7 units for total of 16779.56 euros
# Closed long position: 423.08 units
# New short position: 84.62 units
#
# Day 1350:
# Short position closed: repurchase of 84.62 shares.
# Long position built: 395.34 units. Total value: 13817.09 euros
#
# Day 1399:
# Total sale:474.41 units for total of 16741.67 euros
# Closed long position: 395.34 units
# New short position: 79.07 units
#
# Day 1411:
# Short position closed: repurchase of 79.07 shares.
# Long position built: 363.93 units. Total value: 13749.41 euros
#
# Day 1440:
# Total sale:436.72 units for total of 15048.74 euros
# Closed long position: 363.93 units
# New short position: 72.79 units
#
# Day 1472:
# Short position closed: repurchase of 72.79 shares.
# Long position built: 339.03 units. Total value: 12384.72 euros
#
# Day 1587:
# Total sale:406.84 units for total of 17680.33 euros
# Closed long position: 339.03 units
# New short position: 67.81 units
#
# Day 1597:
# Short position closed: repurchase of 67.81 shares.
# Long position built: 324.71 units. Total value: 14621.85 euros
#
# Day 1628:
# Total sale:389.65 units for total of 15908.31 euros
# Closed long position: 324.71 units
# New short position: 64.94 units
#
# Day 1698:
# Short position closed: repurchase of 64.94 shares.
# Long position built: 313.62 units. Total value: 13175.18 euros
#
# Day 1758:
# Total sale:376.34 units for total of 15090.0 euros
# ...
#
# Day 1451:
# Total sale:457.93 units for total of 15212.01 euros
# Closed long position: 381.61 units
# New short position: 76.32 units
#
# Day 1485:
# Short position closed: repurchase of 76.32 shares.
# Long position built: 317.95 units. Total value: 12263.35 euros
#
# Day 1589:
# Total sale:381.54 units for total of 16557.65 euros
# Closed long position: 317.95 units
# New short position: 63.59 units
#
# Day 1604:
# Short position closed: repurchase of 63.59 shares.
# Long position built: 296.96 units. Total value: 13633.23 euros
#
# Day 1639:
# Total sale:356.35 units for total of 14341.65 euros
# Closed long position: 296.96 units
# New short position: 59.39 units
#
# Day 1702:
# Short position closed: repurchase of 59.39 shares.
# Long position built: 285.74 units. Total value: 11869.59 euros
#
# Day 1763:
# Total sale:342.89 units for total of 13196.26 euros
# Closed long position: 285.74 units
# New short position: 57.15 units
#
# Day 1806:
# Short position closed: repurchase of 57.15 shares.
# Long position built: 239.48 units. Total value: 10649.8 euros
#
# Day 1848:
# Total sale:287.38 units for total of 12280.5 euros
# Closed long position: 239.48 units
# New short position: 47.9 units
#
# Day 1873:
# Short position closed: repurchase of 47.9 shares.
# Long position built: 249.62 units. Total value: 10299.14 euros
#
# Day 2079:
# Total sale:299.54 units for total of 17763.71 euros
# Closed long position: 249.62 units
# New short position: 49.92 units
#
# Day 2100:
# Short position closed: repurchase of 49.92 shares.
# Long position built: 230.01 units. Total value: 14591.79 euros
#
# Day 2154:
# Total sale:276.01 units for total of 17441.59 euros
# Closed long position: 230.01 units
# New short position: 46.0 units
#
# Day 2169:
# Short position closed: repurchase of 46.0 shares.
# Long position built: 233.66 units. Total value: 14568.49 euros
#
# Day 2180:
# Total sale:280.39 units for total of 18046.51 euros
# Closed long position: 233.66 units
# New short position: 46.73 units
#
# Day 2200:
# Short position closed: repurchase of 46.73 shares.
# Long position built: 220.67 units. Total value: 14888.64 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 14844.5 euros
# Total return: 48.45%
# Shares held at end of period: 220.67
# Total fee spending: 225
# Day 69: purchase of 667.67 units for total of 9995 euros
#
# Day 212:
# Total sale:801.2 units for total of 16860.26 euros
# Closed long position: 667.67 units
# New short position: 133.53 units
#
# Day 232:
# Short position closed: repurchase of 133.53 shares.
# Long position built: 619.27 units. Total value: 13865.52 euros
#
# Day 287:
# Total sale:743.12 units for total of 17911.62 euros
# Closed long position: 619.27 units
# New short position: 123.85 units
#
# Day 300:
# Short position closed: repurchase of 123.85 shares.
# Long position built: 620.09 units. Total value: 14925.55 euros
#
# Day 348:
# Total sale:744.11 units for total of 15941.28 euros
# Closed long position: 620.09 units
# New short position: 124.02 units
#
# Day 444:
# Short position closed: repurchase of 124.02 shares.
# Long position built: 585.2 units. Total value: 13149.55 euros
#
# Day 561:
# Total sale:702.24 units for total of 20549.56 euros
# Closed long position: 585.2 units
# New short position: 117.04 units
#
# Day 592:
# Short position closed: repurchase of 117.04 shares.
# Long position built: 600.8 units. Total value: 17194.88 euros
#
# Day 613:
# Total sale:720.96 units for total of 19590.69 euros
# Closed long position: 600.8 units
# New short position: 120.16 units
#
# Day 705:
# Short position closed: repurchase of 120.16 shares.
# Long position built: 702.42 units. Total value: 16724.68 euros
#
# Day 739:
# Total sale:842.9 units for total of 18117.35 euros
# Closed long position: 702.42 units
# New short position: 140.48 units
#
# Day 770:
# Short position closed: repurchase of 140.48 shares.
# Long position built: 550.04 units. Total value: 14427.56 euros
#
# Day 822:
# Total sale:660.05 units for total of 15479.77 euros
# Closed long position: 550.04 units
# New short position: 110.01 units
#
# Day 906:
# Short position closed: repurchase of 110.01 shares.
# Long position built: 552.44 units. Total value: 12904.94 euros
#
# Day 950:
# Total sale:662.93 units for total of 13664.62 euros
# Closed long position: 552.44 units
# New short position: 110.49 units
#
# Day 994:
# Short position closed: repurchase of 110.49 shares.
# Long position built: 508.15 units. Total value: 11220.0 euros
#
# Day 1237:
# Total sale:609.78 units for total of 17928.63 euros
# Closed long position: 508.15 units
# New short position: 101.63 units
#
# Day 1241:
# Short position closed: repurchase of 101.63 shares.
# Long position built: 501.86 units. Total value: 14905.22 euros
#
# Day 1350:
# Total sale:602.23 units for total of 21042.94 euros
# Closed long position: 501.86 units
# New short position: 100.37 units
#
# Day 1357:
# Short position closed: repurchase of 100.37 shares.
# Long position built: 470.69 units. Total value: 17340.31 euros
#
# Day 1415:
# Total sale:564.83 units for total of 21803.09 euros
# Closed long position: 470.69 units
# New short position: 94.14 units
#
# Day 1433:
# Short position closed: repurchase of 94.14 shares.
# Long position built: 490.26 units. Total value: 18286.66 euros
#
# Day 1450:
# Total sale:588.31 units for total of 19944.59 euros
# Closed long position: 490.26 units
# New short position: 98.05 units
#
# Day 1487:
# Short position closed: repurchase of 98.05 shares.
# Long position built: 420.13 units. Total value: 16166.63 euros
#
# Day 1594:
# Total sale:504.16 units for total of 22470.45 euros
# Closed long position: 420.13 units
# New short position: 84.03 units
#
# Day 1605:
# Short position closed: repurchase of 84.03 shares.
# Long position built: 407.66 units. Total value: 18626.12 euros
#
# Day 1639:
# Total sale:489.19 units for total of 19689.79 euros
# Closed long position: 407.66 units
# New short position: 81.53 units
#
# Day 1704:
# Short position closed: repurchase of 81.53 shares.
# Long position built: 373.93 units. Total value: 16161.06 euros
#
# Day 1766:
# Total sale:448.72 units for total of 17755.34 euros
# Closed long position: 373.93 units
# New short position: 74.79 units
#
# Day 1810:
# Short position closed: repurchase of 74.79 shares.
# Long position built: 324.18 units. Total value: 14422.93 euros
#
# Day 1855:
# Total sale:389.02 units for total of 17780.99 euros
# Closed long position: 324.18 units
# New short position: 64.84 units
#
# Day 1875:
# Short position closed: repurchase of 64.84 shares.
# Long position built: 344.84 units. Total value: 14962.59 euros
#
# Day 2086:
# Total sale:413.81 units for total of 24327.03 euros
# Closed long position: 344.84 units
# New short position: 68.97 units
#
# Day 2102:
# Short position closed: repurchase of 68.97 shares.
# Long position built: 311.54 units. Total value: 19913.47 euros
#
# Day 2163:
# Total sale:373.85 units for total of 22590.49 euros
# Closed long position: 311.54 units
# New short position: 62.31 units
#
# Day 2172:
# Short position closed: repurchase of 62.31 shares.
# Long position built: 288.72 units. Total value: 18576.47 euros
#
# Day 2177:
# Total sale:346.46 units for total of 22012.53 euros
# Closed long position: 288.72 units
# New short position: 57.74 units
#
# Day 2199:
# Short position closed: repurchase of 57.74 shares.
# Long position built: 267.62 units. Total value: 18102.0 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 18002.98 euros
# Total return: 80.03%
# Shares held at end of period: 267.62
# Total fee spending: 195
# Day 79: purchase of 675.79 units for total of 9995 euros
#
# Day 350:
# Total sale:810.95 units for total of 17073.61 euros
# Closed long position: 675.79 units
# New short position: 135.16 units
#
# Day 443:
# Short position closed: repurchase of 135.16 shares.
# Long position built: 619.42 units. Total value: 14011.29 euros
#
# Day 564:
# Total sale:743.3 units for total of 21193.92 euros
# Closed long position: 619.42 units
# New short position: 123.88 units
#
# Day 603:
# Short position closed: repurchase of 123.88 shares.
# Long position built: 641.06 units. Total value: 17757.44 euros
#
# Day 612:
# Total sale:769.27 units for total of 20511.43 euros
# Closed long position: 641.06 units
# New short position: 128.21 units
#
# Day 713:
# Short position closed: repurchase of 128.21 shares.
# Long position built: 721.27 units. Total value: 17411.44 euros
#
# Day 741:
# Total sale:865.52 units for total of 19425.92 euros
# Closed long position: 721.27 units
# New short position: 144.25 units
#
# Day 771:
# Short position closed: repurchase of 144.25 shares.
# Long position built: 587.23 units. Total value: 15591.09 euros
#
# Day 826:
# Total sale:704.68 units for total of 17139.86 euros
# Closed long position: 587.23 units
# New short position: 117.45 units
#
# Day 909:
# Short position closed: repurchase of 117.45 shares.
# Long position built: 625.28 units. Total value: 14425.29 euros
#
# Day 952:
# Total sale:750.34 units for total of 15391.98 euros
# Closed long position: 625.28 units
# New short position: 125.06 units
#
# Day 999:
# Short position closed: repurchase of 125.06 shares.
# Long position built: 535.33 units. Total value: 12473.08 euros
#
# Day 1426:
# Total sale:642.4 units for total of 24464.02 euros
# Closed long position: 535.33 units
# New short position: 107.07 units
#
# Day 1430:
# Short position closed: repurchase of 107.07 shares.
# Long position built: 548.67 units. Total value: 20465.31 euros
#
# Day 1448:
# Total sale:658.4 units for total of 21340.33 euros
# Closed long position: 548.67 units
# New short position: 109.73 units
#
# Day 1488:
# Short position closed: repurchase of 109.73 shares.
# Long position built: 445.3 units. Total value: 17117.31 euros
#
# Day 1639:
# Total sale:534.36 units for total of 21508.33 euros
# Closed long position: 445.3 units
# New short position: 89.06 units
#
# Day 1707:
# Short position closed: repurchase of 89.06 shares.
# Long position built: 411.6 units. Total value: 17678.21 euros
#
# Day 1769:
# Total sale:493.92 units for total of 19598.68 euros
# Closed long position: 411.6 units
# New short position: 82.32 units
#
# Day 1813:
# Short position closed: repurchase of 82.32 shares.
# Long position built: 354.26 units. Total value: 15899.16 euros
#
# Day 2095:
# Total sale:425.11 units for total of 26606.89 euros
# Closed long position: 354.26 units
# New short position: 70.85 units
#
# Day 2098:
# Short position closed: repurchase of 70.85 shares.
# Long position built: 362.05 units. Total value: 22248.15 euros
#
# Day 2177:
# Total sale:434.46 units for total of 27604.93 euros
# Closed long position: 362.05 units
# New short position: 72.41 units
#
# Day 2197:
# Short position closed: repurchase of 72.41 shares.
# Long position built: 339.96 units. Total value: 22753.53 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 22869.12 euros
# Total return: 128.69%
# Shares held at end of period: 339.96
# Total fee spending: 125
# Day 89: purchase of 613.94 units for total of 9995 euros
#
# Day 352:
# Total sale:736.73 units for total of 16284.1 euros
# Closed long position: 613.94 units
# New short position: 122.79 units
#
# Day 445:
# Short position closed: repurchase of 122.79 shares.
# Long position built: 584.38 units. Total value: 13452.47 euros
#
# Day 567:
# Total sale:701.26 units for total of 19735.47 euros
# Closed long position: 584.38 units
# New short position: 116.88 units
#
# Day 722:
# Short position closed: repurchase of 116.88 shares.
# Long position built: 795.72 units. Total value: 17203.52 euros
#
# Day 742:
# Total sale:954.86 units for total of 21374.32 euros
# Closed long position: 795.72 units
# New short position: 159.14 units
#
# Day 767:
# Short position closed: repurchase of 159.14 shares.
# Long position built: 667.85 units. Total value: 17257.14 euros
#
# Day 833:
# Total sale:801.42 units for total of 18323.48 euros
# Closed long position: 667.85 units
# New short position: 133.57 units
#
# Day 916:
# Short position closed: repurchase of 133.57 shares.
# Long position built: 686.42 units. Total value: 15334.52 euros
#
# Day 952:
# Total sale:823.7 units for total of 16897.32 euros
# Closed long position: 686.42 units
# New short position: 137.28 units
#
# Day 1001:
# Short position closed: repurchase of 137.28 shares.
# Long position built: 592.73 units. Total value: 13715.66 euros
#
# Day 1446:
# Total sale:711.28 units for total of 22514.12 euros
# Closed long position: 592.73 units
# New short position: 118.55 units
#
# Day 1488:
# Short position closed: repurchase of 118.55 shares.
# Long position built: 467.02 units. Total value: 17952.06 euros
#
# Day 1638:
# Total sale:560.42 units for total of 22120.38 euros
# Closed long position: 467.02 units
# New short position: 93.4 units
#
# Day 1710:
# Short position closed: repurchase of 93.4 shares.
# Long position built: 421.27 units. Total value: 18101.98 euros
#
# Day 1773:
# Total sale:505.52 units for total of 19947.87 euros
# Closed long position: 421.27 units
# New short position: 84.25 units
#
# Day 1816:
# Short position closed: repurchase of 84.25 shares.
# Long position built: 366.54 units. Total value: 16215.65 euros
#
# Day 2181:
# Total sale:439.85 units for total of 28721.6 euros
# Closed long position: 366.54 units
# New short position: 73.31 units
#
# Day 2198:
# Short position closed: repurchase of 73.31 shares.
# Long position built: 353.13 units. Total value: 23779.91 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 23755.19 euros
# Total return: 137.55%
# Shares held at end of period: 353.13
# Total fee spending: 95
# Day 99: purchase of 556.82 units for total of 9995 euros
#
# Day 354:
# Total sale:668.18 units for total of 15530.19 euros
# Closed long position: 556.82 units
# New short position: 111.36 units
#
# Day 445:
# Short position closed: repurchase of 111.36 shares.
# Long position built: 563.06 units. Total value: 12961.68 euros
#
# Day 571:
# Total sale:675.67 units for total of 20089.43 euros
# Closed long position: 563.06 units
# New short position: 112.61 units
#
# Day 588:
# Short position closed: repurchase of 112.61 shares.
# Long position built: 559.56 units. Total value: 16719.64 euros
#
# Day 591:
# Total sale:671.47 units for total of 19454.2 euros
# Closed long position: 559.56 units
# New short position: 111.91 units
#
# Day 727:
# Short position closed: repurchase of 111.91 shares.
# Long position built: 727.87 units. Total value: 16857.36 euros
#
# Day 742:
# Total sale:873.44 units for total of 19551.32 euros
# Closed long position: 727.87 units
# New short position: 145.57 units
#
# Day 768:
# Short position closed: repurchase of 145.57 shares.
# Long position built: 591.47 units. Total value: 15685.81 euros
#
# Day 837:
# Total sale:709.76 units for total of 16028.48 euros
# Closed long position: 591.47 units
# New short position: 118.29 units
#
# Day 919:
# Short position closed: repurchase of 118.29 shares.
# Long position built: 575.67 units. Total value: 13292.16 euros
#
# Day 952:
# Total sale:690.8 units for total of 14170.22 euros
# Closed long position: 575.67 units
# New short position: 115.13 units
#
# Day 1003:
# Short position closed: repurchase of 115.13 shares.
# Long position built: 488.93 units. Total value: 11465.42 euros
#
# Day 1448:
# Total sale:586.72 units for total of 19016.46 euros
# Closed long position: 488.93 units
# New short position: 97.79 units
#
# Day 1487:
# Short position closed: repurchase of 97.79 shares.
# Long position built: 396.27 units. Total value: 15248.5 euros
#
# Day 1638:
# Total sale:475.52 units for total of 18768.53 euros
# Closed long position: 396.27 units
# New short position: 79.25 units
#
# Day 1715:
# Short position closed: repurchase of 79.25 shares.
# Long position built: 347.78 units. Total value: 15281.28 euros
#
# Day 1775:
# Total sale:417.34 units for total of 16208.66 euros
# Closed long position: 347.78 units
# New short position: 69.56 units
#
# Day 1816:
# Short position closed: repurchase of 69.56 shares.
# Long position built: 296.71 units. Total value: 13126.32 euros
#
# Day 2186:
# Total sale:356.05 units for total of 22970.91 euros
# Closed long position: 296.71 units
# New short position: 59.34 units
#
# Day 2197:
# Short position closed: repurchase of 59.34 shares.
# Long position built: 283.79 units. Total value: 18994.28 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 2204: 19090.77 euros
# Total return: 90.91%
# Shares held at end of period: 283.79
# Total fee spending: 105

# %%
best_vals
# Out:
# {'best_sms_s': 20, 'best_sms_l': 90}

# %%
best_total_final_capital
# Out:
# 27896.12499275136

# %%
best_total_return
# Out:
# 1.7896124992751359

# %%
results["SMA Strategy"]["XSD train"] = str(round(best_total_return*100, 2))+"%"
results["SMA Parameter"]["XSD train"] = str("SMA short: " + str(best_vals["best_sms_s"]) +", SMA long: " +str(best_vals["best_sms_l"]))
results["SMA Parameter"]["XSD test"] = str("SMA short: " + str(best_vals["best_sms_s"]) +", SMA long: " +str(best_vals["best_sms_l"]))

# %%
return_test, _ = sma_evaluation_short(xsd_test, best_vals["best_sms_s"], best_vals["best_sms_l"])
# Out:
# Day 90: purchase of 134.25 units for total of 9995 euros
#
# Day 108:
# Total sale:161.1 units for total of 11301.0 euros
# Closed long position: 134.25 units
# New short position: 26.85 units
#
# Day 139:
# Short position closed: repurchase of 26.85 shares.
# Long position built: 125.9 units. Total value: 9310.44 euros
#
# Day 235:
# Total sale:151.08 units for total of 10717.15 euros
# Closed long position: 125.9 units
# New short position: 25.18 units
#
# Day 314:
# Short position closed: repurchase of 25.18 shares.
# Long position built: 121.42 units. Total value: 8872.24 euros
#
# Day 395:
# Total sale:145.7 units for total of 10722.89 euros
# Closed long position: 121.42 units
# New short position: 24.28 units
#
# Day 417:
# Short position closed: repurchase of 24.28 shares.
# Long position built: 100.72 units. Total value: 8636.12 euros
#
# End of observation period
# Short position of 0 units closed for 0.0 euros.
#
# End capital on day 544: 10665.72 euros
# Total return: 6.66%
# Shares held at end of period: 100.72
# Total fee spending: 35

# %%
results["SMA Strategy"]["XSD test"] = str(round(return_test*100, 2))+"%"

# %% [markdown]
# # Mean-Reversion Strategy Performance Evaluation

# %%
grid={"sma_list": list(range(10,85,5)), "std_list": [0.5,1,1.5,2,2.5,3,3.5,4]}

keys, values = zip(*grid.items())
permut_grid = [dict(zip(keys, v)) for v in itertools.product(*values)]

# %% [markdown]
# ## VGT

# %%
best_total_return = -1000
best_total_final_capital = 0
for i in range(len(permut_grid)):
    sma, std_dev = permut_grid[i].values()
    total_return, total_final_capital = mean_rev_evaluation(sma=sma, std_dev=std_dev, data=vgt_train)
    if total_return > best_total_return: 
        best_total_final_capital = total_final_capital
        best_total_return= total_return
        best_vals = {"best_sma": sma, "best_std": std_dev}
# Out:
# Day 21: purchase of 298.36 units for total of 9995 euros
#
# Day 35:
# Went neutral. Long position closed - sold 298.36 units for 9294.83 euros.
#
# Day 78: purchase of 235.3 units for total of 9289.83 euros
#
# Day 83:
# Went neutral. Long position closed - sold 235.3 units for 9353.06 euros.
#
# Day 103: purchase of 223.42 units for total of 9348.06 euros
#
# Day 110:
# Went neutral. Long position closed - sold 223.42 units for 9497.23 euros.
#
# Day 116: purchase of 227.85 units for total of 9492.23 euros
#
# Day 121:
# Went neutral. Long position closed - sold 227.85 units for 9512.29 euros.
#
# Day 142: purchase of 205.65 units for total of 9507.29 euros
#
# Day 143:
# Went neutral. Long position closed - sold 205.65 units for 9646.25 euros.
#
# Day 147: purchase of 208.05 units for total of 9641.25 euros
#
# Day 148:
# Went neutral. Long position closed - sold 208.05 units for 9692.42 euros.
#
# Day 158: purchase of 207.48 units for total of 9687.42 euros
#
# Day 160:
# Went neutral. Long position closed - sold 207.48 units for 9921.03 euros.
#
# Day 174: purchase of 200.65 units for total of 9916.03 euros
#
# Day 175:
# Went neutral. Long position closed - sold 200.65 units for 10093.62 euros.
#
# Day 178: purchase of 207.84 units for total of 10088.62 euros
#
# Day 181:
# Went neutral. Long position closed - sold 207.84 units for 10333.03 euros.
#
# Day 196: purchase of 204.07 units for total of 10328.03 euros
#
# Day 203:
# Went neutral. Long position closed - sold 204.07 units for 10388.33 euros.
#
# Day 214: purchase of 199.91 units for total of 10383.33 euros
#
# Day 215:
# Went neutral. Long position closed - sold 199.91 units for 10540.26 euros.
#
# Day 218: purchase of 203.38 units for total of 10535.26 euros
#
# Day 220:
# Went neutral. Long position closed - sold 203.38 units for 10707.2 euros.
#
# Day 248: purchase of 196.01 units for total of 10702.2 euros
#
# Day 250:
# Went neutral. Long position closed - sold 196.01 units for 10883.41 euros.
#
# Day 254: purchase of 200.12 units for total of 10878.41 euros
#
# Day 269:
# Went neutral. Long position closed - sold 200.12 units for 10317.08 euros.
#
# Day 321: purchase of 177.27 units for total of 10312.08 euros
#
# Day 322:
# Went neutral. Long position closed - sold 177.27 units for 10404.58 euros.
#
# Day 324: purchase of 178.66 units for total of 10399.58 euros
#
# Day 331:
# Went neutral. Long position closed - sold 178.66 units for 10123.03 euros.
#
# Day 335: purchase of 187.41 units for total of 10118.03 euros
#
# Day 342:
# Went neutral. Long position closed - sold 187.41 units for 9991.21 euros.
#
# Day 348: purchase of 195.69 units for total of 9986.21 euros
#
# Day 352:
# Went neutral. Long position closed - sold 195.69 units for 10296.28 euros.
#
# Day 361: purchase of 197.11 units for total of 10291.28 euros
#
# Day 369:
# Went neutral. Long position closed - sold 197.11 units for 10091.14 euros.
#
# Day 394: purchase of 194.19 units for total of 10086.14 euros
#
# Day 409:
# Went neutral. Long position closed - sold 194.19 units for 9851.99 euros.
#
# Day 460: purchase of 165.94 units for total of 9846.99 euros
#
# Day 466:
# Went neutral. Long position closed - sold 165.94 units for 9906.71 euros.
#
# Day 493: purchase of 160.95 units for total of 9901.71 euros
#
# Day 494:
# Went neutral. Long position closed - sold 160.95 units for 10009.38 euros.
#
# Day 507: purchase of 158.22 units for total of 10004.38 euros
#
# Day 508:
# Went neutral. Long position closed - sold 158.22 units for 10143.36 euros.
#
# Day 529: purchase of 157.84 units for total of 10138.36 euros
#
# Day 535:
# Went neutral. Long position closed - sold 157.84 units for 10384.33 euros.
#
# Day 539: purchase of 161.17 units for total of 10379.33 euros
#
# Day 549:
# Went neutral. Long position closed - sold 161.17 units for 10108.4 euros.
#
# Day 562: purchase of 158.73 units for total of 10103.4 euros
#
# Day 569:
# Went neutral. Long position closed - sold 158.73 units for 10219.04 euros.
#
# Day 579: purchase of 157.24 units for total of 10214.04 euros
#
# Day 582:
# Went neutral. Long position closed - sold 157.24 units for 10388.29 euros.
#
# Day 586: purchase of 161.88 units for total of 10383.29 euros
#
# Day 595:
# Went neutral. Long position closed - sold 161.88 units for 10362.1 euros.
#
# Day 599: purchase of 165.29 units for total of 10357.1 euros
#
# Day 611:
# Went neutral. Long position closed - sold 165.29 units for 10112.43 euros.
#
# Day 626: purchase of 159.0 units for total of 10107.43 euros
#
# Day 630:
# Went neutral. Long position closed - sold 159.0 units for 10342.51 euros.
#
# Day 637: purchase of 161.98 units for total of 10337.51 euros
#
# Day 649:
# Went neutral. Long position closed - sold 161.98 units for 9673.26 euros.
#
# Day 653: purchase of 179.44 units for total of 9668.26 euros
#
# Day 658:
# Went neutral. Long position closed - sold 179.44 units for 10264.38 euros.
#
# Day 664: purchase of 181.01 units for total of 10259.38 euros
#
# Day 665:
# Went neutral. Long position closed - sold 181.01 units for 10549.42 euros.
#
# Day 668: purchase of 183.76 units for total of 10544.42 euros
#
# Day 669:
# Went neutral. Long position closed - sold 183.76 units for 10688.27 euros.
#
# Day 677: purchase of 183.94 units for total of 10683.27 euros
#
# Day 679:
# Went neutral. Long position closed - sold 183.94 units for 10959.7 euros.
#
# Day 681: purchase of 187.64 units for total of 10954.7 euros
#
# Day 685:
# Went neutral. Long position closed - sold 187.64 units for 10889.66 euros.
#
# Day 711: purchase of 173.68 units for total of 10884.66 euros
#
# Day 712:
# Went neutral. Long position closed - sold 173.68 units for 11114.13 euros.
#
# Day 716: purchase of 179.01 units for total of 11109.13 euros
#
# Day 724:
# Went neutral. Long position closed - sold 179.01 units for 11175.73 euros.
#
# Day 733: purchase of 180.17 units for total of 11170.73 euros
#
# Day 738:
# Went neutral. Long position closed - sold 180.17 units for 11171.13 euros.
#
# Day 789: purchase of 160.8 units for total of 11166.13 euros
#
# Day 791:
# Went neutral. Long position closed - sold 160.8 units for 11394.3 euros.
#
# Day 811: purchase of 154.06 units for total of 11389.3 euros
#
# Day 818:
# Went neutral. Long position closed - sold 154.06 units for 11307.27 euros.
#
# Day 820: purchase of 156.87 units for total of 11302.27 euros
#
# Day 824:
# Went neutral. Long position closed - sold 156.87 units for 11391.39 euros.
#
# Day 831: purchase of 161.35 units for total of 11386.39 euros
#
# Day 847:
# Went neutral. Long position closed - sold 161.35 units for 10937.68 euros.
#
# Day 850: purchase of 168.45 units for total of 10932.68 euros
#
# Day 853:
# Went neutral. Long position closed - sold 168.45 units for 11342.08 euros.
#
# Day 867: purchase of 169.51 units for total of 11337.08 euros
#
# Day 870:
# Went neutral. Long position closed - sold 169.51 units for 11645.68 euros.
#
# Day 877: purchase of 174.03 units for total of 11640.68 euros
#
# Day 882:
# Went neutral. Long position closed - sold 174.03 units for 11893.24 euros.
#
# Day 887: purchase of 178.39 units for total of 11888.24 euros
#
# Day 889:
# Went neutral. Long position closed - sold 178.39 units for 12313.17 euros.
#
# Day 914: purchase of 169.46 units for total of 12308.17 euros
#
# Day 917:
# Went neutral. Long position closed - sold 169.46 units for 12586.18 euros.
#
# Day 930: purchase of 171.41 units for total of 12581.18 euros
#
# Day 937:
# Went neutral. Long position closed - sold 171.41 units for 12637.88 euros.
#
# Day 939: purchase of 174.29 units for total of 12632.88 euros
#
# Day 945:
# Went neutral. Long position closed - sold 174.29 units for 12671.46 euros.
#
# Day 948: purchase of 182.12 units for total of 12666.46 euros
#
# Day 955:
# Went neutral. Long position closed - sold 182.12 units for 12732.48 euros.
#
# Day 960: purchase of 189.71 units for total of 12727.48 euros
#
# Day 967:
# Went neutral. Long position closed - sold 189.71 units for 12849.59 euros.
#
# Day 980: purchase of 186.37 units for total of 12844.59 euros
#
# Day 982:
# Went neutral. Long position closed - sold 186.37 units for 13076.28 euros.
#
# Day 985: purchase of 190.04 units for total of 13071.28 euros
#
# Day 986:
# Went neutral. Long position closed - sold 190.04 units for 13235.42 euros.
#
# Day 991: purchase of 191.86 units for total of 13230.42 euros
#
# Day 996:
# Went neutral. Long position closed - sold 191.86 units for 13662.85 euros.
#
# Day 1015: purchase of 193.37 units for total of 13657.85 euros
#
# Day 1017:
# Went neutral. Long position closed - sold 193.37 units for 13807.55 euros.
#
# Day 1030: purchase of 196.0 units for total of 13802.55 euros
#
# Day 1036:
# Went neutral. Long position closed - sold 196.0 units for 13936.71 euros.
#
# Day 1051: purchase of 192.27 units for total of 13931.71 euros
#
# Day 1053:
# Went neutral. Long position closed - sold 192.27 units for 13986.31 euros.
#
# Day 1057: purchase of 193.57 units for total of 13981.31 euros
#
# Day 1063:
# Went neutral. Long position closed - sold 193.57 units for 14144.71 euros.
#
# Day 1069: purchase of 203.83 units for total of 14139.71 euros
#
# Day 1073:
# Went neutral. Long position closed - sold 203.83 units for 14507.72 euros.
#
# Day 1095: purchase of 191.25 units for total of 14502.72 euros
#
# Day 1096:
# Went neutral. Long position closed - sold 191.25 units for 14606.74 euros.
#
# Day 1102: purchase of 193.45 units for total of 14601.74 euros
#
# Day 1104:
# Went neutral. Long position closed - sold 193.45 units for 14778.58 euros.
#
# Day 1107: purchase of 196.85 units for total of 14773.58 euros
#
# Day 1110:
# Went neutral. Long position closed - sold 196.85 units for 14992.99 euros.
#
# Day 1114: purchase of 202.7 units for total of 14987.99 euros
#
# Day 1120:
# Went neutral. Long position closed - sold 202.7 units for 15106.64 euros.
#
# Day 1134: purchase of 196.35 units for total of 15101.64 euros
#
# Day 1137:
# Went neutral. Long position closed - sold 196.35 units for 15236.05 euros.
#
# Day 1153: purchase of 193.98 units for total of 15231.05 euros
#
# Day 1158:
# Went neutral. Long position closed - sold 193.98 units for 15381.23 euros.
#
# Day 1161: purchase of 197.92 units for total of 15376.23 euros
#
# Day 1165:
# Went neutral. Long position closed - sold 197.92 units for 15557.28 euros.
#
# Day 1183: purchase of 192.72 units for total of 15552.28 euros
#
# Day 1184:
# Went neutral. Long position closed - sold 192.72 units for 15713.01 euros.
#
# Day 1189: purchase of 198.63 units for total of 15708.01 euros
#
# Day 1191:
# Went neutral. Long position closed - sold 198.63 units for 16030.76 euros.
#
# Day 1220: purchase of 189.9 units for total of 16025.76 euros
#
# Day 1221:
# Went neutral. Long position closed - sold 189.9 units for 16199.27 euros.
#
# Day 1235: purchase of 188.33 units for total of 16194.27 euros
#
# Day 1237:
# Went neutral. Long position closed - sold 188.33 units for 16334.28 euros.
#
# Day 1250: purchase of 185.41 units for total of 16329.28 euros
#
# Day 1251:
# Went neutral. Long position closed - sold 185.41 units for 16489.3 euros.
#
# Day 1264: purchase of 189.02 units for total of 16484.3 euros
#
# Day 1272:
# Went neutral. Long position closed - sold 189.02 units for 16445.27 euros.
#
# Day 1297: purchase of 182.31 units for total of 16440.27 euros
#
# Day 1299:
# Went neutral. Long position closed - sold 182.31 units for 16869.16 euros.
#
# Day 1306: purchase of 186.88 units for total of 16864.16 euros
#
# Day 1309:
# Went neutral. Long position closed - sold 186.88 units for 17328.23 euros.
#
# Day 1313: purchase of 194.4 units for total of 17323.23 euros
#
# Day 1315:
# Went neutral. Long position closed - sold 194.4 units for 17753.69 euros.
#
# Day 1317: purchase of 202.22 units for total of 17748.69 euros
#
# Day 1320:
# Went neutral. Long position closed - sold 202.22 units for 18186.55 euros.
#
# Day 1334: purchase of 203.19 units for total of 18181.55 euros
#
# Day 1337:
# Went neutral. Long position closed - sold 203.19 units for 18532.14 euros.
#
# Day 1394: purchase of 191.26 units for total of 18527.14 euros
#
# Day 1400:
# Went neutral. Long position closed - sold 191.26 units for 18659.84 euros.
#
# Day 1417: purchase of 184.94 units for total of 18654.84 euros
#
# Day 1418:
# Went neutral. Long position closed - sold 184.94 units for 18755.26 euros.
#
# Day 1430: purchase of 186.68 units for total of 18750.26 euros
#
# Day 1441:
# Went neutral. Long position closed - sold 186.68 units for 18545.51 euros.
#
# Day 1443: purchase of 195.76 units for total of 18540.51 euros
#
# Day 1450:
# Went neutral. Long position closed - sold 195.76 units for 18960.31 euros.
#
# Day 1484: purchase of 178.89 units for total of 18955.31 euros
#
# Day 1491:
# Went neutral. Long position closed - sold 178.89 units for 18769.63 euros.
#
# Day 1500: purchase of 180.01 units for total of 18764.63 euros
#
# Day 1513:
# Went neutral. Long position closed - sold 180.01 units for 18792.03 euros.
#
# Day 1517: purchase of 185.57 units for total of 18787.03 euros
#
# Day 1521:
# Went neutral. Long position closed - sold 185.57 units for 19099.36 euros.
#
# Day 1542: purchase of 175.21 units for total of 19094.36 euros
#
# Day 1551:
# Went neutral. Long position closed - sold 175.21 units for 18959.7 euros.
#
# Day 1557: purchase of 179.51 units for total of 18954.7 euros
#
# Day 1563:
# Went neutral. Long position closed - sold 179.51 units for 19139.98 euros.
#
# Day 1585: purchase of 178.78 units for total of 19134.98 euros
#
# Day 1587:
# Went neutral. Long position closed - sold 178.78 units for 19539.39 euros.
#
# Day 1606: purchase of 177.62 units for total of 19534.39 euros
#
# Day 1610:
# Went neutral. Long position closed - sold 177.62 units for 19545.38 euros.
#
# Day 1612: purchase of 179.8 units for total of 19540.38 euros
#
# Day 1614:
# Went neutral. Long position closed - sold 179.8 units for 19686.41 euros.
#
# Day 1621: purchase of 181.41 units for total of 19681.41 euros
#
# Day 1631:
# Went neutral. Long position closed - sold 181.41 units for 19505.88 euros.
#
# Day 1641: purchase of 181.91 units for total of 19500.88 euros
#
# Day 1648:
# Went neutral. Long position closed - sold 181.91 units for 19708.72 euros.
#
# Day 1650: purchase of 183.58 units for total of 19703.72 euros
#
# Day 1651:
# Went neutral. Long position closed - sold 183.58 units for 19999.79 euros.
#
# Day 1654: purchase of 186.1 units for total of 19994.79 euros
#
# Day 1655:
# Went neutral. Long position closed - sold 186.1 units for 20095.87 euros.
#
# Day 1659: purchase of 192.48 units for total of 20090.87 euros
#
# Day 1665:
# Went neutral. Long position closed - sold 192.48 units for 19854.89 euros.
#
# Day 1682: purchase of 196.18 units for total of 19849.89 euros
#
# Day 1689:
# Went neutral. Long position closed - sold 196.18 units for 19921.41 euros.
#
# Day 1717: purchase of 179.7 units for total of 19916.41 euros
#
# Day 1722:
# Went neutral. Long position closed - sold 179.7 units for 19909.61 euros.
#
# Day 1737: purchase of 179.84 units for total of 19904.61 euros
#
# Day 1741:
# Went neutral. Long position closed - sold 179.84 units for 19939.17 euros.
#
# Day 1743: purchase of 186.21 units for total of 19934.17 euros
#
# Day 1746:
# Went neutral. Long position closed - sold 186.21 units for 20359.33 euros.
#
# Day 1752: purchase of 190.92 units for total of 20354.33 euros
#
# Day 1765:
# Went neutral. Long position closed - sold 190.92 units for 19144.6 euros.
#
# Day 1776: purchase of 202.26 units for total of 19139.6 euros
#
# Day 1781:
# Went neutral. Long position closed - sold 202.26 units for 19747.44 euros.
#
# Day 1818: purchase of 182.33 units for total of 19742.44 euros
#
# Day 1821:
# Went neutral. Long position closed - sold 182.33 units for 20098.45 euros.
#
# Day 1829: purchase of 186.45 units for total of 20093.45 euros
#
# Day 1840:
# Went neutral. Long position closed - sold 186.45 units for 19711.83 euros.
#
# Day 1863: purchase of 182.25 units for total of 19706.83 euros
#
# Day 1871:
# Went neutral. Long position closed - sold 182.25 units for 19940.57 euros.
#
# Day 1873: purchase of 195.56 units for total of 19935.57 euros
#
# Day 1876:
# Went neutral. Long position closed - sold 195.56 units for 20937.72 euros.
#
# Day 1926: purchase of 177.91 units for total of 20932.72 euros
#
# Day 1929:
# Went neutral. Long position closed - sold 177.91 units for 21230.16 euros.
#
# Day 1948: purchase of 177.78 units for total of 21225.16 euros
#
# Day 1953:
# Went neutral. Long position closed - sold 177.78 units for 21261.05 euros.
#
# Day 1962: purchase of 179.0 units for total of 21256.05 euros
#
# Day 1966:
# Went neutral. Long position closed - sold 179.0 units for 21345.92 euros.
#
# Day 1983: purchase of 181.73 units for total of 21340.92 euros
#
# Day 1987:
# Went neutral. Long position closed - sold 181.73 units for 22108.29 euros.
#
# Day 2002: purchase of 180.26 units for total of 22103.29 euros
#
# Day 2005:
# Went neutral. Long position closed - sold 180.26 units for 22202.84 euros.
#
# Day 2059: purchase of 165.09 units for total of 22197.84 euros
#
# Day 2062:
# Went neutral. Long position closed - sold 165.09 units for 22318.3 euros.
#
# Day 2069: purchase of 165.63 units for total of 22313.3 euros
#
# Day 2077:
# Went neutral. Long position closed - sold 165.63 units for 22213.9 euros.
#
# Day 2098: purchase of 157.81 units for total of 22208.9 euros
#
# Day 2100:
# Went neutral. Long position closed - sold 157.81 units for 22558.97 euros.
#
# Day 2114: purchase of 158.16 units for total of 22553.97 euros
#
# Day 2119:
# Went neutral. Long position closed - sold 158.16 units for 22833.67 euros.
#
# Day 2127: purchase of 161.87 units for total of 22828.67 euros
#
# Day 2133:
# Went neutral. Long position closed - sold 161.87 units for 23098.85 euros.
#
# Day 2147: purchase of 156.67 units for total of 23093.85 euros
#
# Day 2153:
# Went neutral. Long position closed - sold 156.67 units for 23236.12 euros.
#
# Day 2157: purchase of 159.12 units for total of 23231.12 euros
#
# Day 2158:
# Went neutral. Long position closed - sold 159.12 units for 23601.64 euros.
#
# Day 2162: purchase of 161.44 units for total of 23596.64 euros
#
# Day 2164:
# Went neutral. Long position closed - sold 161.44 units for 23911.3 euros.
#
# Day 2186: purchase of 158.32 units for total of 23906.3 euros
#
# Day 2190:
# Went neutral. Long position closed - sold 158.32 units for 23907.63 euros.
#
#
# End capital on day 2204: 23907.63 euros
# Total return: 139.08%
# Shares held at end of period: 0
# Total fee spending: 1190
# Day 21: purchase of 298.36 units for total of 9995 euros
#
# Day 35:
# Went neutral. Long position closed - sold 298.36 units for 9294.83 euros.
#
# Day 79: purchase of 236.92 units for total of 9289.83 euros
#
# Day 83:
# Went neutral. Long position closed - sold 236.92 units for 9417.5 euros.
#
# Day 103: purchase of 224.96 units for total of 9412.5 euros
#
# Day 110:
# Went neutral. Long position closed - sold 224.96 units for 9562.73 euros.
#
# Day 117: purchase of 235.24 units for total of 9557.73 euros
#
# Day 121:
# Went neutral. Long position closed - sold 235.24 units for 9820.9 euros.
#
# Day 142: purchase of 212.33 units for total of 9815.9 euros
#
# Day 143:
# Went neutral. Long position closed - sold 212.33 units for 9959.53 euros.
#
# Day 158: purchase of 213.2 units for total of 9954.53 euros
#
# Day 160:
# Went neutral. Long position closed - sold 213.2 units for 10194.71 euros.
#
# Day 174: purchase of 206.19 units for total of 10189.71 euros
#
# Day 175:
# Went neutral. Long position closed - sold 206.19 units for 10372.34 euros.
#
# Day 178: purchase of 213.58 units for total of 10367.34 euros
#
# Day 181:
# Went neutral. Long position closed - sold 213.58 units for 10618.64 euros.
#
# Day 196: purchase of 209.71 units for total of 10613.64 euros
#
# Day 203:
# Went neutral. Long position closed - sold 209.71 units for 10675.75 euros.
#
# Day 214: purchase of 205.44 units for total of 10670.75 euros
#
# Day 215:
# Went neutral. Long position closed - sold 205.44 units for 10832.16 euros.
#
# Day 218: purchase of 209.02 units for total of 10827.16 euros
#
# Day 220:
# Went neutral. Long position closed - sold 209.02 units for 11004.01 euros.
#
# Day 248: purchase of 201.45 units for total of 10999.01 euros
#
# Day 250:
# Went neutral. Long position closed - sold 201.45 units for 11185.38 euros.
#
# Day 254: purchase of 205.67 units for total of 11180.38 euros
#
# Day 269:
# Went neutral. Long position closed - sold 205.67 units for 10603.61 euros.
#
# Day 321: purchase of 182.2 units for total of 10598.61 euros
#
# Day 322:
# Went neutral. Long position closed - sold 182.2 units for 10693.82 euros.
#
# Day 325: purchase of 189.32 units for total of 10688.82 euros
#
# Day 331:
# Went neutral. Long position closed - sold 189.32 units for 10727.37 euros.
#
# Day 337: purchase of 207.44 units for total of 10722.37 euros
#
# Day 342:
# Went neutral. Long position closed - sold 207.44 units for 11059.64 euros.
#
# Day 348: purchase of 216.63 units for total of 11054.64 euros
#
# Day 352:
# Went neutral. Long position closed - sold 216.63 units for 11398.41 euros.
#
# Day 361: purchase of 218.22 units for total of 11393.41 euros
#
# Day 369:
# Went neutral. Long position closed - sold 218.22 units for 11172.37 euros.
#
# Day 394: purchase of 215.01 units for total of 11167.37 euros
#
# Day 409:
# Went neutral. Long position closed - sold 215.01 units for 10908.66 euros.
#
# Day 460: purchase of 183.75 units for total of 10903.66 euros
#
# Day 466:
# Went neutral. Long position closed - sold 183.75 units for 10970.33 euros.
#
# Day 493: purchase of 178.24 units for total of 10965.33 euros
#
# Day 494:
# Went neutral. Long position closed - sold 178.24 units for 11085.09 euros.
#
# Day 507: purchase of 175.23 units for total of 11080.09 euros
#
# Day 508:
# Went neutral. Long position closed - sold 175.23 units for 11234.56 euros.
#
# Day 529: purchase of 174.83 units for total of 11229.56 euros
#
# Day 535:
# Went neutral. Long position closed - sold 174.83 units for 11502.54 euros.
#
# Day 540: purchase of 182.33 units for total of 11497.54 euros
#
# Day 549:
# Went neutral. Long position closed - sold 182.33 units for 11436.02 euros.
#
# Day 562: purchase of 179.59 units for total of 11431.02 euros
#
# Day 569:
# Went neutral. Long position closed - sold 179.59 units for 11562.51 euros.
#
# Day 579: purchase of 177.92 units for total of 11557.51 euros
#
# Day 582:
# Went neutral. Long position closed - sold 177.92 units for 11755.34 euros.
#
# Day 586: purchase of 183.2 units for total of 11750.34 euros
#
# Day 595:
# Went neutral. Long position closed - sold 183.2 units for 11727.02 euros.
#
# Day 599: purchase of 187.07 units for total of 11722.02 euros
#
# Day 611:
# Went neutral. Long position closed - sold 187.07 units for 11445.76 euros.
#
# Day 627: purchase of 181.74 units for total of 11440.76 euros
#
# Day 630:
# Went neutral. Long position closed - sold 181.74 units for 11822.87 euros.
#
# Day 638: purchase of 186.81 units for total of 11817.87 euros
#
# Day 649:
# Went neutral. Long position closed - sold 186.81 units for 11157.16 euros.
#
# Day 653: purchase of 206.98 units for total of 11152.16 euros
#
# Day 658:
# Went neutral. Long position closed - sold 206.98 units for 11840.54 euros.
#
# Day 682: purchase of 208.52 units for total of 11835.54 euros
#
# Day 685:
# Went neutral. Long position closed - sold 208.52 units for 12101.62 euros.
#
# Day 716: purchase of 194.92 units for total of 12096.62 euros
#
# Day 724:
# Went neutral. Long position closed - sold 194.92 units for 12169.59 euros.
#
# Day 733: purchase of 196.2 units for total of 12164.59 euros
#
# Day 738:
# Went neutral. Long position closed - sold 196.2 units for 12165.47 euros.
#
# Day 789: purchase of 175.12 units for total of 12160.47 euros
#
# Day 791:
# Went neutral. Long position closed - sold 175.12 units for 12409.4 euros.
#
# Day 812: purchase of 169.02 units for total of 12404.4 euros
#
# Day 818:
# Went neutral. Long position closed - sold 169.02 units for 12406.16 euros.
#
# Day 820: purchase of 172.12 units for total of 12401.16 euros
#
# Day 824:
# Went neutral. Long position closed - sold 172.12 units for 12499.43 euros.
#
# Day 831: purchase of 177.05 units for total of 12494.43 euros
#
# Day 847:
# Went neutral. Long position closed - sold 177.05 units for 12002.54 euros.
#
# Day 850: purchase of 184.86 units for total of 11997.54 euros
#
# Day 853:
# Went neutral. Long position closed - sold 184.86 units for 12447.3 euros.
#
# Day 869: purchase of 186.91 units for total of 12442.3 euros
#
# Day 870:
# Went neutral. Long position closed - sold 186.91 units for 12841.02 euros.
#
# Day 877: purchase of 191.9 units for total of 12836.02 euros
#
# Day 882:
# Went neutral. Long position closed - sold 191.9 units for 13115.03 euros.
#
# Day 930: purchase of 178.61 units for total of 13110.03 euros
#
# Day 937:
# Went neutral. Long position closed - sold 178.61 units for 13169.33 euros.
#
# Day 939: purchase of 181.63 units for total of 13164.33 euros
#
# Day 945:
# Went neutral. Long position closed - sold 181.63 units for 13204.73 euros.
#
# Day 948: purchase of 189.79 units for total of 13199.73 euros
#
# Day 955:
# Went neutral. Long position closed - sold 189.79 units for 13268.75 euros.
#
# Day 960: purchase of 197.7 units for total of 13263.75 euros
#
# Day 967:
# Went neutral. Long position closed - sold 197.7 units for 13391.21 euros.
#
# Day 980: purchase of 194.23 units for total of 13386.21 euros
#
# Day 982:
# Went neutral. Long position closed - sold 194.23 units for 13627.88 euros.
#
# Day 985: purchase of 198.06 units for total of 13622.88 euros
#
# Day 986:
# Went neutral. Long position closed - sold 198.06 units for 13794.16 euros.
#
# Day 991: purchase of 199.96 units for total of 13789.16 euros
#
# Day 996:
# Went neutral. Long position closed - sold 199.96 units for 14240.06 euros.
#
# Day 1030: purchase of 202.15 units for total of 14235.06 euros
#
# Day 1036:
# Went neutral. Long position closed - sold 202.15 units for 14373.59 euros.
#
# Day 1052: purchase of 198.71 units for total of 14368.59 euros
#
# Day 1053:
# Went neutral. Long position closed - sold 198.71 units for 14454.99 euros.
#
# Day 1058: purchase of 201.59 units for total of 14449.99 euros
#
# Day 1063:
# Went neutral. Long position closed - sold 201.59 units for 14731.25 euros.
#
# Day 1069: purchase of 212.29 units for total of 14726.25 euros
#
# Day 1073:
# Went neutral. Long position closed - sold 212.29 units for 15109.73 euros.
#
# Day 1102: purchase of 200.12 units for total of 15104.73 euros
#
# Day 1104:
# Went neutral. Long position closed - sold 200.12 units for 15287.84 euros.
#
# Day 1107: purchase of 203.64 units for total of 15282.84 euros
#
# Day 1110:
# Went neutral. Long position closed - sold 203.64 units for 15509.99 euros.
#
# Day 1114: purchase of 209.7 units for total of 15504.99 euros
#
# Day 1120:
# Went neutral. Long position closed - sold 209.7 units for 15627.9 euros.
#
# Day 1135: purchase of 204.01 units for total of 15622.9 euros
#
# Day 1137:
# Went neutral. Long position closed - sold 204.01 units for 15830.07 euros.
#
# Day 1153: purchase of 201.54 units for total of 15825.07 euros
#
# Day 1158:
# Went neutral. Long position closed - sold 201.54 units for 15981.3 euros.
#
# Day 1161: purchase of 205.64 units for total of 15976.3 euros
#
# Day 1165:
# Went neutral. Long position closed - sold 205.64 units for 16164.61 euros.
#
# Day 1183: purchase of 200.24 units for total of 16159.61 euros
#
# Day 1184:
# Went neutral. Long position closed - sold 200.24 units for 16326.82 euros.
#
# Day 1189: purchase of 206.4 units for total of 16321.82 euros
#
# Day 1191:
# Went neutral. Long position closed - sold 206.4 units for 16657.37 euros.
#
# Day 1235: purchase of 193.65 units for total of 16652.37 euros
#
# Day 1237:
# Went neutral. Long position closed - sold 193.65 units for 16796.48 euros.
#
# Day 1250: purchase of 190.66 units for total of 16791.48 euros
#
# Day 1251:
# Went neutral. Long position closed - sold 190.66 units for 16956.17 euros.
#
# Day 1264: purchase of 194.37 units for total of 16951.17 euros
#
# Day 1272:
# Went neutral. Long position closed - sold 194.37 units for 16911.18 euros.
#
# Day 1297: purchase of 187.47 units for total of 16906.18 euros
#
# Day 1299:
# Went neutral. Long position closed - sold 187.47 units for 17347.37 euros.
#
# Day 1306: purchase of 192.18 units for total of 17342.37 euros
#
# Day 1309:
# Went neutral. Long position closed - sold 192.18 units for 17819.74 euros.
#
# Day 1313: purchase of 199.92 units for total of 17814.74 euros
#
# Day 1315:
# Went neutral. Long position closed - sold 199.92 units for 18257.56 euros.
#
# Day 1317: purchase of 207.96 units for total of 18252.56 euros
#
# Day 1320:
# Went neutral. Long position closed - sold 207.96 units for 18702.99 euros.
#
# Day 1334: purchase of 208.96 units for total of 18697.99 euros
#
# Day 1337:
# Went neutral. Long position closed - sold 208.96 units for 19058.67 euros.
#
# Day 1394: purchase of 196.69 units for total of 19053.67 euros
#
# Day 1400:
# Went neutral. Long position closed - sold 196.69 units for 19190.29 euros.
#
# Day 1430: purchase of 191.01 units for total of 19185.29 euros
#
# Day 1441:
# Went neutral. Long position closed - sold 191.01 units for 18975.91 euros.
#
# Day 1443: purchase of 200.31 units for total of 18970.91 euros
#
# Day 1450:
# Went neutral. Long position closed - sold 200.31 units for 19400.57 euros.
#
# Day 1485: purchase of 186.08 units for total of 19395.57 euros
#
# Day 1491:
# Went neutral. Long position closed - sold 186.08 units for 19524.55 euros.
#
# Day 1500: purchase of 187.26 units for total of 19519.55 euros
#
# Day 1513:
# Went neutral. Long position closed - sold 187.26 units for 19548.26 euros.
#
# Day 1519: purchase of 193.86 units for total of 19543.26 euros
#
# Day 1521:
# Went neutral. Long position closed - sold 193.86 units for 19953.12 euros.
#
# Day 1542: purchase of 183.04 units for total of 19948.12 euros
#
# Day 1551:
# Went neutral. Long position closed - sold 183.04 units for 19807.67 euros.
#
# Day 1557: purchase of 187.54 units for total of 19802.67 euros
#
# Day 1563:
# Went neutral. Long position closed - sold 187.54 units for 19996.47 euros.
#
# Day 1585: purchase of 186.78 units for total of 19991.47 euros
#
# Day 1587:
# Went neutral. Long position closed - sold 186.78 units for 20414.2 euros.
#
# Day 1606: purchase of 185.57 units for total of 20409.2 euros
#
# Day 1610:
# Went neutral. Long position closed - sold 185.57 units for 20420.9 euros.
#
# Day 1612: purchase of 187.85 units for total of 20415.9 euros
#
# Day 1614:
# Went neutral. Long position closed - sold 187.85 units for 20568.7 euros.
#
# Day 1621: purchase of 189.54 units for total of 20563.7 euros
#
# Day 1631:
# Went neutral. Long position closed - sold 189.54 units for 20380.53 euros.
#
# Day 1641: purchase of 190.07 units for total of 20375.53 euros
#
# Day 1648:
# Went neutral. Long position closed - sold 190.07 units for 20592.91 euros.
#
# Day 1659: purchase of 197.24 units for total of 20587.91 euros
#
# Day 1665:
# Went neutral. Long position closed - sold 197.24 units for 20346.22 euros.
#
# Day 1682: purchase of 201.04 units for total of 20341.22 euros
#
# Day 1689:
# Went neutral. Long position closed - sold 201.04 units for 20414.63 euros.
#
# Day 1718: purchase of 186.02 units for total of 20409.63 euros
#
# Day 1722:
# Went neutral. Long position closed - sold 186.02 units for 20609.24 euros.
#
# Day 1737: purchase of 186.16 units for total of 20604.24 euros
#
# Day 1741:
# Went neutral. Long position closed - sold 186.16 units for 20640.2 euros.
#
# Day 1743: purchase of 192.76 units for total of 20635.2 euros
#
# Day 1746:
# Went neutral. Long position closed - sold 192.76 units for 21075.48 euros.
#
# Day 1752: purchase of 197.64 units for total of 21070.48 euros
#
# Day 1765:
# Went neutral. Long position closed - sold 197.64 units for 19818.37 euros.
#
# Day 1776: purchase of 209.38 units for total of 19813.37 euros
#
# Day 1781:
# Went neutral. Long position closed - sold 209.38 units for 20442.78 euros.
#
# Day 1819: purchase of 189.13 units for total of 20437.78 euros
#
# Day 1821:
# Went neutral. Long position closed - sold 189.13 units for 20848.87 euros.
#
# Day 1829: purchase of 193.41 units for total of 20843.87 euros
#
# Day 1840:
# Went neutral. Long position closed - sold 193.41 units for 20448.18 euros.
#
# Day 1863: purchase of 189.06 units for total of 20443.18 euros
#
# Day 1871:
# Went neutral. Long position closed - sold 189.06 units for 20685.85 euros.
#
# Day 1873: purchase of 202.87 units for total of 20680.85 euros
#
# Day 1876:
# Went neutral. Long position closed - sold 202.87 units for 21720.65 euros.
#
# Day 1927: purchase of 185.87 units for total of 21715.65 euros
#
# Day 1929:
# Went neutral. Long position closed - sold 185.87 units for 22180.91 euros.
#
# Day 1948: purchase of 185.74 units for total of 22175.91 euros
#
# Day 1953:
# Went neutral. Long position closed - sold 185.74 units for 22213.63 euros.
#
# Day 1962: purchase of 187.02 units for total of 22208.63 euros
#
# Day 1966:
# Went neutral. Long position closed - sold 187.02 units for 22302.75 euros.
#
# Day 1983: purchase of 189.88 units for total of 22297.75 euros
#
# Day 1987:
# Went neutral. Long position closed - sold 189.88 units for 23099.75 euros.
#
# Day 2002: purchase of 188.34 units for total of 23094.75 euros
#
# Day 2005:
# Went neutral. Long position closed - sold 188.34 units for 23198.99 euros.
#
# Day 2060: purchase of 172.84 units for total of 23193.99 euros
#
# Day 2062:
# Went neutral. Long position closed - sold 172.84 units for 23367.02 euros.
#
# Day 2071: purchase of 173.62 units for total of 23362.02 euros
#
# Day 2077:
# Went neutral. Long position closed - sold 173.62 units for 23285.83 euros.
#
# Day 2114: purchase of 163.26 units for total of 23280.83 euros
#
# Day 2119:
# Went neutral. Long position closed - sold 163.26 units for 23569.7 euros.
#
# Day 2127: purchase of 167.09 units for total of 23564.7 euros
#
# Day 2133:
# Went neutral. Long position closed - sold 167.09 units for 23843.75 euros.
#
# Day 2147: purchase of 161.73 units for total of 23838.75 euros
#
# Day 2153:
# Went neutral. Long position closed - sold 161.73 units for 23985.78 euros.
#
# Day 2157: purchase of 164.25 units for total of 23980.78 euros
#
# Day 2158:
# Went neutral. Long position closed - sold 164.25 units for 24363.41 euros.
#
# Day 2186: purchase of 161.31 units for total of 24358.41 euros
#
# Day 2190:
# Went neutral. Long position closed - sold 161.31 units for 24359.86 euros.
#
#
# End capital on day 2204: 24359.86 euros
# Total return: 143.6%
# Shares held at end of period: 0
# Total fee spending: 1040
# Day 22: purchase of 307.92 units for total of 9995 euros
#
# Day 35:
# Went neutral. Long position closed - sold 307.92 units for 9592.79 euros.
#
# Day 80: purchase of 251.05 units for total of 9587.79 euros
#
# Day 83:
# Went neutral. Long position closed - sold 251.05 units for 9979.45 euros.
#
# Day 103: purchase of 238.4 units for total of 9974.45 euros
#
# Day 110:
# Went neutral. Long position closed - sold 238.4 units for 10133.95 euros.
#
# Day 117: purchase of 249.3 units for total of 10128.95 euros
#
# Day 121:
# Went neutral. Long position closed - sold 249.3 units for 10408.14 euros.
#
# Day 158: purchase of 222.81 units for total of 10403.14 euros
#
# Day 160:
# Went neutral. Long position closed - sold 222.81 units for 10654.38 euros.
#
# Day 178: purchase of 219.39 units for total of 10649.38 euros
#
# Day 181:
# Went neutral. Long position closed - sold 219.39 units for 10907.65 euros.
#
# Day 196: purchase of 215.42 units for total of 10902.65 euros
#
# Day 203:
# Went neutral. Long position closed - sold 215.42 units for 10966.59 euros.
#
# Day 218: purchase of 211.61 units for total of 10961.59 euros
#
# Day 220:
# Went neutral. Long position closed - sold 211.61 units for 11140.69 euros.
#
# Day 248: purchase of 203.95 units for total of 11135.69 euros
#
# Day 250:
# Went neutral. Long position closed - sold 203.95 units for 11324.45 euros.
#
# Day 254: purchase of 208.23 units for total of 11319.45 euros
#
# Day 269:
# Went neutral. Long position closed - sold 208.23 units for 10735.56 euros.
#
# Day 325: purchase of 190.06 units for total of 10730.56 euros
#
# Day 331:
# Went neutral. Long position closed - sold 190.06 units for 10769.28 euros.
#
# Day 337: purchase of 208.25 units for total of 10764.28 euros
#
# Day 342:
# Went neutral. Long position closed - sold 208.25 units for 11102.88 euros.
#
# Day 361: purchase of 212.56 units for total of 11097.88 euros
#
# Day 369:
# Went neutral. Long position closed - sold 212.56 units for 10882.45 euros.
#
# Day 394: purchase of 209.42 units for total of 10877.45 euros
#
# Day 409:
# Went neutral. Long position closed - sold 209.42 units for 10625.33 euros.
#
# Day 461: purchase of 179.7 units for total of 10620.33 euros
#
# Day 466:
# Went neutral. Long position closed - sold 179.7 units for 10728.54 euros.
#
# Day 493: purchase of 174.31 units for total of 10723.54 euros
#
# Day 494:
# Went neutral. Long position closed - sold 174.31 units for 10840.55 euros.
#
# Day 529: purchase of 168.7 units for total of 10835.55 euros
#
# Day 535:
# Went neutral. Long position closed - sold 168.7 units for 11098.79 euros.
#
# Day 540: purchase of 175.92 units for total of 11093.79 euros
#
# Day 549:
# Went neutral. Long position closed - sold 175.92 units for 11034.25 euros.
#
# Day 562: purchase of 173.28 units for total of 11029.25 euros
#
# Day 569:
# Went neutral. Long position closed - sold 173.28 units for 11155.94 euros.
#
# Day 586: purchase of 173.85 units for total of 11150.94 euros
#
# Day 595:
# Went neutral. Long position closed - sold 173.85 units for 11128.56 euros.
#
# Day 600: purchase of 179.04 units for total of 11123.56 euros
#
# Day 611:
# Went neutral. Long position closed - sold 179.04 units for 10953.84 euros.
#
# Day 640: purchase of 177.57 units for total of 10948.84 euros
#
# Day 649:
# Went neutral. Long position closed - sold 177.57 units for 10604.69 euros.
#
# Day 653: purchase of 196.73 units for total of 10599.69 euros
#
# Day 658:
# Went neutral. Long position closed - sold 196.73 units for 11253.73 euros.
#
# Day 682: purchase of 198.18 units for total of 11248.73 euros
#
# Day 685:
# Went neutral. Long position closed - sold 198.18 units for 11501.36 euros.
#
# Day 716: purchase of 185.25 units for total of 11496.36 euros
#
# Day 724:
# Went neutral. Long position closed - sold 185.25 units for 11565.46 euros.
#
# Day 733: purchase of 186.46 units for total of 11560.46 euros
#
# Day 738:
# Went neutral. Long position closed - sold 186.46 units for 11561.05 euros.
#
# Day 789: purchase of 166.42 units for total of 11556.05 euros
#
# Day 791:
# Went neutral. Long position closed - sold 166.42 units for 11792.36 euros.
#
# Day 812: purchase of 160.61 units for total of 11787.36 euros
#
# Day 818:
# Went neutral. Long position closed - sold 160.61 units for 11788.78 euros.
#
# Day 822: purchase of 166.06 units for total of 11783.78 euros
#
# Day 824:
# Went neutral. Long position closed - sold 166.06 units for 12059.43 euros.
#
# Day 832: purchase of 171.47 units for total of 12054.43 euros
#
# Day 847:
# Went neutral. Long position closed - sold 171.47 units for 11624.18 euros.
#
# Day 850: purchase of 179.03 units for total of 11619.18 euros
#
# Day 853:
# Went neutral. Long position closed - sold 179.03 units for 12054.6 euros.
#
# Day 930: purchase of 164.16 units for total of 12049.6 euros
#
# Day 937:
# Went neutral. Long position closed - sold 164.16 units for 12103.7 euros.
#
# Day 939: purchase of 166.92 units for total of 12098.7 euros
#
# Day 945:
# Went neutral. Long position closed - sold 166.92 units for 12135.43 euros.
#
# Day 948: purchase of 174.41 units for total of 12130.43 euros
#
# Day 955:
# Went neutral. Long position closed - sold 174.41 units for 12193.45 euros.
#
# Day 960: purchase of 181.67 units for total of 12188.45 euros
#
# Day 967:
# Went neutral. Long position closed - sold 181.67 units for 12305.17 euros.
#
# Day 994: purchase of 181.61 units for total of 12300.17 euros
#
# Day 996:
# Went neutral. Long position closed - sold 181.61 units for 12932.61 euros.
#
# Day 1030: purchase of 183.58 units for total of 12927.61 euros
#
# Day 1036:
# Went neutral. Long position closed - sold 183.58 units for 13052.95 euros.
#
# Day 1058: purchase of 182.03 units for total of 13047.95 euros
#
# Day 1063:
# Went neutral. Long position closed - sold 182.03 units for 13301.43 euros.
#
# Day 1069: purchase of 191.67 units for total of 13296.43 euros
#
# Day 1073:
# Went neutral. Long position closed - sold 191.67 units for 13642.2 euros.
#
# Day 1102: purchase of 180.67 units for total of 13637.2 euros
#
# Day 1104:
# Went neutral. Long position closed - sold 180.67 units for 13802.03 euros.
#
# Day 1107: purchase of 183.84 units for total of 13797.03 euros
#
# Day 1110:
# Went neutral. Long position closed - sold 183.84 units for 14001.6 euros.
#
# Day 1114: purchase of 189.3 units for total of 13996.6 euros
#
# Day 1120:
# Went neutral. Long position closed - sold 189.3 units for 14107.07 euros.
#
# Day 1189: purchase of 178.33 units for total of 14102.07 euros
#
# Day 1191:
# Went neutral. Long position closed - sold 178.33 units for 14391.31 euros.
#
# Day 1264: purchase of 164.96 units for total of 14386.31 euros
#
# Day 1272:
# Went neutral. Long position closed - sold 164.96 units for 14351.62 euros.
#
# Day 1297: purchase of 159.09 units for total of 14346.62 euros
#
# Day 1299:
# Went neutral. Long position closed - sold 159.09 units for 14720.25 euros.
#
# Day 1313: purchase of 165.14 units for total of 14715.25 euros
#
# Day 1315:
# Went neutral. Long position closed - sold 165.14 units for 15080.16 euros.
#
# Day 1317: purchase of 171.76 units for total of 15075.16 euros
#
# Day 1320:
# Went neutral. Long position closed - sold 171.76 units for 15446.3 euros.
#
# Day 1394: purchase of 159.4 units for total of 15441.3 euros
#
# Day 1400:
# Went neutral. Long position closed - sold 159.4 units for 15551.07 euros.
#
# Day 1430: purchase of 154.78 units for total of 15546.07 euros
#
# Day 1441:
# Went neutral. Long position closed - sold 154.78 units for 15375.46 euros.
#
# Day 1443: purchase of 162.29 units for total of 15370.46 euros
#
# Day 1450:
# Went neutral. Long position closed - sold 162.29 units for 15717.63 euros.
#
# Day 1485: purchase of 150.75 units for total of 15712.63 euros
#
# Day 1491:
# Went neutral. Long position closed - sold 150.75 units for 15816.17 euros.
#
# Day 1500: purchase of 151.68 units for total of 15811.17 euros
#
# Day 1513:
# Went neutral. Long position closed - sold 151.68 units for 15833.47 euros.
#
# Day 1543: purchase of 146.9 units for total of 15828.47 euros
#
# Day 1551:
# Went neutral. Long position closed - sold 146.9 units for 15895.45 euros.
#
# Day 1585: purchase of 148.47 units for total of 15890.45 euros
#
# Day 1587:
# Went neutral. Long position closed - sold 148.47 units for 16225.44 euros.
#
# Day 1607: purchase of 149.36 units for total of 16220.44 euros
#
# Day 1610:
# Went neutral. Long position closed - sold 149.36 units for 16435.0 euros.
#
# Day 1621: purchase of 151.44 units for total of 16430.0 euros
#
# Day 1631:
# Went neutral. Long position closed - sold 151.44 units for 16282.64 euros.
#
# Day 1659: purchase of 155.95 units for total of 16277.64 euros
#
# Day 1665:
# Went neutral. Long position closed - sold 155.95 units for 16085.51 euros.
#
# Day 1682: purchase of 158.93 units for total of 16080.51 euros
#
# Day 1689:
# Went neutral. Long position closed - sold 158.93 units for 16137.49 euros.
#
# Day 1718: purchase of 147.03 units for total of 16132.49 euros
#
# Day 1722:
# Went neutral. Long position closed - sold 147.03 units for 16289.23 euros.
#
# Day 1738: purchase of 150.27 units for total of 16284.23 euros
#
# Day 1741:
# Went neutral. Long position closed - sold 150.27 units for 16659.4 euros.
#
# Day 1743: purchase of 155.58 units for total of 16654.4 euros
#
# Day 1746:
# Went neutral. Long position closed - sold 155.58 units for 17008.78 euros.
#
# Day 1752: purchase of 159.5 units for total of 17003.78 euros
#
# Day 1765:
# Went neutral. Long position closed - sold 159.5 units for 15992.37 euros.
#
# Day 1776: purchase of 168.95 units for total of 15987.37 euros
#
# Day 1781:
# Went neutral. Long position closed - sold 168.95 units for 16494.27 euros.
#
# Day 1829: purchase of 153.0 units for total of 16489.27 euros
#
# Day 1840:
# Went neutral. Long position closed - sold 153.0 units for 16175.2 euros.
#
# Day 1863: purchase of 149.54 units for total of 16170.2 euros
#
# Day 1871:
# Went neutral. Long position closed - sold 149.54 units for 16361.11 euros.
#
# Day 1873: purchase of 160.45 units for total of 16356.11 euros
#
# Day 1876:
# Went neutral. Long position closed - sold 160.45 units for 17177.41 euros.
#
# Day 1949: purchase of 144.77 units for total of 17172.41 euros
#
# Day 1953:
# Went neutral. Long position closed - sold 144.77 units for 17312.18 euros.
#
# Day 1962: purchase of 145.74 units for total of 17307.18 euros
#
# Day 1966:
# Went neutral. Long position closed - sold 145.74 units for 17379.43 euros.
#
# Day 1983: purchase of 147.96 units for total of 17374.43 euros
#
# Day 1987:
# Went neutral. Long position closed - sold 147.96 units for 17998.24 euros.
#
# Day 2003: purchase of 148.09 units for total of 17993.24 euros
#
# Day 2005:
# Went neutral. Long position closed - sold 148.09 units for 18240.0 euros.
#
# Day 2072: purchase of 135.99 units for total of 18235.0 euros
#
# Day 2077:
# Went neutral. Long position closed - sold 135.99 units for 18238.16 euros.
#
# Day 2114: purchase of 127.86 units for total of 18233.16 euros
#
# Day 2119:
# Went neutral. Long position closed - sold 127.86 units for 18458.31 euros.
#
# Day 2127: purchase of 130.85 units for total of 18453.31 euros
#
# Day 2133:
# Went neutral. Long position closed - sold 130.85 units for 18670.75 euros.
#
# Day 2148: purchase of 127.27 units for total of 18665.75 euros
#
# Day 2153:
# Went neutral. Long position closed - sold 127.27 units for 18874.56 euros.
#
# Day 2187: purchase of 126.69 units for total of 18869.56 euros
#
# Day 2190:
# Went neutral. Long position closed - sold 126.69 units for 19130.62 euros.
#
#
# End capital on day 2204: 19130.62 euros
# Total return: 91.31%
# Shares held at end of period: 0
# Total fee spending: 750
# Day 178: purchase of 205.91 units for total of 9995 euros
#
# Day 181:
# Went neutral. Long position closed - sold 205.91 units for 10237.1 euros.
#
# Day 196: purchase of 202.18 units for total of 10232.1 euros
#
# Day 203:
# Went neutral. Long position closed - sold 202.18 units for 10291.79 euros.
#
# Day 255: purchase of 196.61 units for total of 10286.79 euros
#
# Day 269:
# Went neutral. Long position closed - sold 196.61 units for 10136.3 euros.
#
# Day 325: purchase of 179.44 units for total of 10131.3 euros
#
# Day 331:
# Went neutral. Long position closed - sold 179.44 units for 10167.57 euros.
#
# Day 364: purchase of 202.52 units for total of 10162.57 euros
#
# Day 369:
# Went neutral. Long position closed - sold 202.52 units for 10368.19 euros.
#
# Day 394: purchase of 199.52 units for total of 10363.19 euros
#
# Day 409:
# Went neutral. Long position closed - sold 199.52 units for 10122.76 euros.
#
# Day 529: purchase of 157.52 units for total of 10117.76 euros
#
# Day 535:
# Went neutral. Long position closed - sold 157.52 units for 10363.22 euros.
#
# Day 540: purchase of 164.26 units for total of 10358.22 euros
#
# Day 549:
# Went neutral. Long position closed - sold 164.26 units for 10302.3 euros.
#
# Day 563: purchase of 163.37 units for total of 10297.3 euros
#
# Day 569:
# Went neutral. Long position closed - sold 163.37 units for 10517.75 euros.
#
# Day 586: purchase of 163.9 units for total of 10512.75 euros
#
# Day 595:
# Went neutral. Long position closed - sold 163.9 units for 10491.36 euros.
#
# Day 644: purchase of 189.15 units for total of 10486.36 euros
#
# Day 649:
# Went neutral. Long position closed - sold 189.15 units for 11296.59 euros.
#
# Day 683: purchase of 204.48 units for total of 11291.59 euros
#
# Day 685:
# Went neutral. Long position closed - sold 204.48 units for 11867.32 euros.
#
# Day 734: purchase of 194.69 units for total of 11862.32 euros
#
# Day 738:
# Went neutral. Long position closed - sold 194.69 units for 12071.48 euros.
#
# Day 789: purchase of 173.77 units for total of 12066.48 euros
#
# Day 791:
# Went neutral. Long position closed - sold 173.77 units for 12313.44 euros.
#
# Day 813: purchase of 170.29 units for total of 12308.44 euros
#
# Day 818:
# Went neutral. Long position closed - sold 170.29 units for 12499.27 euros.
#
# Day 840: purchase of 187.43 units for total of 12494.27 euros
#
# Day 847:
# Went neutral. Long position closed - sold 187.43 units for 12706.7 euros.
#
# Day 850: purchase of 195.71 units for total of 12701.7 euros
#
# Day 853:
# Went neutral. Long position closed - sold 195.71 units for 13178.15 euros.
#
# Day 931: purchase of 180.97 units for total of 13173.15 euros
#
# Day 937:
# Went neutral. Long position closed - sold 180.97 units for 13343.69 euros.
#
# Day 940: purchase of 186.4 units for total of 13338.69 euros
#
# Day 945:
# Went neutral. Long position closed - sold 186.4 units for 13551.78 euros.
#
# Day 948: purchase of 194.78 units for total of 13546.78 euros
#
# Day 955:
# Went neutral. Long position closed - sold 194.78 units for 13617.74 euros.
#
# Day 960: purchase of 202.9 units for total of 13612.74 euros
#
# Day 967:
# Went neutral. Long position closed - sold 202.9 units for 13743.69 euros.
#
# Day 1030: purchase of 195.1 units for total of 13738.69 euros
#
# Day 1036:
# Went neutral. Long position closed - sold 195.1 units for 13872.21 euros.
#
# Day 1060: purchase of 195.45 units for total of 13867.21 euros
#
# Day 1063:
# Went neutral. Long position closed - sold 195.45 units for 14282.42 euros.
#
# ...
# Day 1659: purchase of 135.02 units for total of 14093.74 euros
#
# Day 1694:
# Went neutral. Long position closed - sold 135.02 units for 14233.21 euros.
#
# Day 1755: purchase of 140.47 units for total of 14228.21 euros
#
# Day 1794:
# Went neutral. Long position closed - sold 140.47 units for 14692.38 euros.
#
# Day 1873: purchase of 144.08 units for total of 14687.38 euros
#
# Day 1881:
# Went neutral. Long position closed - sold 144.08 units for 15721.19 euros.
#
#
# End capital on day 2204: 15721.19 euros
# Total return: 57.21%
# Shares held at end of period: 0
# Total fee spending: 120
# Day 364: purchase of 199.18 units for total of 9995 euros
#
# Day 382:
# Went neutral. Long position closed - sold 199.18 units for 10818.6 euros.
#
# Day 602: purchase of 176.12 units for total of 10813.6 euros
#
# Day 618:
# Went neutral. Long position closed - sold 176.12 units for 11152.03 euros.
#
# Day 642: purchase of 187.12 units for total of 11147.03 euros
#
# Day 688:
# Went neutral. Long position closed - sold 187.12 units for 11351.61 euros.
#
# Day 840: purchase of 170.22 units for total of 11346.61 euros
#
# Day 883:
# Went neutral. Long position closed - sold 170.22 units for 11787.58 euros.
#
# Day 960: purchase of 175.62 units for total of 11782.58 euros
#
# Day 996:
# Went neutral. Long position closed - sold 175.62 units for 12506.41 euros.
#
# Day 1069: purchase of 180.21 units for total of 12501.41 euros
#
# Day 1076:
# Went neutral. Long position closed - sold 180.21 units for 13055.08 euros.
#
# Day 1443: purchase of 137.79 units for total of 13050.08 euros
#
# Day 1455:
# Went neutral. Long position closed - sold 137.79 units for 13780.87 euros.
#
# Day 1628: purchase of 131.61 units for total of 13775.87 euros
#
# Day 1634:
# Went neutral. Long position closed - sold 131.61 units for 14385.5 euros.
#
# Day 1659: purchase of 137.77 units for total of 14380.5 euros
#
# Day 1694:
# Went neutral. Long position closed - sold 137.77 units for 14522.92 euros.
#
# Day 1759: purchase of 146.35 units for total of 14517.92 euros
#
# Day 1794:
# Went neutral. Long position closed - sold 146.35 units for 15307.6 euros.
#
# Day 1873: purchase of 150.11 units for total of 15302.6 euros
#
# Day 1881:
# Went neutral. Long position closed - sold 150.11 units for 16379.92 euros.
#
#
# End capital on day 2204: 16379.92 euros
# Total return: 63.8%
# Shares held at end of period: 0
# Total fee spending: 110
# Day 644: purchase of 180.28 units for total of 9995 euros
#
# Day 688:
# Went neutral. Long position closed - sold 180.28 units for 10936.5 euros.
#
# Day 841: purchase of 166.26 units for total of 10931.5 euros
#
# Day 883:
# Went neutral. Long position closed - sold 166.26 units for 11513.39 euros.
#
# Day 1444: purchase of 123.03 units for total of 11508.39 euros
#
# Day 1455:
# Went neutral. Long position closed - sold 123.03 units for 12304.33 euros.
#
# Day 1659: purchase of 117.83 units for total of 12299.33 euros
#
# Day 1694:
# Went neutral. Long position closed - sold 117.83 units for 12420.41 euros.
#
# Day 1761: purchase of 126.56 units for total of 12415.41 euros
#
# Day 1794:
# Went neutral. Long position closed - sold 126.56 units for 13236.83 euros.
#
# Day 1873: purchase of 129.8 units for total of 13231.83 euros
#
# Day 1881:
# Went neutral. Long position closed - sold 129.8 units for 14162.69 euros.
#
#
# End capital on day 2204: 14162.69 euros
# Total return: 41.63%
# Shares held at end of period: 0
# Total fee spending: 60
# Day 644: purchase of 180.28 units for total of 9995 euros
#
# Day 688:
# Went neutral. Long position closed - sold 180.28 units for 10936.5 euros.
#
# Day 1660: purchase of 108.81 units for total of 10931.5 euros
#
# Day 1694:
# Went neutral. Long position closed - sold 108.81 units for 11469.48 euros.
#
#
# End capital on day 2204: 11469.48 euros
# Total return: 14.69%
# Shares held at end of period: 0
# Total fee spending: 20
# Day 644: purchase of 180.28 units for total of 9995 euros
#
# Day 688:
# Went neutral. Long position closed - sold 180.28 units for 10936.5 euros.
#
# Day 1660: purchase of 108.81 units for total of 10931.5 euros
#
# Day 1694:
# Went neutral. Long position closed - sold 108.81 units for 11469.48 euros.
#
#
# End capital on day 2204: 11469.48 euros
# Total return: 14.69%
# Shares held at end of period: 0
# Total fee spending: 20
# Day 1660: purchase of 99.49 units for total of 9995 euros
#
# Day 1694:
# Went neutral. Long position closed - sold 99.49 units for 10486.47 euros.
#
#
# End capital on day 2204: 10486.47 euros
# Total return: 4.86%
# Shares held at end of period: 0
# Total fee spending: 10
# Day 260: purchase of 198.39 units for total of 9995 euros
#
# Day 273:
# Went neutral. Long position closed - sold 198.39 units for 10537.56 euros.
#
# Day 328: purchase of 198.92 units for total of 10532.56 euros
#
# Day 329:
# Went neutral. Long position closed - sold 198.92 units for 11038.77 euros.
#
# Day 336: purchase of 205.7 units for total of 11033.77 euros
#
# Day 382:
# Went neutral. Long position closed - sold 205.7 units for 11172.77 euros.
#
# Day 394: purchase of 215.01 units for total of 11167.77 euros
#
# Day 416:
# Went neutral. Long position closed - sold 215.01 units for 11399.28 euros.
#
# Day 544: purchase of 187.78 units for total of 11394.28 euros
#
# Day 550:
# Went neutral. Long position closed - sold 187.78 units for 11965.75 euros.
#
# Day 563: purchase of 189.76 units for total of 11960.75 euros
#
# Day 569:
# Went neutral. Long position closed - sold 189.76 units for 12217.63 euros.
#
# Day 591: purchase of 193.18 units for total of 12212.63 euros
#
# Day 596:
# Went neutral. Long position closed - sold 193.18 units for 12549.55 euros.
#
# Day 598: purchase of 197.24 units for total of 12544.55 euros
#
# Day 618:
# Went neutral. Long position closed - sold 197.24 units for 12490.24 euros.
#
# Day 640: purchase of 202.49 units for total of 12485.24 euros
#
# Day 688:
# Went neutral. Long position closed - sold 202.49 units for 12283.83 euros.
#
# Day 721: purchase of 210.29 units for total of 12278.83 euros
#
# Day 722:
# Went neutral. Long position closed - sold 210.29 units for 12694.41 euros.
#
# Day 835: purchase of 182.82 units for total of 12689.41 euros
#
# Day 889:
# Went neutral. Long position closed - sold 182.82 units for 12618.59 euros.
#
# Day 948: purchase of 181.36 units for total of 12613.59 euros
#
# Day 996:
# Went neutral. Long position closed - sold 181.36 units for 12915.09 euros.
#
# Day 1069: purchase of 186.1 units for total of 12910.09 euros
#
# Day 1074:
# Went neutral. Long position closed - sold 186.1 units for 13294.05 euros.
#
# Day 1317: purchase of 151.41 units for total of 13289.05 euros
#
# Day 1320:
# Went neutral. Long position closed - sold 151.41 units for 13615.63 euros.
#
# Day 1443: purchase of 143.71 units for total of 13610.63 euros
#
# Day 1455:
# Went neutral. Long position closed - sold 143.71 units for 14373.04 euros.
#
# Day 1622: purchase of 135.52 units for total of 14368.04 euros
#
# Day 1634:
# Went neutral. Long position closed - sold 135.52 units for 14812.97 euros.
#
# Day 1641: purchase of 138.13 units for total of 14807.97 euros
#
# Day 1643:
# Went neutral. Long position closed - sold 138.13 units for 15032.27 euros.
#
# Day 1646: purchase of 139.15 units for total of 15027.27 euros
#
# Day 1651:
# Went neutral. Long position closed - sold 139.15 units for 15158.64 euros.
#
# Day 1653: purchase of 140.69 units for total of 15153.64 euros
#
# Day 1694:
# Went neutral. Long position closed - sold 140.69 units for 14830.69 euros.
#
# Day 1754: purchase of 141.66 units for total of 14825.69 euros
#
# Day 1799:
# Went neutral. Long position closed - sold 141.66 units for 14949.59 euros.
#
# Day 1873: purchase of 146.6 units for total of 14944.59 euros
#
# Day 1881:
# Went neutral. Long position closed - sold 146.6 units for 15996.59 euros.
#
# Day 1965: purchase of 137.15 units for total of 15991.59 euros
#
# Day 1966:
# Went neutral. Long position closed - sold 137.15 units for 16354.15 euros.
#
# Day 1984: purchase of 138.7 units for total of 16349.15 euros
#
# Day 1985:
# Went neutral. Long position closed - sold 138.7 units for 16527.24 euros.
#
#
# End capital on day 2204: 16527.24 euros
# Total return: 65.27%
# Shares held at end of period: 0
# Total fee spending: 230
# Day 260: purchase of 198.39 units for total of 9995 euros
#
# Day 273:
# Went neutral. Long position closed - sold 198.39 units for 10537.56 euros.
#
# Day 337: purchase of 203.76 units for total of 10532.56 euros
#
# Day 382:
# Went neutral. Long position closed - sold 203.76 units for 11067.54 euros.
#
# Day 395: purchase of 216.62 units for total of 11062.54 euros
#
# Day 416:
# Went neutral. Long position closed - sold 216.62 units for 11484.27 euros.
#
# Day 544: purchase of 189.18 units for total of 11479.27 euros
#
# Day 550:
# Went neutral. Long position closed - sold 189.18 units for 12055.04 euros.
#
# Day 592: purchase of 191.61 units for total of 12050.04 euros
#
# Day 596:
# Went neutral. Long position closed - sold 191.61 units for 12447.41 euros.
#
# Day 599: purchase of 198.57 units for total of 12442.41 euros
#
# Day 618:
# Went neutral. Long position closed - sold 198.57 units for 12574.43 euros.
#
# Day 640: purchase of 203.85 units for total of 12569.43 euros
#
# Day 688:
# Went neutral. Long position closed - sold 203.85 units for 12366.69 euros.
#
# Day 838: purchase of 180.52 units for total of 12361.69 euros
#
# Day 889:
# Went neutral. Long position closed - sold 180.52 units for 12459.59 euros.
#
# Day 954: purchase of 181.47 units for total of 12454.59 euros
#
# Day 996:
# Went neutral. Long position closed - sold 181.47 units for 12923.23 euros.
#
# Day 1069: purchase of 186.22 units for total of 12918.23 euros
#
# Day 1074:
# Went neutral. Long position closed - sold 186.22 units for 13302.44 euros.
#
# Day 1317: purchase of 151.5 units for total of 13297.44 euros
#
# Day 1320:
# Went neutral. Long position closed - sold 151.5 units for 13624.23 euros.
#
# Day 1443: purchase of 143.8 units for total of 13619.23 euros
#
# Day 1455:
# Went neutral. Long position closed - sold 143.8 units for 14382.12 euros.
#
# Day 1622: purchase of 135.61 units for total of 14377.12 euros
#
# Day 1634:
# Went neutral. Long position closed - sold 135.61 units for 14822.34 euros.
#
# Day 1649: purchase of 138.17 units for total of 14817.34 euros
#
# Day 1651:
# Went neutral. Long position closed - sold 138.17 units for 15051.37 euros.
#
# Day 1658: purchase of 140.44 units for total of 15046.37 euros
#
# Day 1694:
# Went neutral. Long position closed - sold 140.44 units for 14804.03 euros.
#
# Day 1755: purchase of 146.11 units for total of 14799.03 euros
#
# Day 1799:
# Went neutral. Long position closed - sold 146.11 units for 15419.36 euros.
#
# Day 1873: purchase of 151.21 units for total of 15414.36 euros
#
# Day 1881:
# Went neutral. Long position closed - sold 151.21 units for 16499.59 euros.
#
#
# End capital on day 2204: 16499.59 euros
# Total return: 65.0%
# Shares held at end of period: 0
# Total fee spending: 170
# Day 348: purchase of 195.87 units for total of 9995 euros
#
# Day 382:
# Went neutral. Long position closed - sold 195.87 units for 10638.31 euros.
#
# Day 403: purchase of 213.43 units for total of 10633.31 euros
#
# Day 416:
# Went neutral. Long position closed - sold 213.43 units for 11315.57 euros.
#
# Day 600: purchase of 182.05 units for total of 11310.57 euros
#
# Day 618:
# Went neutral. Long position closed - sold 182.05 units for 11527.67 euros.
#
# Day 642: purchase of 193.43 units for total of 11522.67 euros
#
# Day 688:
# Went neutral. Long position closed - sold 193.43 units for 11734.31 euros.
#
# Day 840: purchase of 175.96 units for total of 11729.31 euros
#
# Day 889:
# Went neutral. Long position closed - sold 175.96 units for 12144.85 euros.
#
# Day 960: purchase of 180.95 units for total of 12139.85 euros
#
# Day 996:
# Went neutral. Long position closed - sold 180.95 units for 12885.79 euros.
#
# Day 1069: purchase of 185.68 units for total of 12880.79 euros
#
# Day 1074:
# Went neutral. Long position closed - sold 185.68 units for 13263.86 euros.
#
# Day 1443: purchase of 139.99 units for total of 13258.86 euros
#
# Day 1455:
# Went neutral. Long position closed - sold 139.99 units for 14001.43 euros.
#
# Day 1622: purchase of 132.02 units for total of 13996.43 euros
#
# Day 1634:
# Went neutral. Long position closed - sold 132.02 units for 14429.73 euros.
#
# Day 1659: purchase of 138.19 units for total of 14424.73 euros
#
# Day 1694:
# Went neutral. Long position closed - sold 138.19 units for 14567.6 euros.
#
# Day 1755: purchase of 143.77 units for total of 14562.6 euros
#
# Day 1799:
# Went neutral. Long position closed - sold 143.77 units for 15172.94 euros.
#
# Day 1873: purchase of 148.79 units for total of 15167.94 euros
#
# Day 1881:
# Went neutral. Long position closed - sold 148.79 units for 16235.74 euros.
#
#
# End capital on day 2204: 16235.74 euros
# Total return: 62.36%
# Shares held at end of period: 0
# Total fee spending: 120
# Day 364: purchase of 199.18 units for total of 9995 euros
#
# Day 382:
# Went neutral. Long position closed - sold 199.18 units for 10818.6 euros.
#
# Day 602: purchase of 176.12 units for total of 10813.6 euros
#
# Day 618:
# Went neutral. Long position closed - sold 176.12 units for 11152.03 euros.
#
# Day 642: purchase of 187.12 units for total of 11147.03 euros
#
# Day 688:
# Went neutral. Long position closed - sold 187.12 units for 11351.61 euros.
#
# Day 841: purchase of 172.57 units for total of 11346.61 euros
#
# Day 889:
# Went neutral. Long position closed - sold 172.57 units for 11911.1 euros.
#
# Day 964: purchase of 180.18 units for total of 11906.1 euros
#
# Day 996:
# Went neutral. Long position closed - sold 180.18 units for 12830.81 euros.
#
# Day 1443: purchase of 135.42 units for total of 12825.81 euros
#
# Day 1455:
# Went neutral. Long position closed - sold 135.42 units for 13543.96 euros.
#
# Day 1628: purchase of 129.35 units for total of 13538.96 euros
#
# Day 1634:
# Went neutral. Long position closed - sold 129.35 units for 14138.02 euros.
#
# Day 1659: purchase of 135.4 units for total of 14133.02 euros
#
# Day 1694:
# Went neutral. Long position closed - sold 135.4 units for 14272.9 euros.
#
# Day 1759: purchase of 143.83 units for total of 14267.9 euros
#
# Day 1799:
# Went neutral. Long position closed - sold 143.83 units for 15179.1 euros.
#
# Day 1873: purchase of 148.85 units for total of 15174.1 euros
#
# Day 1881:
# Went neutral. Long position closed - sold 148.85 units for 16242.33 euros.
#
#
# End capital on day 2204: 16242.33 euros
# Total return: 62.42%
# Shares held at end of period: 0
# Total fee spending: 100
# Day 608: purchase of 166.86 units for total of 9995 euros
#
# Day 618:
# Went neutral. Long position closed - sold 166.86 units for 10565.67 euros.
#
# Day 644: purchase of 190.49 units for total of 10560.67 euros
#
# Day 688:
# Went neutral. Long position closed - sold 190.49 units for 11555.74 euros.
#
# Day 850: purchase of 177.98 units for total of 11550.74 euros
#
# Day 889:
# Went neutral. Long position closed - sold 177.98 units for 12284.34 euros.
#
# Day 1444: purchase of 131.27 units for total of 12279.34 euros
#
# Day 1455:
# Went neutral. Long position closed - sold 131.27 units for 13128.93 euros.
#
# Day 1659: purchase of 125.73 units for total of 13123.93 euros
#
# Day 1694:
# Went neutral. Long position closed - sold 125.73 units for 13253.47 euros.
#
#
# End capital on day 2204: 13253.47 euros
# Total return: 32.53%
# Shares held at end of period: 0
# Total fee spending: 50
# Day 644: purchase of 180.28 units for total of 9995 euros
#
# Day 688:
# Went neutral. Long position closed - sold 180.28 units for 10936.5 euros.
#
# Day 1660: purchase of 108.81 units for total of 10931.5 euros
#
# Day 1694:
# Went neutral. Long position closed - sold 108.81 units for 11469.48 euros.
#
#
# End capital on day 2204: 11469.48 euros
# Total return: 14.69%
# Shares held at end of period: 0
# Total fee spending: 20
# Day 644: purchase of 180.28 units for total of 9995 euros
#
# Day 688:
# Went neutral. Long position closed - sold 180.28 units for 10936.5 euros.
#
# Day 1660: purchase of 108.81 units for total of 10931.5 euros
#
# Day 1694:
# Went neutral. Long position closed - sold 108.81 units for 11469.48 euros.
#
#
# End capital on day 2204: 11469.48 euros
# Total return: 14.69%
# Shares held at end of period: 0
# Total fee spending: 20
# Day 1660: purchase of 99.49 units for total of 9995 euros
#
# Day 1694:
# Went neutral. Long position closed - sold 99.49 units for 10486.47 euros.
#
#
# End capital on day 2204: 10486.47 euros
# Total return: 4.86%
# Shares held at end of period: 0
# Total fee spending: 10

# %%
best_total_final_capital
# Out:
# 24359.86426904214

# %%
best_total_return
# Out:
# 1.435986426904214

# %%
best_vals
# Out:
# {'best_sma': 10, 'best_std': 1}

# %%
results["Mean-Reversion Strategy"]["VGT train"] = str(round(best_total_return*100, 2))+"%"
results["MR Parameter"]["VGT train"] = str("SMA: " + str(best_vals["best_sma"]) +", STD: " +str(best_vals["best_std"]))
results["MR Parameter"]["VGT test"] = str("SMA: " + str(best_vals["best_sma"]) +", STD: " +str(best_vals["best_std"]))

# %%
return_test, _ = mean_rev_evaluation(sma=best_vals["best_sma"], std_dev=best_vals["best_std"], data=vgt_test)
# Out:
# Day 10: purchase of 61.23 units for total of 9995 euros
#
# Day 11:
# Went neutral. Long position closed - sold 61.23 units for 10127.77 euros.
#
# Day 21: purchase of 61.69 units for total of 10122.77 euros
#
# Day 26:
# Went neutral. Long position closed - sold 61.69 units for 10117.77 euros.
#
# Day 40: purchase of 61.39 units for total of 10112.77 euros
#
# Day 41:
# Went neutral. Long position closed - sold 61.39 units for 10245.9 euros.
#
# Day 63: purchase of 59.52 units for total of 10240.9 euros
#
# Day 71:
# Went neutral. Long position closed - sold 59.52 units for 10201.38 euros.
#
# Day 94: purchase of 57.02 units for total of 10196.38 euros
#
# Day 105:
# Went neutral. Long position closed - sold 57.02 units for 9765.41 euros.
#
# Day 118: purchase of 57.68 units for total of 9760.41 euros
#
# Day 123:
# Went neutral. Long position closed - sold 57.68 units for 9975.18 euros.
#
# Day 159: purchase of 53.36 units for total of 9970.18 euros
#
# Day 168:
# Went neutral. Long position closed - sold 53.36 units for 9793.38 euros.
#
# Day 185: purchase of 52.74 units for total of 9788.38 euros
#
# Day 188:
# Went neutral. Long position closed - sold 52.74 units for 10069.22 euros.
#
# Day 213: purchase of 50.77 units for total of 10064.22 euros
#
# Day 217:
# Went neutral. Long position closed - sold 50.77 units for 10257.71 euros.
#
# Day 233: purchase of 51.95 units for total of 10252.71 euros
#
# Day 251:
# Went neutral. Long position closed - sold 51.95 units for 9626.37 euros.
#
# Day 260: purchase of 53.3 units for total of 9621.37 euros
#
# Day 270:
# Went neutral. Long position closed - sold 53.3 units for 9712.31 euros.
#
# Day 281: purchase of 56.15 units for total of 9707.31 euros
#
# Day 290:
# Went neutral. Long position closed - sold 56.15 units for 9269.92 euros.
#
# Day 335: purchase of 48.36 units for total of 9264.92 euros
#
# Day 338:
# Went neutral. Long position closed - sold 48.36 units for 9382.27 euros.
#
# Day 378: purchase of 45.14 units for total of 9377.27 euros
#
# Day 398:
# Went neutral. Long position closed - sold 45.14 units for 9014.32 euros.
#
# Day 438: purchase of 41.47 units for total of 9009.32 euros
#
# Day 446:
# Went neutral. Long position closed - sold 41.47 units for 8860.83 euros.
#
# Day 475: purchase of 41.3 units for total of 8855.83 euros
#
# Day 483:
# Went neutral. Long position closed - sold 41.3 units for 8911.95 euros.
#
# Day 496: purchase of 41.29 units for total of 8906.95 euros
#
# Day 497:
# Went neutral. Long position closed - sold 41.29 units for 9038.2 euros.
#
# Day 524: purchase of 39.11 units for total of 9033.2 euros
#
# Day 527:
# Went neutral. Long position closed - sold 39.11 units for 9183.48 euros.
#
#
# End capital on day 544: 9183.48 euros
# Total return: -8.17%
# Shares held at end of period: 0
# Total fee spending: 180

# %%
results["Mean-Reversion Strategy"]["VGT test"] = str(round(return_test*100, 2))+"%"

# %% [markdown]
# ## XSD

# %%
best_total_return = 0 
best_total_final_capital = 0
for i in range(len(permut_grid)):
    sma, std_dev = permut_grid[i].values()
    total_return, total_final_capital = mean_rev_evaluation(sma=sma, std_dev=std_dev, data=xsd_train)
    if total_return > best_total_return: 
        best_total_final_capital = total_final_capital
        best_total_return= total_return
        best_vals = {"best_sma": sma, "best_std": std_dev}
# Out:
# Day 21: purchase of 819.26 units for total of 9995 euros
#
# Day 26:
# Went neutral. Long position closed - sold 819.26 units for 9916.27 euros.
#
# Day 34: purchase of 863.35 units for total of 9911.27 euros
#
# Day 35:
# Went neutral. Long position closed - sold 863.35 units for 10752.35 euros.
#
# Day 50: purchase of 785.63 units for total of 10747.35 euros
#
# Day 51:
# Went neutral. Long position closed - sold 785.63 units for 11033.03 euros.
#
# Day 64: purchase of 747.16 units for total of 11028.03 euros
#
# Day 65:
# Went neutral. Long position closed - sold 747.16 units for 11284.54 euros.
#
# Day 77: purchase of 747.48 units for total of 11279.54 euros
#
# Day 84:
# Went neutral. Long position closed - sold 747.48 units for 11648.28 euros.
#
# Day 105: purchase of 687.32 units for total of 11643.28 euros
#
# Day 110:
# Went neutral. Long position closed - sold 687.32 units for 11679.52 euros.
#
# Day 117: purchase of 721.54 units for total of 11674.52 euros
#
# Day 121:
# Went neutral. Long position closed - sold 721.54 units for 12160.16 euros.
#
# Day 140: purchase of 641.43 units for total of 12155.16 euros
#
# Day 144:
# Went neutral. Long position closed - sold 641.43 units for 12470.88 euros.
#
# Day 158: purchase of 641.91 units for total of 12465.88 euros
#
# Day 159:
# Went neutral. Long position closed - sold 641.91 units for 12698.39 euros.
#
# Day 169: purchase of 612.32 units for total of 12693.39 euros
#
# Day 175:
# Went neutral. Long position closed - sold 612.32 units for 12755.74 euros.
#
# Day 178: purchase of 649.55 units for total of 12750.74 euros
#
# Day 184:
# Went neutral. Long position closed - sold 649.55 units for 13408.29 euros.
#
# Day 193: purchase of 653.82 units for total of 13403.29 euros
#
# Day 203:
# Went neutral. Long position closed - sold 653.82 units for 12652.93 euros.
#
# Day 214: purchase of 626.76 units for total of 12647.93 euros
#
# Day 216:
# Went neutral. Long position closed - sold 626.76 units for 12918.71 euros.
#
# Day 249: purchase of 550.93 units for total of 12913.71 euros
#
# Day 263:
# Went neutral. Long position closed - sold 550.93 units for 12231.07 euros.
#
# Day 265: purchase of 568.65 units for total of 12226.07 euros
#
# Day 268:
# Went neutral. Long position closed - sold 568.65 units for 12391.66 euros.
#
# Day 299: purchase of 517.84 units for total of 12386.66 euros
#
# Day 304:
# Went neutral. Long position closed - sold 517.84 units for 12780.4 euros.
#
# Day 321: purchase of 505.96 units for total of 12775.4 euros
#
# Day 331:
# Went neutral. Long position closed - sold 505.96 units for 12309.98 euros.
#
# Day 333: purchase of 532.45 units for total of 12304.98 euros
#
# Day 342:
# Went neutral. Long position closed - sold 532.45 units for 12353.22 euros.
#
# Day 348: purchase of 576.21 units for total of 12348.22 euros
#
# Day 353:
# Went neutral. Long position closed - sold 576.21 units for 12740.81 euros.
#
# Day 361: purchase of 577.59 units for total of 12735.81 euros
#
# Day 369:
# Went neutral. Long position closed - sold 577.59 units for 12626.84 euros.
#
# Day 385: purchase of 573.72 units for total of 12621.84 euros
#
# Day 392:
# Went neutral. Long position closed - sold 573.72 units for 12863.54 euros.
#
# Day 394: purchase of 609.7 units for total of 12858.54 euros
#
# Day 406:
# Went neutral. Long position closed - sold 609.7 units for 12719.41 euros.
#
# Day 408: purchase of 636.36 units for total of 12714.41 euros
#
# Day 410:
# Went neutral. Long position closed - sold 636.36 units for 13333.04 euros.
#
# Day 434: purchase of 596.6 units for total of 13328.04 euros
#
# Day 435:
# Went neutral. Long position closed - sold 596.6 units for 13472.19 euros.
#
# Day 443: purchase of 595.37 units for total of 13467.19 euros
#
# Day 445:
# Went neutral. Long position closed - sold 595.37 units for 13700.34 euros.
#
# Day 461: purchase of 549.35 units for total of 13695.34 euros
#
# Day 465:
# Went neutral. Long position closed - sold 549.35 units for 13992.48 euros.
#
# Day 482: purchase of 519.4 units for total of 13987.48 euros
#
# Day 489:
# Went neutral. Long position closed - sold 519.4 units for 14169.46 euros.
#
# Day 507: purchase of 486.58 units for total of 14164.46 euros
#
# Day 508:
# Went neutral. Long position closed - sold 486.58 units for 14514.67 euros.
#
# Day 510: purchase of 491.85 units for total of 14509.67 euros
#
# Day 511:
# Went neutral. Long position closed - sold 491.85 units for 14794.86 euros.
#
# Day 529: purchase of 496.3 units for total of 14789.86 euros
#
# Day 535:
# Went neutral. Long position closed - sold 496.3 units for 15211.69 euros.
#
# Day 537: purchase of 514.61 units for total of 15206.69 euros
#
# Day 547:
# Went neutral. Long position closed - sold 514.61 units for 14553.28 euros.
#
# Day 563: purchase of 514.07 units for total of 14548.28 euros
#
# Day 569:
# Went neutral. Long position closed - sold 514.07 units for 15124.18 euros.
#
# Day 578: purchase of 507.18 units for total of 15119.18 euros
#
# Day 580:
# Went neutral. Long position closed - sold 507.18 units for 15337.34 euros.
#
# Day 586: purchase of 519.04 units for total of 15332.34 euros
#
# Day 595:
# Went neutral. Long position closed - sold 519.04 units for 15296.2 euros.
#
# Day 598: purchase of 528.56 units for total of 15291.2 euros
#
# Day 613:
# Went neutral. Long position closed - sold 528.56 units for 14361.22 euros.
#
# Day 625: purchase of 536.28 units for total of 14356.22 euros
#
# Day 633:
# Went neutral. Long position closed - sold 536.28 units for 14903.59 euros.
#
# Day 637: purchase of 569.74 units for total of 14898.59 euros
#
# Day 649:
# Went neutral. Long position closed - sold 569.74 units for 13474.95 euros.
#
# Day 653: purchase of 640.82 units for total of 13469.95 euros
#
# Day 655:
# Went neutral. Long position closed - sold 640.82 units for 14349.28 euros.
#
# Day 664: purchase of 661.03 units for total of 14344.28 euros
#
# Day 665:
# Went neutral. Long position closed - sold 661.03 units for 14927.59 euros.
#
# Day 667: purchase of 677.07 units for total of 14922.59 euros
#
# Day 668:
# Went neutral. Long position closed - sold 677.07 units for 15472.79 euros.
#
# Day 676: purchase of 693.93 units for total of 15467.79 euros
#
# Day 685:
# Went neutral. Long position closed - sold 693.93 units for 15303.18 euros.
#
# Day 696: purchase of 665.72 units for total of 15298.18 euros
#
# Day 697:
# Went neutral. Long position closed - sold 665.72 units for 15626.04 euros.
#
# Day 705: purchase of 656.07 units for total of 15621.04 euros
#
# Day 706:
# Went neutral. Long position closed - sold 656.07 units for 16193.38 euros.
#
# Day 711: purchase of 683.63 units for total of 16188.38 euros
#
# Day 712:
# Went neutral. Long position closed - sold 683.63 units for 16723.45 euros.
#
# Day 716: purchase of 726.89 units for total of 16718.45 euros
#
# Day 724:
# Went neutral. Long position closed - sold 726.89 units for 16582.61 euros.
#
# Day 733: purchase of 771.41 units for total of 16577.61 euros
#
# Day 740:
# Went neutral. Long position closed - sold 771.41 units for 17259.17 euros.
#
# Day 786: purchase of 663.37 units for total of 17254.17 euros
#
# Day 794:
# Went neutral. Long position closed - sold 663.37 units for 17076.69 euros.
#
# Day 808: purchase of 652.34 units for total of 17071.69 euros
#
# Day 818:
# Went neutral. Long position closed - sold 652.34 units for 16394.78 euros.
#
# Day 821: purchase of 685.48 units for total of 16389.78 euros
#
# Day 826:
# Went neutral. Long position closed - sold 685.48 units for 16672.68 euros.
#
# Day 831: purchase of 720.92 units for total of 16667.68 euros
#
# Day 847:
# Went neutral. Long position closed - sold 720.92 units for 16028.27 euros.
#
# Day 850: purchase of 771.46 units for total of 16023.27 euros
#
# Day 853:
# Went neutral. Long position closed - sold 771.46 units for 17036.6 euros.
#
# Day 867: purchase of 802.62 units for total of 17031.6 euros
#
# Day 870:
# Went neutral. Long position closed - sold 802.62 units for 17885.41 euros.
#
# Day 875: purchase of 828.95 units for total of 17880.41 euros
#
# Day 883:
# Went neutral. Long position closed - sold 828.95 units for 17833.96 euros.
#
# Day 885: purchase of 864.64 units for total of 17828.96 euros
#
# Day 888:
# Went neutral. Long position closed - sold 864.64 units for 18290.87 euros.
#
# Day 908: purchase of 796.77 units for total of 18285.87 euros
#
# Day 917:
# Went neutral. Long position closed - sold 796.77 units for 18623.48 euros.
#
# Day 928: purchase of 810.91 units for total of 18618.48 euros
#
# Day 945:
# Went neutral. Long position closed - sold 810.91 units for 17267.37 euros.
#
# Day 949: purchase of 844.95 units for total of 17262.37 euros
#
# Day 954:
# Went neutral. Long position closed - sold 844.95 units for 17544.65 euros.
#
# Day 960: purchase of 848.97 units for total of 17539.65 euros
#
# Day 969:
# Went neutral. Long position closed - sold 848.97 units for 17364.86 euros.
#
# Day 991: purchase of 775.69 units for total of 17359.86 euros
#
# Day 995:
# Went neutral. Long position closed - sold 775.69 units for 17478.97 euros.
#
# Day 1030: purchase of 728.08 units for total of 17473.97 euros
#
# Day 1038:
# Went neutral. Long position closed - sold 728.08 units for 17534.5 euros.
#
# Day 1051: purchase of 713.45 units for total of 17529.5 euros
#
# Day 1053:
# Went neutral. Long position closed - sold 713.45 units for 17681.46 euros.
#
# Day 1057: purchase of 738.06 units for total of 17676.46 euros
#
# Day 1062:
# Went neutral. Long position closed - sold 738.06 units for 18010.96 euros.
#
# Day 1069: purchase of 781.17 units for total of 18005.96 euros
#
# Day 1073:
# Went neutral. Long position closed - sold 781.17 units for 18774.32 euros.
#
# Day 1094: purchase of 710.69 units for total of 18769.32 euros
#
# Day 1098:
# Went neutral. Long position closed - sold 710.69 units for 19375.51 euros.
#
# Day 1107: purchase of 747.32 units for total of 19370.51 euros
#
# Day 1110:
# Went neutral. Long position closed - sold 747.32 units for 20000.73 euros.
#
# Day 1114: purchase of 762.32 units for total of 19995.73 euros
#
# Day 1118:
# Went neutral. Long position closed - sold 762.32 units for 20265.17 euros.
#
# Day 1138: purchase of 726.17 units for total of 20260.17 euros
#
# Day 1141:
# Went neutral. Long position closed - sold 726.17 units for 20625.52 euros.
#
# Day 1146: purchase of 743.08 units for total of 20620.52 euros
#
# Day 1150:
# Went neutral. Long position closed - sold 743.08 units for 20905.32 euros.
#
# Day 1152: purchase of 767.83 units for total of 20900.32 euros
#
# Day 1158:
# Went neutral. Long position closed - sold 767.83 units for 21148.7 euros.
#
# Day 1181: purchase of 737.23 units for total of 21143.7 euros
#
# Day 1184:
# Went neutral. Long position closed - sold 737.23 units for 21374.62 euros.
#
# Day 1190: purchase of 760.21 units for total of 21369.62 euros
#
# Day 1191:
# Went neutral. Long position closed - sold 760.21 units for 21881.56 euros.
#
# Day 1201: purchase of 775.49 units for total of 21876.56 euros
#
# Day 1206:
# Went neutral. Long position closed - sold 775.49 units for 22391.14 euros.
#
# Day 1213: purchase of 784.1 units for total of 22386.14 euros
#
# Day 1214:
# Went neutral. Long position closed - sold 784.1 units for 22577.17 euros.
#
# Day 1219: purchase of 805.86 units for total of 22572.17 euros
#
# Day 1221:
# Went neutral. Long position closed - sold 805.86 units for 23074.86 euros.
#
# Day 1235: purchase of 801.04 units for total of 23069.86 euros
#
# Day 1237:
# Went neutral. Long position closed - sold 801.04 units for 23553.49 euros.
#
# Day 1264: purchase of 782.08 units for total of 23548.49 euros
#
# Day 1273:
# Went neutral. Long position closed - sold 782.08 units for 23840.68 euros.
#
# Day 1297: purchase of 711.73 units for total of 23835.68 euros
#
# Day 1299:
# Went neutral. Long position closed - sold 711.73 units for 24528.17 euros.
#
# Day 1306: purchase of 728.99 units for total of 24523.17 euros
#
# Day 1308:
# Went neutral. Long position closed - sold 728.99 units for 25094.07 euros.
#
# Day 1313: purchase of 744.7 units for total of 25089.07 euros
#
# Day 1314:
# Went neutral. Long position closed - sold 744.7 units for 25545.79 euros.
#
# Day 1317: purchase of 777.5 units for total of 25540.79 euros
#
# Day 1321:
# Went neutral. Long position closed - sold 777.5 units for 26142.24 euros.
#
# Day 1328: purchase of 779.05 units for total of 26137.24 euros
#
# Day 1337:
# Went neutral. Long position closed - sold 779.05 units for 26537.35 euros.
#
# Day 1340: purchase of 808.17 units for total of 26532.35 euros
#
# Day 1342:
# Went neutral. Long position closed - sold 808.17 units for 27206.21 euros.
#
# Day 1368: purchase of 728.08 units for total of 27201.21 euros
#
# Day 1372:
# Went neutral. Long position closed - sold 728.08 units for 27727.71 euros.
#
# Day 1378: purchase of 745.23 units for total of 27722.71 euros
#
# Day 1384:
# Went neutral. Long position closed - sold 745.23 units for 27896.57 euros.
#
# Day 1388: purchase of 765.2 units for total of 27891.57 euros
#
# Day 1400:
# Went neutral. Long position closed - sold 765.2 units for 27381.54 euros.
#
# Day 1423: purchase of 720.62 units for total of 27376.54 euros
#
# Day 1427:
# Went neutral. Long position closed - sold 720.62 units for 27926.42 euros.
#
# Day 1429: purchase of 746.56 units for total of 27921.42 euros
#
# Day 1449:
# Went neutral. Long position closed - sold 746.56 units for 24616.61 euros.
#
# Day 1469: purchase of 687.09 units for total of 24611.61 euros
#
# Day 1470:
# Went neutral. Long position closed - sold 687.09 units for 25108.19 euros.
#
# Day 1488: purchase of 653.05 units for total of 25103.19 euros
#
# Day 1490:
# Went neutral. Long position closed - sold 653.05 units for 25444.31 euros.
#
# Day 1501: purchase of 651.62 units for total of 25439.31 euros
#
# Day 1504:
# Went neutral. Long position closed - sold 651.62 units for 25929.54 euros.
#
# Day 1508: purchase of 665.59 units for total of 25924.54 euros
#
# Day 1512:
# Went neutral. Long position closed - sold 665.59 units for 26239.02 euros.
#
# Day 1546: purchase of 597.59 units for total of 26234.02 euros
#
# Day 1549:
# Went neutral. Long position closed - sold 597.59 units for 26707.09 euros.
#
# Day 1557: purchase of 626.66 units for total of 26702.09 euros
#
# Day 1565:
# Went neutral. Long position closed - sold 626.66 units for 27392.68 euros.
#
# Day 1577: purchase of 643.36 units for total of 27387.68 euros
#
# Day 1583:
# Went neutral. Long position closed - sold 643.36 units for 27878.07 euros.
#
# Day 1585: purchase of 654.91 units for total of 27873.07 euros
#
# Day 1586:
# Went neutral. Long position closed - sold 654.91 units for 28241.37 euros.
#
# Day 1608: purchase of 627.06 units for total of 28236.37 euros
#
# Day 1609:
# Went neutral. Long position closed - sold 627.06 units for 28695.39 euros.
#
# Day 1620: purchase of 631.25 units for total of 28690.39 euros
#
# Day 1644:
# Went neutral. Long position closed - sold 631.25 units for 25308.19 euros.
#
# Day 1646: purchase of 639.78 units for total of 25303.19 euros
#
# Day 1648:
# Went neutral. Long position closed - sold 639.78 units for 25490.13 euros.
#
# Day 1654: purchase of 648.15 units for total of 25485.13 euros
#
# Day 1656:
# Went neutral. Long position closed - sold 648.15 units for 25752.35 euros.
#
# Day 1658: purchase of 669.63 units for total of 25747.35 euros
#
# Day 1664:
# Went neutral. Long position closed - sold 669.63 units for 25641.9 euros.
#
# Day 1680: purchase of 671.83 units for total of 25636.9 euros
#
# Day 1687:
# Went neutral. Long position closed - sold 671.83 units for 25329.58 euros.
#
# Day 1718: purchase of 596.86 units for total of 25324.58 euros
#
# Day 1722:
# Went neutral. Long position closed - sold 596.86 units for 26023.87 euros.
#
# Day 1736: purchase of 593.77 units for total of 26018.87 euros
#
# Day 1744:
# Went neutral. Long position closed - sold 593.77 units for 25966.37 euros.
#
# Day 1752: purchase of 602.21 units for total of 25961.37 euros
#
# Day 1764:
# Went neutral. Long position closed - sold 602.21 units for 23698.07 euros.
#
# Day 1773: purchase of 600.28 units for total of 23693.07 euros
#
# Day 1774:
# Went neutral. Long position closed - sold 600.28 units for 24090.26 euros.
#
# Day 1776: purchase of 636.0 units for total of 24085.26 euros
#
# Day 1781:
# Went neutral. Long position closed - sold 636.0 units for 24951.58 euros.
#
# Day 1815: purchase of 567.35 units for total of 24946.58 euros
#
# Day 1816:
# Went neutral. Long position closed - sold 567.35 units for 25094.77 euros.
#
# Day 1818: purchase of 577.04 units for total of 25089.77 euros
#
# Day 1821:
# Went neutral. Long position closed - sold 577.04 units for 25742.59 euros.
#
# Day 1825: purchase of 600.5 units for total of 25737.59 euros
#
# Day 1828:
# Went neutral. Long position closed - sold 600.5 units for 26465.21 euros.
#
# Day 1833: purchase of 624.65 units for total of 26460.21 euros
#
# Day 1844:
# Went neutral. Long position closed - sold 624.65 units for 26217.84 euros.
#
# Day 1863: purchase of 582.9 units for total of 26212.84 euros
#
# Day 1871:
# Went neutral. Long position closed - sold 582.9 units for 26884.0 euros.
#
# Day 1873: purchase of 651.45 units for total of 26879.0 euros
#
# Day 1876:
# Went neutral. Long position closed - sold 651.45 units for 28906.54 euros.
#
# Day 1878: purchase of 674.17 units for total of 28901.54 euros
#
# Day 1880:
# Went neutral. Long position closed - sold 674.17 units for 29341.49 euros.
#
# Day 1924: purchase of 574.1 units for total of 29336.49 euros
#
# Day 1929:
# Went neutral. Long position closed - sold 574.1 units for 29337.23 euros.
#
# Day 1948: purchase of 572.34 units for total of 29332.23 euros
#
# Day 1954:
# Went neutral. Long position closed - sold 572.34 units for 29504.65 euros.
#
# Day 1960: purchase of 580.36 units for total of 29499.65 euros
#
# Day 1966:
# Went neutral. Long position closed - sold 580.36 units for 29750.01 euros.
#
# Day 1983: purchase of 568.85 units for total of 29745.01 euros
#
# Day 1986:
# Went neutral. Long position closed - sold 568.85 units for 31116.62 euros.
#
# Day 2002: purchase of 545.72 units for total of 31111.62 euros
#
# Day 2008:
# Went neutral. Long position closed - sold 545.72 units for 31084.79 euros.
#
# Day 2044: purchase of 518.6 units for total of 31079.79 euros
#
# Day 2050:
# Went neutral. Long position closed - sold 518.6 units for 31038.49 euros.
#
# Day 2058: purchase of 522.54 units for total of 31033.49 euros
#
# Day 2061:
# Went neutral. Long position closed - sold 522.54 units for 31326.33 euros.
#
# Day 2067: purchase of 526.23 units for total of 31321.33 euros
#
# Day 2078:
# Went neutral. Long position closed - sold 526.23 units for 31390.01 euros.
#
# Day 2087: purchase of 534.21 units for total of 31385.01 euros
#
# Day 2091:
# Went neutral. Long position closed - sold 534.21 units for 32149.27 euros.
#
# Day 2114: purchase of 504.94 units for total of 32144.27 euros
#
# Day 2122:
# Went neutral. Long position closed - sold 504.94 units for 32215.01 euros.
#
# Day 2128: purchase of 522.38 units for total of 32210.01 euros
#
# Day 2132:
# Went neutral. Long position closed - sold 522.38 units for 32701.28 euros.
#
# Day 2147: purchase of 498.95 units for total of 32696.28 euros
#
# Day 2159:
# Went neutral. Long position closed - sold 498.95 units for 31438.91 euros.
#
# Day 2162: purchase of 513.71 units for total of 31433.91 euros
#
# Day 2165:
# Went neutral. Long position closed - sold 513.71 units for 31716.59 euros.
#
# Day 2187: purchase of 502.16 units for total of 31711.59 euros
#
# Day 2189:
# Went neutral. Long position closed - sold 502.16 units for 32600.44 euros.
#
#
# End capital on day 2204: 32600.44 euros
# Total return: 226.0%
# Shares held at end of period: 0
# Total fee spending: 1270
# Day 21: purchase of 819.26 units for total of 9995 euros
#
# Day 26:
# Went neutral. Long position closed - sold 819.26 units for 9916.27 euros.
#
# Day 34: purchase of 863.35 units for total of 9911.27 euros
#
# Day 35:
# Went neutral. Long position closed - sold 863.35 units for 10752.35 euros.
#
# Day 77: purchase of 712.22 units for total of 10747.35 euros
#
# Day 84:
# Went neutral. Long position closed - sold 712.22 units for 11098.46 euros.
#
# Day 105: purchase of 654.87 units for total of 11093.46 euros
#
# Day 110:
# Went neutral. Long position closed - sold 654.87 units for 11127.75 euros.
#
# Day 117: purchase of 687.44 units for total of 11122.75 euros
#
# Day 121:
# Went neutral. Long position closed - sold 687.44 units for 11585.21 euros.
#
# Day 140: purchase of 611.09 units for total of 11580.21 euros
#
# Day 144:
# Went neutral. Long position closed - sold 611.09 units for 11880.75 euros.
#
# Day 173: purchase of 581.86 units for total of 11875.75 euros
#
# Day 175:
# Went neutral. Long position closed - sold 581.86 units for 12120.95 euros.
#
# Day 178: purchase of 617.22 units for total of 12115.95 euros
#
# Day 184:
# Went neutral. Long position closed - sold 617.22 units for 12740.52 euros.
#
# Day 194: purchase of 638.05 units for total of 12735.52 euros
#
# Day 203:
# Went neutral. Long position closed - sold 638.05 units for 12347.68 euros.
#
# Day 249: purchase of 526.57 units for total of 12342.68 euros
#
# Day 263:
# Went neutral. Long position closed - sold 526.57 units for 11690.01 euros.
#
# Day 321: purchase of 462.77 units for total of 11685.01 euros
#
# Day 331:
# Went neutral. Long position closed - sold 462.77 units for 11258.89 euros.
#
# Day 335: purchase of 496.2 units for total of 11253.89 euros
#
# Day 342:
# Went neutral. Long position closed - sold 496.2 units for 11511.87 euros.
#
# Day 348: purchase of 536.95 units for total of 11506.87 euros
#
# Day 353:
# Went neutral. Long position closed - sold 536.95 units for 11872.37 euros.
#
# Day 361: purchase of 538.2 units for total of 11867.37 euros
#
# Day 369:
# Went neutral. Long position closed - sold 538.2 units for 11765.49 euros.
#
# Day 385: purchase of 534.57 units for total of 11760.49 euros
#
# Day 392:
# Went neutral. Long position closed - sold 534.57 units for 11985.36 euros.
#
# Day 394: purchase of 568.06 units for total of 11980.36 euros
#
# Day 406:
# Went neutral. Long position closed - sold 568.06 units for 11850.38 euros.
#
# Day 408: purchase of 592.86 units for total of 11845.38 euros
#
# Day 410:
# Went neutral. Long position closed - sold 592.86 units for 12421.39 euros.
#
# Day 434: purchase of 555.79 units for total of 12416.39 euros
#
# Day 435:
# Went neutral. Long position closed - sold 555.79 units for 12550.34 euros.
#
# Day 444: purchase of 558.31 units for total of 12545.34 euros
#
# Day 445:
# Went neutral. Long position closed - sold 558.31 units for 12847.41 euros.
#
# Day 462: purchase of 523.11 units for total of 12842.41 euros
#
# Day 465:
# Went neutral. Long position closed - sold 523.11 units for 13323.91 euros.
#
# Day 482: purchase of 494.58 units for total of 13318.91 euros
#
# Day 489:
# Went neutral. Long position closed - sold 494.58 units for 13491.95 euros.
#
# Day 529: purchase of 452.58 units for total of 13486.95 euros
#
# Day 535:
# Went neutral. Long position closed - sold 452.58 units for 13871.17 euros.
#
# Day 537: purchase of 469.24 units for total of 13866.17 euros
#
# Day 547:
# Went neutral. Long position closed - sold 469.24 units for 13269.93 euros.
#
# Day 563: purchase of 468.73 units for total of 13264.93 euros
#
# Day 569:
# Went neutral. Long position closed - sold 468.73 units for 13789.59 euros.
#
# Day 586: purchase of 466.64 units for total of 13784.59 euros
#
# Day 595:
# Went neutral. Long position closed - sold 466.64 units for 13751.59 euros.
#
# Day 599: purchase of 486.26 units for total of 13746.59 euros
#
# Day 613:
# Went neutral. Long position closed - sold 486.26 units for 13211.56 euros.
#
# Day 625: purchase of 493.33 units for total of 13206.56 euros
#
# Day 633:
# Went neutral. Long position closed - sold 493.33 units for 13709.7 euros.
#
# Day 637: purchase of 524.08 units for total of 13704.7 euros
#
# Day 649:
# Went neutral. Long position closed - sold 524.08 units for 12394.74 euros.
#
# Day 653: purchase of 589.43 units for total of 12389.74 euros
#
# Day 655:
# Went neutral. Long position closed - sold 589.43 units for 13198.15 euros.
#
# Day 664: purchase of 607.98 units for total of 13193.15 euros
#
# Day 665:
# Went neutral. Long position closed - sold 607.98 units for 13729.25 euros.
#
# Day 676: purchase of 615.71 units for total of 13724.25 euros
#
# Day 685:
# Went neutral. Long position closed - sold 615.71 units for 13577.63 euros.
#
# Day 711: purchase of 573.17 units for total of 13572.63 euros
#
# Day 712:
# Went neutral. Long position closed - sold 573.17 units for 14020.44 euros.
#
# Day 716: purchase of 609.37 units for total of 14015.44 euros
#
# Day 724:
# Went neutral. Long position closed - sold 609.37 units for 13900.75 euros.
#
# Day 733: purchase of 646.61 units for total of 13895.75 euros
#
# Day 740:
# Went neutral. Long position closed - sold 646.61 units for 14466.24 euros.
#
# Day 786: purchase of 555.99 units for total of 14461.24 euros
#
# Day 794:
# Went neutral. Long position closed - sold 555.99 units for 14311.68 euros.
#
# Day 809: purchase of 557.11 units for total of 14306.68 euros
#
# Day 818:
# Went neutral. Long position closed - sold 557.11 units for 14000.84 euros.
#
# Day 821: purchase of 585.36 units for total of 13995.84 euros
#
# Day 826:
# Went neutral. Long position closed - sold 585.36 units for 14236.69 euros.
#
# Day 831: purchase of 615.56 units for total of 14231.69 euros
#
# Day 847:
# Went neutral. Long position closed - sold 615.56 units for 13685.0 euros.
#
# Day 850: purchase of 658.64 units for total of 13680.0 euros
#
# Day 853:
# Went neutral. Long position closed - sold 658.64 units for 14544.4 euros.
#
# Day 867: purchase of 685.17 units for total of 14539.4 euros
#
# Day 870:
# Went neutral. Long position closed - sold 685.17 units for 15267.54 euros.
#
# Day 876: purchase of 725.41 units for total of 15262.54 euros
#
# Day 883:
# Went neutral. Long position closed - sold 725.41 units for 15605.74 euros.
#
# Day 886: purchase of 769.65 units for total of 15600.74 euros
#
# Day 888:
# Went neutral. Long position closed - sold 769.65 units for 16280.72 euros.
#
# Day 908: purchase of 709.18 units for total of 16275.72 euros
#
# Day 917:
# Went neutral. Long position closed - sold 709.18 units for 16575.67 euros.
#
# Day 928: purchase of 721.72 units for total of 16570.67 euros
#
# Day 945:
# Went neutral. Long position closed - sold 721.72 units for 15367.62 euros.
#
# Day 949: purchase of 751.96 units for total of 15362.62 euros
#
# Day 954:
# Went neutral. Long position closed - sold 751.96 units for 15613.28 euros.
#
# Day 963: purchase of 762.12 units for total of 15608.28 euros
#
# Day 969:
# Went neutral. Long position closed - sold 762.12 units for 15588.04 euros.
#
# Day 992: purchase of 699.73 units for total of 15583.04 euros
#
# Day 995:
# Went neutral. Long position closed - sold 699.73 units for 15766.97 euros.
#
# Day 1030: purchase of 656.75 units for total of 15761.97 euros
#
# Day 1038:
# Went neutral. Long position closed - sold 656.75 units for 15816.08 euros.
#
# Day 1057: purchase of 660.17 units for total of 15811.08 euros
#
# Day 1062:
# Went neutral. Long position closed - sold 660.17 units for 16109.76 euros.
#
# Day 1069: purchase of 698.69 units for total of 16104.76 euros
#
# Day 1073:
# Went neutral. Long position closed - sold 698.69 units for 16791.46 euros.
#
# Day 1107: purchase of 647.63 units for total of 16786.46 euros
#
# Day 1110:
# Went neutral. Long position closed - sold 647.63 units for 17331.94 euros.
#
# Day 1115: purchase of 673.41 units for total of 17326.94 euros
#
# Day 1118:
# Went neutral. Long position closed - sold 673.41 units for 17901.07 euros.
#
# Day 1138: purchase of 641.44 units for total of 17896.07 euros
#
# Day 1141:
# Went neutral. Long position closed - sold 641.44 units for 18218.21 euros.
#
# Day 1146: purchase of 656.33 units for total of 18213.21 euros
#
# Day 1150:
# Went neutral. Long position closed - sold 656.33 units for 18464.18 euros.
#
# Day 1152: purchase of 678.15 units for total of 18459.18 euros
#
# Day 1158:
# Went neutral. Long position closed - sold 678.15 units for 18677.96 euros.
#
# Day 1182: purchase of 653.82 units for total of 18672.96 euros
#
# Day 1184:
# Went neutral. Long position closed - sold 653.82 units for 18955.64 euros.
#
# Day 1190: purchase of 674.16 units for total of 18950.64 euros
#
# Day 1191:
# Went neutral. Long position closed - sold 674.16 units for 19404.07 euros.
#
# Day 1201: purchase of 687.67 units for total of 19399.07 euros
#
# Day 1206:
# Went neutral. Long position closed - sold 687.67 units for 19854.81 euros.
#
# Day 1219: purchase of 708.67 units for total of 19849.81 euros
#
# Day 1221:
# Went neutral. Long position closed - sold 708.67 units for 20291.27 euros.
#
# Day 1235: purchase of 704.38 units for total of 20286.27 euros
#
# Day 1237:
# Went neutral. Long position closed - sold 704.38 units for 20710.94 euros.
#
# Day 1264: purchase of 687.68 units for total of 20705.94 euros
#
# Day 1273:
# Went neutral. Long position closed - sold 687.68 units for 20962.26 euros.
#
# Day 1306: purchase of 622.99 units for total of 20957.26 euros
#
# Day 1308:
# Went neutral. Long position closed - sold 622.99 units for 21444.42 euros.
#
# Day 1317: purchase of 652.65 units for total of 21439.42 euros
#
# Day 1321:
# Went neutral. Long position closed - sold 652.65 units for 21943.48 euros.
#
# Day 1333: purchase of 660.4 units for total of 21938.48 euros
#
# Day 1337:
# Went neutral. Long position closed - sold 660.4 units for 22494.82 euros.
#
# Day 1340: purchase of 685.04 units for total of 22489.82 euros
#
# Day 1342:
# Went neutral. Long position closed - sold 685.04 units for 23060.26 euros.
#
# Day 1369: purchase of 620.93 units for total of 23055.26 euros
#
# Day 1372:
# Went neutral. Long position closed - sold 620.93 units for 23646.35 euros.
#
# Day 1378: purchase of 635.52 units for total of 23641.35 euros
#
# Day 1384:
# Went neutral. Long position closed - sold 635.52 units for 23788.88 euros.
#
# Day 1388: purchase of 652.51 units for total of 23783.88 euros
#
# Day 1400:
# Went neutral. Long position closed - sold 652.51 units for 23348.22 euros.
#
# Day 1423: purchase of 614.46 units for total of 23343.22 euros
#
# Day 1427:
# Went neutral. Long position closed - sold 614.46 units for 23811.36 euros.
#
# Day 1429: purchase of 636.53 units for total of 23806.36 euros
#
# Day 1449:
# Went neutral. Long position closed - sold 636.53 units for 20987.88 euros.
#
# Day 1469: purchase of 585.79 units for total of 20982.88 euros
#
# Day 1470:
# Went neutral. Long position closed - sold 585.79 units for 21405.5 euros.
#
# Day 1489: purchase of 559.34 units for total of 21400.5 euros
#
# Day 1490:
# Went neutral. Long position closed - sold 559.34 units for 21792.64 euros.
#
# Day 1501: purchase of 558.08 units for total of 21787.64 euros
#
# Day 1504:
# Went neutral. Long position closed - sold 558.08 units for 22206.78 euros.
#
# Day 1509: purchase of 583.34 units for total of 22201.78 euros
#
# Day 1512:
# Went neutral. Long position closed - sold 583.34 units for 22995.95 euros.
#
# Day 1546: purchase of 523.71 units for total of 22990.95 euros
#
# Day 1549:
# Went neutral. Long position closed - sold 523.71 units for 23404.92 euros.
#
# Day 1557: purchase of 549.16 units for total of 23399.92 euros
#
# Day 1565:
# Went neutral. Long position closed - sold 549.16 units for 24004.49 euros.
#
# Day 1577: purchase of 563.77 units for total of 23999.49 euros
#
# Day 1583:
# Went neutral. Long position closed - sold 563.77 units for 24428.59 euros.
#
# Day 1608: purchase of 542.38 units for total of 24423.59 euros
#
# Day 1609:
# Went neutral. Long position closed - sold 542.38 units for 24819.96 euros.
#
# Day 1620: purchase of 545.98 units for total of 24814.96 euros
#
# Day 1644:
# Went neutral. Long position closed - sold 545.98 units for 21888.95 euros.
#
# Day 1647: purchase of 558.26 units for total of 21883.95 euros
#
# Day 1648:
# Went neutral. Long position closed - sold 558.26 units for 22241.82 euros.
#
# Day 1658: purchase of 578.33 units for total of 22236.82 euros
#
# Day 1664:
# Went neutral. Long position closed - sold 578.33 units for 22145.07 euros.
#
# Day 1680: purchase of 580.19 units for total of 22140.07 euros
#
# Day 1687:
# Went neutral. Long position closed - sold 580.19 units for 21873.98 euros.
#
# Day 1718: purchase of 515.41 units for total of 21868.98 euros
#
# Day 1722:
# Went neutral. Long position closed - sold 515.41 units for 22472.17 euros.
#
# Day 1736: purchase of 512.71 units for total of 22467.17 euros
#
# Day 1744:
# Went neutral. Long position closed - sold 512.71 units for 22421.15 euros.
#
# Day 1752: purchase of 519.98 units for total of 22416.15 euros
#
# Day 1764:
# Went neutral. Long position closed - sold 519.98 units for 20461.24 euros.
#
# Day 1776: purchase of 540.17 units for total of 20456.24 euros
#
# Day 1781:
# Went neutral. Long position closed - sold 540.17 units for 21191.28 euros.
#
# Day 1818: purchase of 487.26 units for total of 21186.28 euros
#
# Day 1821:
# Went neutral. Long position closed - sold 487.26 units for 21736.76 euros.
#
# Day 1825: purchase of 507.04 units for total of 21731.76 euros
#
# Day 1828:
# Went neutral. Long position closed - sold 507.04 units for 22345.35 euros.
#
# Day 1833: purchase of 527.39 units for total of 22340.35 euros
#
# Day 1844:
# Went neutral. Long position closed - sold 527.39 units for 22134.94 euros.
#
# Day 1863: purchase of 492.1 units for total of 22129.94 euros
#
# Day 1871:
# Went neutral. Long position closed - sold 492.1 units for 22695.78 euros.
#
# Day 1873: purchase of 549.95 units for total of 22690.78 euros
#
# Day 1876:
# Went neutral. Long position closed - sold 549.95 units for 24401.61 euros.
#
# Day 1924: purchase of 477.43 units for total of 24396.61 euros
#
# Day 1929:
# Went neutral. Long position closed - sold 477.43 units for 24396.39 euros.
#
# Day 1948: purchase of 475.93 units for total of 24391.39 euros
#
# Day 1954:
# Went neutral. Long position closed - sold 475.93 units for 24533.92 euros.
#
# Day 1960: purchase of 482.57 units for total of 24528.92 euros
#
# Day 1966:
# Went neutral. Long position closed - sold 482.57 units for 24736.25 euros.
#
# Day 1983: purchase of 472.96 units for total of 24731.25 euros
#
# Day 1986:
# Went neutral. Long position closed - sold 472.96 units for 25870.83 euros.
#
# Day 2003: purchase of 460.98 units for total of 25865.83 euros
#
# Day 2008:
# Went neutral. Long position closed - sold 460.98 units for 26257.27 euros.
#
# Day 2044: purchase of 438.05 units for total of 26252.27 euros
#
# Day 2050:
# Went neutral. Long position closed - sold 438.05 units for 26216.61 euros.
#
# Day 2068: purchase of 445.02 units for total of 26211.61 euros
#
# Day 2078:
# Went neutral. Long position closed - sold 445.02 units for 26544.82 euros.
#
# Day 2087: purchase of 451.74 units for total of 26539.82 euros
#
# Day 2091:
# Went neutral. Long position closed - sold 451.74 units for 27185.33 euros.
#
# Day 2114: purchase of 426.96 units for total of 27180.33 euros
#
# Day 2122:
# Went neutral. Long position closed - sold 426.96 units for 27239.37 euros.
#
# Day 2128: purchase of 441.69 units for total of 27234.37 euros
#
# Day 2132:
# Went neutral. Long position closed - sold 441.69 units for 27648.98 euros.
#
# Day 2148: purchase of 425.16 units for total of 27643.98 euros
#
# Day 2159:
# Went neutral. Long position closed - sold 425.16 units for 26788.65 euros.
#
# Day 2162: purchase of 437.71 units for total of 26783.65 euros
#
# Day 2165:
# Went neutral. Long position closed - sold 437.71 units for 27023.77 euros.
#
# Day 2187: purchase of 427.85 units for total of 27018.77 euros
#
# Day 2189:
# Went neutral. Long position closed - sold 427.85 units for 27775.35 euros.
#
#
# End capital on day 2204: 27775.35 euros
# Total return: 177.75%
# Shares held at end of period: 0
# Total fee spending: 1040
# Day 22: purchase of 861.64 units for total of 9995 euros
#
# Day 26:
# Went neutral. Long position closed - sold 861.64 units for 10429.44 euros.
#
# Day 80: purchase of 721.91 units for total of 10424.44 euros
#
# Day 84:
# Went neutral. Long position closed - sold 721.91 units for 11249.64 euros.
#
# Day 107: purchase of 681.91 units for total of 11244.64 euros
#
# Day 110:
# Went neutral. Long position closed - sold 681.91 units for 11587.41 euros.
#
# Day 117: purchase of 715.85 units for total of 11582.41 euros
#
# Day 121:
# Went neutral. Long position closed - sold 715.85 units for 12064.18 euros.
#
# Day 142: purchase of 646.26 units for total of 12059.18 euros
#
# Day 144:
# Went neutral. Long position closed - sold 646.26 units for 12564.73 euros.
#
# Day 173: purchase of 615.37 units for total of 12559.73 euros
#
# Day 175:
# Went neutral. Long position closed - sold 615.37 units for 12819.34 euros.
#
# Day 178: purchase of 652.79 units for total of 12814.34 euros
#
# Day 184:
# Went neutral. Long position closed - sold 652.79 units for 13475.19 euros.
#
# Day 194: purchase of 674.86 units for total of 13470.19 euros
#
# Day 203:
# Went neutral. Long position closed - sold 674.86 units for 13060.27 euros.
#
# Day 251: purchase of 577.16 units for total of 13055.27 euros
#
# Day 263:
# Went neutral. Long position closed - sold 577.16 units for 12813.64 euros.
#
# Day 323: purchase of 523.66 units for total of 12808.64 euros
#
# Day 331:
# Went neutral. Long position closed - sold 523.66 units for 12740.8 euros.
#
# Day 337: purchase of 576.54 units for total of 12735.8 euros
#
# Day 342:
# Went neutral. Long position closed - sold 576.54 units for 13376.53 euros.
#
# Day 348: purchase of 623.96 units for total of 13371.53 euros
#
# Day 353:
# Went neutral. Long position closed - sold 623.96 units for 13797.06 euros.
#
# Day 364: purchase of 646.3 units for total of 13792.06 euros
#
# Day 369:
# Went neutral. Long position closed - sold 646.3 units for 14129.6 euros.
#
# Day 386: purchase of 647.32 units for total of 14124.6 euros
#
# Day 392:
# Went neutral. Long position closed - sold 647.32 units for 14514.47 euros.
#
# Day 394: purchase of 687.98 units for total of 14509.47 euros
#
# Day 406:
# Went neutral. Long position closed - sold 687.98 units for 14353.11 euros.
#
# Day 408: purchase of 718.12 units for total of 14348.11 euros
#
# Day 410:
# Went neutral. Long position closed - sold 718.12 units for 15046.87 euros.
#
# Day 444: purchase of 669.42 units for total of 15041.87 euros
#
# Day 445:
# Went neutral. Long position closed - sold 669.42 units for 15405.05 euros.
#
# Day 462: purchase of 627.29 units for total of 15400.05 euros
#
# Day 465:
# Went neutral. Long position closed - sold 627.29 units for 15978.44 euros.
#
# Day 482: purchase of 593.15 units for total of 15973.44 euros
#
# Day 489:
# Went neutral. Long position closed - sold 593.15 units for 16181.97 euros.
#
# Day 529: purchase of 542.85 units for total of 16176.97 euros
#
# Day 535:
# Went neutral. Long position closed - sold 542.85 units for 16638.82 euros.
#
# Day 537: purchase of 562.9 units for total of 16633.82 euros
#
# Day 547:
# Went neutral. Long position closed - sold 562.9 units for 15919.56 euros.
#
# Day 563: purchase of 562.35 units for total of 15914.56 euros
#
# Day 569:
# Went neutral. Long position closed - sold 562.35 units for 16545.02 euros.
#
# Day 586: purchase of 559.92 units for total of 16540.02 euros
#
# Day 595:
# Went neutral. Long position closed - sold 559.92 units for 16501.43 euros.
#
# Day 599: purchase of 583.53 units for total of 16496.43 euros
#
# Day 613:
# Went neutral. Long position closed - sold 583.53 units for 15855.38 euros.
#
# Day 625: purchase of 592.09 units for total of 15850.38 euros
#
# Day 633:
# Went neutral. Long position closed - sold 592.09 units for 16455.23 euros.
#
# Day 639: purchase of 640.83 units for total of 16450.23 euros
#
# Day 649:
# Went neutral. Long position closed - sold 640.83 units for 15157.16 euros.
#
# Day 682: purchase of 714.72 units for total of 15152.16 euros
#
# Day 685:
# Went neutral. Long position closed - sold 714.72 units for 15761.82 euros.
#
# Day 716: purchase of 685.08 units for total of 15756.82 euros
#
# Day 724:
# Went neutral. Long position closed - sold 685.08 units for 15628.5 euros.
#
# Day 733: purchase of 727.01 units for total of 15623.5 euros
#
# Day 740:
# Went neutral. Long position closed - sold 727.01 units for 16265.55 euros.
#
# Day 787: purchase of 637.17 units for total of 16260.55 euros
#
# Day 794:
# Went neutral. Long position closed - sold 637.17 units for 16402.09 euros.
#
# Day 809: purchase of 638.52 units for total of 16397.09 euros
#
# Day 818:
# Went neutral. Long position closed - sold 638.52 units for 16047.3 euros.
#
# Day 821: purchase of 670.95 units for total of 16042.3 euros
#
# Day 826:
# Went neutral. Long position closed - sold 670.95 units for 16319.09 euros.
#
# Day 831: purchase of 705.63 units for total of 16314.09 euros
#
# Day 847:
# Went neutral. Long position closed - sold 705.63 units for 15688.14 euros.
#
# Day 850: purchase of 755.09 units for total of 15683.14 euros
#
# Day 853:
# Went neutral. Long position closed - sold 755.09 units for 16674.86 euros.
#
# Day 878: purchase of 808.04 units for total of 16669.86 euros
#
# Day 883:
# Went neutral. Long position closed - sold 808.04 units for 17384.01 euros.
#
# Day 913: purchase of 773.78 units for total of 17379.01 euros
#
# Day 917:
# Went neutral. Long position closed - sold 773.78 units for 18085.88 euros.
#
# Day 929: purchase of 800.39 units for total of 18080.88 euros
#
# Day 945:
# Went neutral. Long position closed - sold 800.39 units for 17043.38 euros.
#
# Day 964: purchase of 847.26 units for total of 17038.38 euros
#
# Day 969:
# Went neutral. Long position closed - sold 847.26 units for 17329.92 euros.
#
# Day 1030: purchase of 721.87 units for total of 17324.92 euros
#
# Day 1038:
# Went neutral. Long position closed - sold 721.87 units for 17384.89 euros.
#
# Day 1057: purchase of 725.67 units for total of 17379.89 euros
#
# Day 1062:
# Went neutral. Long position closed - sold 725.67 units for 17708.7 euros.
#
# Day 1069: purchase of 768.06 units for total of 17703.7 euros
#
# Day 1073:
# Went neutral. Long position closed - sold 768.06 units for 18459.07 euros.
#
# Day 1107: purchase of 711.96 units for total of 18454.07 euros
#
# Day 1110:
# Went neutral. Long position closed - sold 711.96 units for 19054.24 euros.
#
# Day 1115: purchase of 740.35 units for total of 19049.24 euros
#
# Day 1118:
# Went neutral. Long position closed - sold 740.35 units for 19680.94 euros.
#
# Day 1138: purchase of 705.23 units for total of 19675.94 euros
#
# Day 1141:
# Went neutral. Long position closed - sold 705.23 units for 20030.61 euros.
#
# Day 1146: purchase of 721.64 units for total of 20025.61 euros
#
# Day 1150:
# Went neutral. Long position closed - sold 721.64 units for 20302.05 euros.
#
# Day 1152: purchase of 745.67 units for total of 20297.05 euros
#
# Day 1158:
# Went neutral. Long position closed - sold 745.67 units for 20538.12 euros.
#
# Day 1190: purchase of 730.46 units for total of 20533.12 euros
#
# Day 1191:
# Went neutral. Long position closed - sold 730.46 units for 21024.83 euros.
#
# Day 1201: purchase of 745.12 units for total of 21019.83 euros
#
# Day 1206:
# Went neutral. Long position closed - sold 745.12 units for 21514.06 euros.
#
# Day 1219: purchase of 767.91 units for total of 21509.06 euros
#
# Day 1221:
# Went neutral. Long position closed - sold 767.91 units for 21987.84 euros.
#
# Day 1235: purchase of 763.29 units for total of 21982.84 euros
#
# Day 1237:
# Went neutral. Long position closed - sold 763.29 units for 22443.45 euros.
#
# Day 1269: purchase of 762.95 units for total of 22438.45 euros
#
# Day 1273:
# Went neutral. Long position closed - sold 762.95 units for 23257.44 euros.
#
# Day 1317: purchase of 707.84 units for total of 23252.44 euros
#
# Day 1321:
# Went neutral. Long position closed - sold 707.84 units for 23799.55 euros.
#
# Day 1340: purchase of 724.78 units for total of 23794.55 euros
#
# Day 1342:
# Went neutral. Long position closed - sold 724.78 units for 24398.37 euros.
#
# Day 1383: purchase of 663.95 units for total of 24393.37 euros
#
# Day 1384:
# Went neutral. Long position closed - sold 663.95 units for 24853.13 euros.
#
# Day 1388: purchase of 681.7 units for total of 24848.13 euros
#
# Day 1400:
# Went neutral. Long position closed - sold 681.7 units for 24393.21 euros.
#
# Day 1423: purchase of 641.96 units for total of 24388.21 euros
#
# Day 1427:
# Went neutral. Long position closed - sold 641.96 units for 24877.52 euros.
#
# Day 1432: purchase of 673.87 units for total of 24872.52 euros
#
# Day 1449:
# Went neutral. Long position closed - sold 673.87 units for 22219.21 euros.
#
# Day 1469: purchase of 620.16 units for total of 22214.21 euros
#
# Day 1470:
# Went neutral. Long position closed - sold 620.16 units for 22661.93 euros.
#
# Day 1501: purchase of 580.35 units for total of 22656.93 euros
#
# Day 1504:
# Went neutral. Long position closed - sold 580.35 units for 23093.0 euros.
#
# Day 1509: purchase of 606.62 units for total of 23088.0 euros
#
# Day 1512:
# Went neutral. Long position closed - sold 606.62 units for 23914.07 euros.
#
# Day 1557: purchase of 561.11 units for total of 23909.07 euros
#
# Day 1565:
# Went neutral. Long position closed - sold 561.11 units for 24526.9 euros.
#
# Day 1577: purchase of 576.04 units for total of 24521.9 euros
#
# Day 1583:
# Went neutral. Long position closed - sold 576.04 units for 24960.45 euros.
#
# Day 1608: purchase of 554.2 units for total of 24955.45 euros
#
# Day 1609:
# Went neutral. Long position closed - sold 554.2 units for 25360.56 euros.
#
# Day 1621: purchase of 573.66 units for total of 25355.56 euros
#
# Day 1644:
# Went neutral. Long position closed - sold 573.66 units for 22998.57 euros.
#
# Day 1658: purchase of 598.01 units for total of 22993.57 euros
#
# Day 1664:
# Went neutral. Long position closed - sold 598.01 units for 22898.87 euros.
#
# Day 1680: purchase of 599.94 units for total of 22893.87 euros
#
# Day 1687:
# Went neutral. Long position closed - sold 599.94 units for 22618.9 euros.
#
# Day 1719: purchase of 538.43 units for total of 22613.9 euros
#
# Day 1722:
# Went neutral. Long position closed - sold 538.43 units for 23475.76 euros.
#
# Day 1736: purchase of 535.62 units for total of 23470.76 euros
#
# Day 1744:
# Went neutral. Long position closed - sold 535.62 units for 23422.91 euros.
#
# Day 1753: purchase of 548.56 units for total of 23417.91 euros
#
# Day 1764:
# Went neutral. Long position closed - sold 548.56 units for 21586.22 euros.
#
# Day 1776: purchase of 569.88 units for total of 21581.22 euros
#
# Day 1781:
# Went neutral. Long position closed - sold 569.88 units for 22356.95 euros.
#
# Day 1825: purchase of 521.51 units for total of 22351.95 euros
#
# Day 1828:
# Went neutral. Long position closed - sold 521.51 units for 22983.19 euros.
#
# Day 1833: purchase of 542.45 units for total of 22978.19 euros
#
# Day 1844:
# Went neutral. Long position closed - sold 542.45 units for 22767.06 euros.
#
# Day 1863: purchase of 506.16 units for total of 22762.06 euros
#
# Day 1871:
# Went neutral. Long position closed - sold 506.16 units for 23344.21 euros.
#
# Day 1873: purchase of 565.66 units for total of 23339.21 euros
#
# Day 1876:
# Went neutral. Long position closed - sold 565.66 units for 25099.07 euros.
#
# Day 1925: purchase of 510.25 units for total of 25094.07 euros
#
# Day 1929:
# Went neutral. Long position closed - sold 510.25 units for 26073.85 euros.
#
# Day 1948: purchase of 508.66 units for total of 26068.85 euros
#
# Day 1954:
# Went neutral. Long position closed - sold 508.66 units for 26221.54 euros.
#
# Day 1983: purchase of 501.37 units for total of 26216.54 euros
#
# Day 1986:
# Went neutral. Long position closed - sold 501.37 units for 27424.85 euros.
#
# Day 2003: purchase of 488.68 units for total of 27419.85 euros
#
# Day 2008:
# Went neutral. Long position closed - sold 488.68 units for 27835.11 euros.
#
# Day 2068: purchase of 472.5 units for total of 27830.11 euros
#
# Day 2078:
# Went neutral. Long position closed - sold 472.5 units for 28184.21 euros.
#
# Day 2116: purchase of 447.22 units for total of 28179.21 euros
#
# Day 2122:
# Went neutral. Long position closed - sold 447.22 units for 28531.99 euros.
#
# Day 2128: purchase of 462.65 units for total of 28526.99 euros
#
# Day 2132:
# Went neutral. Long position closed - sold 462.65 units for 28961.5 euros.
#
# Day 2148: purchase of 445.35 units for total of 28956.5 euros
#
# Day 2159:
# Went neutral. Long position closed - sold 445.35 units for 28060.81 euros.
#
# Day 2187: purchase of 444.27 units for total of 28055.81 euros
#
# Day 2189:
# Went neutral. Long position closed - sold 444.27 units for 28841.61 euros.
#
#
# End capital on day 2204: 28841.61 euros
# Total return: 188.42%
# Shares held at end of period: 0
# Total fee spending: 830
# Day 178: purchase of 509.17 units for total of 9995 euros
#
# Day 184:
# Went neutral. Long position closed - sold 509.17 units for 10509.35 euros.
#
# Day 197: purchase of 559.04 units for total of 10504.35 euros
#
# Day 203:
# Went neutral. Long position closed - sold 559.04 units for 10818.01 euros.
#
# Day 251: purchase of 478.03 units for total of 10813.01 euros
#
# Day 263:
# Went neutral. Long position closed - sold 478.03 units for 10612.01 euros.
#
# Day 323: purchase of 433.65 units for total of 10607.01 euros
#
# Day 331:
# Went neutral. Long position closed - sold 433.65 units for 10549.98 euros.
#
# Day 394: purchase of 500.0 units for total of 10544.98 euros
#
# Day 406:
# Went neutral. Long position closed - sold 500.0 units for 10429.98 euros.
#
# Day 539: purchase of 365.15 units for total of 10424.98 euros
#
# Day 547:
# Went neutral. Long position closed - sold 365.15 units for 10325.04 euros.
#
# Day 683: purchase of 512.92 units for total of 10320.04 euros
#
# ...
#
# Day 822: purchase of 526.08 units for total of 12341.85 euros
#
# Day 894:
# Went neutral. Long position closed - sold 526.08 units for 11616.12 euros.
#
# Day 941: purchase of 563.37 units for total of 11611.12 euros
#
# Day 977:
# Went neutral. Long position closed - sold 563.37 units for 12270.9 euros.
#
# Day 1069: purchase of 532.14 units for total of 12265.9 euros
#
# Day 1074:
# Went neutral. Long position closed - sold 532.14 units for 12958.01 euros.
#
# Day 1439: purchase of 366.01 units for total of 12953.01 euros
#
# Day 1459:
# Went neutral. Long position closed - sold 366.01 units for 13233.5 euros.
#
# Day 1626: purchase of 313.92 units for total of 13228.5 euros
#
# Day 1692:
# Went neutral. Long position closed - sold 313.92 units for 12661.58 euros.
#
# Day 1759: purchase of 325.03 units for total of 12656.58 euros
#
# Day 1791:
# Went neutral. Long position closed - sold 325.03 units for 13789.18 euros.
#
# Day 1873: purchase of 334.08 units for total of 13784.18 euros
#
# Day 1876:
# Went neutral. Long position closed - sold 334.08 units for 14821.52 euros.
#
# Day 2163: purchase of 245.14 units for total of 14816.52 euros
#
# Day 2170:
# Went neutral. Long position closed - sold 245.14 units for 15576.36 euros.
#
#
# End capital on day 2204: 15576.36 euros
# Total return: 55.76%
# Shares held at end of period: 0
# Total fee spending: 140
# Day 348: purchase of 466.4 units for total of 9995 euros
#
# Day 382:
# Went neutral. Long position closed - sold 466.4 units for 10852.84 euros.
#
# Day 408: purchase of 542.94 units for total of 10847.84 euros
#
# Day 421:
# Went neutral. Long position closed - sold 542.94 units for 11841.84 euros.
#
# Day 604: purchase of 434.38 units for total of 11836.84 euros
#
# Day 622:
# Went neutral. Long position closed - sold 434.38 units for 12526.85 euros.
#
# Day 640: purchase of 501.88 units for total of 12521.85 euros
#
# Day 692:
# Went neutral. Long position closed - sold 501.88 units for 12160.52 euros.
#
# Day 823: purchase of 521.7 units for total of 12155.52 euros
#
# Day 894:
# Went neutral. Long position closed - sold 521.7 units for 11519.27 euros.
#
# Day 1070: purchase of 501.71 units for total of 11514.27 euros
#
# Day 1074:
# Went neutral. Long position closed - sold 501.71 units for 12216.68 euros.
#
# Day 1440: purchase of 354.27 units for total of 12211.68 euros
#
# Day 1459:
# Went neutral. Long position closed - sold 354.27 units for 12808.94 euros.
#
# Day 1627: purchase of 305.88 units for total of 12803.94 euros
#
# Day 1692:
# Went neutral. Long position closed - sold 305.88 units for 12337.07 euros.
#
# Day 1761: purchase of 323.93 units for total of 12332.07 euros
#
# Day 1791:
# Went neutral. Long position closed - sold 323.93 units for 13742.65 euros.
#
#
# End capital on day 2204: 13742.65 euros
# Total return: 37.43%
# Shares held at end of period: 0
# Total fee spending: 90
# Day 608: purchase of 380.04 units for total of 9995 euros
#
# Day 622:
# Went neutral. Long position closed - sold 380.04 units for 10959.1 euros.
#
# Day 642: purchase of 464.75 units for total of 10954.1 euros
#
# Day 692:
# Went neutral. Long position closed - sold 464.75 units for 11260.48 euros.
#
# Day 831: purchase of 486.83 units for total of 11255.48 euros
#
# Day 894:
# Went neutral. Long position closed - sold 486.83 units for 10749.04 euros.
#
# Day 1442: purchase of 316.0 units for total of 10744.04 euros
#
# Day 1459:
# Went neutral. Long position closed - sold 316.0 units for 11424.77 euros.
#
# Day 1628: purchase of 279.62 units for total of 11419.77 euros
#
# Day 1692:
# Went neutral. Long position closed - sold 279.62 units for 11277.75 euros.
#
#
# End capital on day 2204: 11277.75 euros
# Total return: 12.78%
# Shares held at end of period: 0
# Total fee spending: 50
# Day 643: purchase of 437.99 units for total of 9995 euros
#
# Day 692:
# Went neutral. Long position closed - sold 437.99 units for 10611.95 euros.
#
# Day 1443: purchase of 338.66 units for total of 10606.95 euros
#
# Day 1459:
# Went neutral. Long position closed - sold 338.66 units for 12244.47 euros.
#
#
# End capital on day 2204: 12244.47 euros
# Total return: 22.44%
# Shares held at end of period: 0
# Total fee spending: 20
# Day 1443: purchase of 319.13 units for total of 9995 euros
#
# Day 1459:
# Went neutral. Long position closed - sold 319.13 units for 11537.76 euros.
#
#
# End capital on day 2204: 11537.76 euros
# Total return: 15.38%
# Shares held at end of period: 0
# Total fee spending: 10
# Day 1443: purchase of 319.13 units for total of 9995 euros
#
# Day 1459:
# Went neutral. Long position closed - sold 319.13 units for 11537.76 euros.
#
#
# End capital on day 2204: 11537.76 euros
# Total return: 15.38%
# Shares held at end of period: 0
# Total fee spending: 10
# Day 197: purchase of 531.93 units for total of 9995 euros
#
# Day 205:
# Went neutral. Long position closed - sold 531.93 units for 10660.23 euros.
#
# Day 328: purchase of 469.39 units for total of 10655.23 euros
#
# Day 329:
# Went neutral. Long position closed - sold 469.39 units for 11194.73 euros.
#
# Day 335: purchase of 493.37 units for total of 11189.73 euros
#
# Day 382:
# Went neutral. Long position closed - sold 493.37 units for 11480.76 euros.
#
# Day 385: purchase of 521.63 units for total of 11475.76 euros
#
# Day 423:
# Went neutral. Long position closed - sold 521.63 units for 11220.38 euros.
#
# Day 544: purchase of 407.83 units for total of 11215.38 euros
#
# Day 550:
# Went neutral. Long position closed - sold 407.83 units for 11834.36 euros.
#
# Day 563: purchase of 418.0 units for total of 11829.36 euros
#
# Day 569:
# Went neutral. Long position closed - sold 418.0 units for 12296.7 euros.
#
# Day 591: purchase of 424.14 units for total of 12291.7 euros
#
# Day 596:
# Went neutral. Long position closed - sold 424.14 units for 12689.63 euros.
#
# Day 598: purchase of 438.46 units for total of 12684.63 euros
#
# Day 622:
# Went neutral. Long position closed - sold 438.46 units for 12644.56 euros.
#
# Day 624: purchase of 454.17 units for total of 12639.56 euros
#
# Day 692:
# Went neutral. Long position closed - sold 454.17 units for 11004.09 euros.
#
# Day 718: purchase of 494.56 units for total of 10999.09 euros
#
# Day 727:
# Went neutral. Long position closed - sold 494.56 units for 11449.08 euros.
#
# Day 732: purchase of 518.07 units for total of 11444.08 euros
#
# Day 750:
# Went neutral. Long position closed - sold 518.07 units for 11972.69 euros.
#
# Day 821: purchase of 500.53 units for total of 11967.69 euros
#
# Day 895:
# Went neutral. Long position closed - sold 500.53 units for 11246.93 euros.
#
# Day 931: purchase of 520.22 units for total of 11241.93 euros
#
# Day 979:
# Went neutral. Long position closed - sold 520.22 units for 11445.02 euros.
#
# Day 1069: purchase of 496.31 units for total of 11440.02 euros
#
# Day 1074:
# Went neutral. Long position closed - sold 496.31 units for 12085.19 euros.
#
# Day 1220: purchase of 431.13 units for total of 12080.19 euros
#
# Day 1221:
# Went neutral. Long position closed - sold 431.13 units for 12342.49 euros.
#
# Day 1436: purchase of 344.62 units for total of 12337.49 euros
#
# Day 1459:
# Went neutral. Long position closed - sold 344.62 units for 12460.0 euros.
#
# Day 1622: purchase of 289.85 units for total of 12455.0 euros
#
# Day 1692:
# Went neutral. Long position closed - sold 289.85 units for 11690.58 euros.
#
# Day 1755: purchase of 290.54 units for total of 11685.58 euros
#
# Day 1791:
# Went neutral. Long position closed - sold 290.54 units for 12325.59 euros.
#
# Day 1842: purchase of 301.09 units for total of 12320.59 euros
#
# Day 1846:
# Went neutral. Long position closed - sold 301.09 units for 12697.97 euros.
#
# Day 1873: purchase of 307.63 units for total of 12692.97 euros
#
# Day 1876:
# Went neutral. Long position closed - sold 307.63 units for 13647.79 euros.
#
# Day 2074: purchase of 236.53 units for total of 13642.79 euros
#
# Day 2078:
# Went neutral. Long position closed - sold 236.53 units for 14106.11 euros.
#
# Day 2087: purchase of 240.02 units for total of 14101.11 euros
#
# Day 2091:
# Went neutral. Long position closed - sold 240.02 units for 14441.74 euros.
#
# Day 2156: purchase of 236.94 units for total of 14436.74 euros
#
# Day 2170:
# Went neutral. Long position closed - sold 236.94 units for 15054.89 euros.
#
# Day 2176: purchase of 241.49 units for total of 15049.89 euros
#
# Day 2178:
# Went neutral. Long position closed - sold 241.49 units for 15431.28 euros.
#
#
# End capital on day 2204: 15431.28 euros
# Total return: 54.31%
# Shares held at end of period: 0
# Total fee spending: 240
# Day 199: purchase of 536.5 units for total of 9995 euros
#
# Day 205:
# Went neutral. Long position closed - sold 536.5 units for 10751.83 euros.
#
# Day 337: purchase of 486.5 units for total of 10746.83 euros
#
# Day 382:
# Went neutral. Long position closed - sold 486.5 units for 11320.77 euros.
#
# Day 394: purchase of 536.55 units for total of 11315.77 euros
#
# Day 423:
# Went neutral. Long position closed - sold 536.55 units for 11541.48 euros.
#
# Day 599: purchase of 408.08 units for total of 11536.48 euros
#
# Day 622:
# Went neutral. Long position closed - sold 408.08 units for 11768.17 euros.
#
# Day 625: purchase of 439.42 units for total of 11763.17 euros
#
# Day 692:
# Went neutral. Long position closed - sold 439.42 units for 10646.45 euros.
#
# Day 719: purchase of 485.25 units for total of 10641.45 euros
#
# Day 727:
# Went neutral. Long position closed - sold 485.25 units for 11233.3 euros.
#
# Day 733: purchase of 522.49 units for total of 11228.3 euros
#
# Day 750:
# Went neutral. Long position closed - sold 522.49 units for 12074.96 euros.
#
# Day 822: purchase of 514.49 units for total of 12069.96 euros
#
# Day 895:
# Went neutral. Long position closed - sold 514.49 units for 11560.76 euros.
#
# Day 939: purchase of 543.8 units for total of 11555.76 euros
#
# Day 979:
# Went neutral. Long position closed - sold 543.8 units for 11964.05 euros.
#
# Day 1069: purchase of 518.83 units for total of 11959.05 euros
#
# Day 1074:
# Went neutral. Long position closed - sold 518.83 units for 12633.71 euros.
#
# Day 1436: purchase of 352.76 units for total of 12628.71 euros
#
# Day 1459:
# Went neutral. Long position closed - sold 352.76 units for 12754.23 euros.
#
# Day 1622: purchase of 296.7 units for total of 12749.23 euros
#
# Day 1692:
# Went neutral. Long position closed - sold 296.7 units for 11966.88 euros.
#
# Day 1756: purchase of 302.37 units for total of 11961.88 euros
#
# Day 1791:
# Went neutral. Long position closed - sold 302.37 units for 12827.71 euros.
#
# Day 1873: purchase of 310.78 units for total of 12822.71 euros
#
# Day 1876:
# Went neutral. Long position closed - sold 310.78 units for 13787.34 euros.
#
# Day 2163: purchase of 228.03 units for total of 13782.34 euros
#
# Day 2170:
# Went neutral. Long position closed - sold 228.03 units for 14488.8 euros.
#
#
# End capital on day 2204: 14488.8 euros
# Total return: 44.89%
# Shares held at end of period: 0
# Total fee spending: 150
# Day 348: purchase of 466.4 units for total of 9995 euros
#
# Day 382:
# Went neutral. Long position closed - sold 466.4 units for 10852.84 euros.
#
# Day 395: purchase of 522.79 units for total of 10847.84 euros
#
# Day 423:
# Went neutral. Long position closed - sold 522.79 units for 11245.39 euros.
#
# Day 602: purchase of 406.97 units for total of 11240.39 euros
#
# Day 622:
# Went neutral. Long position closed - sold 406.97 units for 11735.96 euros.
#
# Day 625: purchase of 438.21 units for total of 11730.96 euros
#
# Day 692:
# Went neutral. Long position closed - sold 438.21 units for 10617.28 euros.
#
# Day 720: purchase of 501.05 units for total of 10612.28 euros
#
# Day 727:
# Went neutral. Long position closed - sold 501.05 units for 11599.36 euros.
#
# Day 734: purchase of 552.11 units for total of 11594.36 euros
#
# Day 750:
# Went neutral. Long position closed - sold 552.11 units for 12759.84 euros.
#
# Day 823: purchase of 547.42 units for total of 12754.84 euros
#
# Day 895:
# Went neutral. Long position closed - sold 547.42 units for 12300.96 euros.
#
# Day 941: purchase of 596.6 units for total of 12295.96 euros
#
# Day 979:
# Went neutral. Long position closed - sold 596.6 units for 13126.2 euros.
#
# Day 1439: purchase of 370.76 units for total of 13121.2 euros
#
# Day 1459:
# Went neutral. Long position closed - sold 370.76 units for 13405.39 euros.
#
# Day 1626: purchase of 318.0 units for total of 13400.39 euros
#
# Day 1692:
# Went neutral. Long position closed - sold 318.0 units for 12826.18 euros.
#
# Day 1761: purchase of 336.78 units for total of 12821.18 euros
#
# Day 1791:
# Went neutral. Long position closed - sold 336.78 units for 14287.9 euros.
#
# Day 1873: purchase of 346.17 units for total of 14282.9 euros
#
# Day 1876:
# Went neutral. Long position closed - sold 346.17 units for 15357.95 euros.
#
#
# End capital on day 2204: 15357.95 euros
# Total return: 53.58%
# Shares held at end of period: 0
# Total fee spending: 120
# Day 348: purchase of 466.4 units for total of 9995 euros
#
# Day 382:
# Went neutral. Long position closed - sold 466.4 units for 10852.84 euros.
#
# Day 405: purchase of 532.8 units for total of 10847.84 euros
#
# Day 423:
# Went neutral. Long position closed - sold 532.8 units for 11460.89 euros.
#
# Day 604: purchase of 420.4 units for total of 11455.89 euros
#
# Day 622:
# Went neutral. Long position closed - sold 420.4 units for 12123.53 euros.
#
# Day 640: purchase of 485.71 units for total of 12118.53 euros
#
# Day 692:
# Went neutral. Long position closed - sold 485.71 units for 11768.68 euros.
#
# Day 737: purchase of 569.95 units for total of 11763.68 euros
#
# Day 750:
# Went neutral. Long position closed - sold 569.95 units for 13172.14 euros.
#
# Day 831: purchase of 569.51 units for total of 13167.14 euros
#
# Day 895:
# Went neutral. Long position closed - sold 569.51 units for 12797.65 euros.
#
# Day 1440: purchase of 371.12 units for total of 12792.65 euros
#
# Day 1459:
# Went neutral. Long position closed - sold 371.12 units for 13418.57 euros.
#
# Day 1627: purchase of 320.44 units for total of 13413.57 euros
#
# Day 1692:
# Went neutral. Long position closed - sold 320.44 units for 12924.7 euros.
#
# Day 1776: purchase of 341.16 units for total of 12919.7 euros
#
# Day 1791:
# Went neutral. Long position closed - sold 341.16 units for 14473.8 euros.
#
#
# End capital on day 2204: 14473.8 euros
# Total return: 44.74%
# Shares held at end of period: 0
# Total fee spending: 90
# Day 608: purchase of 380.04 units for total of 9995 euros
#
# Day 622:
# Went neutral. Long position closed - sold 380.04 units for 10959.1 euros.
#
# Day 642: purchase of 464.75 units for total of 10954.1 euros
#
# Day 692:
# Went neutral. Long position closed - sold 464.75 units for 11260.48 euros.
#
# Day 840: purchase of 514.18 units for total of 11255.48 euros
#
# Day 895:
# Went neutral. Long position closed - sold 514.18 units for 11553.85 euros.
#
# Day 1442: purchase of 339.67 units for total of 11548.85 euros
#
# Day 1459:
# Went neutral. Long position closed - sold 339.67 units for 12280.93 euros.
#
# Day 1628: purchase of 300.59 units for total of 12275.93 euros
#
# Day 1692:
# Went neutral. Long position closed - sold 300.59 units for 12123.65 euros.
#
#
# End capital on day 2204: 12123.65 euros
# Total return: 21.24%
# Shares held at end of period: 0
# Total fee spending: 50
# Day 643: purchase of 437.99 units for total of 9995 euros
#
# Day 692:
# Went neutral. Long position closed - sold 437.99 units for 10611.95 euros.
#
# Day 1443: purchase of 338.66 units for total of 10606.95 euros
#
# Day 1459:
# Went neutral. Long position closed - sold 338.66 units for 12244.47 euros.
#
# Day 1629: purchase of 304.77 units for total of 12239.47 euros
#
# Day 1692:
# Went neutral. Long position closed - sold 304.77 units for 12292.38 euros.
#
#
# End capital on day 2204: 12292.38 euros
# Total return: 22.92%
# Shares held at end of period: 0
# Total fee spending: 30
# Day 644: purchase of 467.49 units for total of 9995 euros
#
# Day 692:
# Went neutral. Long position closed - sold 467.49 units for 11327.03 euros.
#
# Day 1443: purchase of 361.5 units for total of 11322.03 euros
#
# Day 1459:
# Went neutral. Long position closed - sold 361.5 units for 13070.28 euros.
#
#
# End capital on day 2204: 13070.28 euros
# Total return: 30.7%
# Shares held at end of period: 0
# Total fee spending: 20
# Day 1443: purchase of 319.13 units for total of 9995 euros
#
# Day 1459:
# Went neutral. Long position closed - sold 319.13 units for 11537.76 euros.
#
#
# End capital on day 2204: 11537.76 euros
# Total return: 15.38%
# Shares held at end of period: 0
# Total fee spending: 10

# %%
best_total_final_capital
# Out:
# 32600.436170935784

# %%
best_total_return
# Out:
# 2.2600436170935785

# %%
best_vals
# Out:
# {'best_sma': 10, 'best_std': 0.5}

# %%
results["Mean-Reversion Strategy"]["XSD train"] = str(round(best_total_return*100, 2))+"%"
results["MR Parameter"]["XSD train"] = str("SMA: " + str(best_vals["best_sma"]) +", STD: " +str(best_vals["best_std"]))
results["MR Parameter"]["XSD test"] = str("SMA: " + str(best_vals["best_sma"]) +", STD: " +str(best_vals["best_std"]))

# %%
return_test, _ = mean_rev_evaluation(sma=best_vals["best_sma"], std_dev=best_vals["best_std"], data=xsd_test)
# Out:
# Day 20: purchase of 140.42 units for total of 9995 euros
#
# Day 30:
# Went neutral. Long position closed - sold 140.42 units for 9734.44 euros.
#
# Day 40: purchase of 139.37 units for total of 9729.44 euros
#
# Day 41:
# Went neutral. Long position closed - sold 139.37 units for 10036.63 euros.
#
# Day 57: purchase of 138.1 units for total of 10031.63 euros
#
# Day 58:
# Went neutral. Long position closed - sold 138.1 units for 10302.83 euros.
#
# Day 61: purchase of 140.3 units for total of 10297.83 euros
#
# Day 71:
# Went neutral. Long position closed - sold 140.3 units for 9598.36 euros.
#
# Day 96: purchase of 132.49 units for total of 9593.36 euros
#
# Day 108:
# Went neutral. Long position closed - sold 132.49 units for 9292.91 euros.
#
# Day 116: purchase of 133.83 units for total of 9287.91 euros
#
# Day 124:
# Went neutral. Long position closed - sold 133.83 units for 9189.23 euros.
#
# Day 159: purchase of 121.2 units for total of 9184.23 euros
#
# Day 168:
# Went neutral. Long position closed - sold 121.2 units for 8985.32 euros.
#
# Day 182: purchase of 120.03 units for total of 8980.32 euros
#
# Day 183:
# Went neutral. Long position closed - sold 120.03 units for 9122.95 euros.
#
# Day 185: purchase of 122.95 units for total of 9117.95 euros
#
# Day 188:
# Went neutral. Long position closed - sold 122.95 units for 9243.27 euros.
#
# Day 196: purchase of 123.09 units for total of 9238.27 euros
#
# Day 201:
# Went neutral. Long position closed - sold 123.09 units for 9299.75 euros.
#
# Day 213: purchase of 121.75 units for total of 9294.75 euros
#
# Day 221:
# Went neutral. Long position closed - sold 121.75 units for 9382.28 euros.
#
# Day 226: purchase of 124.95 units for total of 9377.28 euros
#
# Day 240:
# Went neutral. Long position closed - sold 124.95 units for 8902.48 euros.
#
# Day 243: purchase of 130.69 units for total of 8897.48 euros
#
# Day 251:
# Went neutral. Long position closed - sold 130.69 units for 8790.54 euros.
#
# Day 260: purchase of 132.21 units for total of 8785.54 euros
#
# Day 262:
# Went neutral. Long position closed - sold 132.21 units for 9179.82 euros.
#
# Day 265: purchase of 137.93 units for total of 9174.82 euros
#
# Day 268:
# Went neutral. Long position closed - sold 137.93 units for 9498.08 euros.
#
# Day 276: purchase of 142.41 units for total of 9493.08 euros
#
# Day 290:
# Went neutral. Long position closed - sold 142.41 units for 9143.45 euros.
#
# Day 306: purchase of 137.03 units for total of 9138.45 euros
#
# Day 307:
# Went neutral. Long position closed - sold 137.03 units for 9560.98 euros.
#
# Day 336: purchase of 125.18 units for total of 9555.98 euros
#
# Day 338:
# Went neutral. Long position closed - sold 125.18 units for 9821.36 euros.
#
# Day 348: purchase of 125.83 units for total of 9816.36 euros
#
# Day 353:
# Went neutral. Long position closed - sold 125.83 units for 10124.69 euros.
#
# Day 372: purchase of 117.52 units for total of 10119.69 euros
#
# Day 376:
# Went neutral. Long position closed - sold 117.52 units for 10332.1 euros.
#
# Day 378: purchase of 121.7 units for total of 10327.1 euros
#
# Day 396:
# Went neutral. Long position closed - sold 121.7 units for 9084.46 euros.
#
# Day 406: purchase of 116.12 units for total of 9079.46 euros
#
# Day 407:
# Went neutral. Long position closed - sold 116.12 units for 9498.3 euros.
#
# Day 438: purchase of 104.0 units for total of 9493.3 euros
#
# Day 443:
# Went neutral. Long position closed - sold 104.0 units for 9404.06 euros.
#
# Day 445: purchase of 107.86 units for total of 9399.06 euros
#
# Day 446:
# Went neutral. Long position closed - sold 107.86 units for 9649.69 euros.
#
# Day 448: purchase of 111.54 units for total of 9644.69 euros
#
# Day 449:
# Went neutral. Long position closed - sold 111.54 units for 9910.72 euros.
#
# Day 455: purchase of 114.77 units for total of 9905.72 euros
#
# Day 459:
# Went neutral. Long position closed - sold 114.77 units for 10102.72 euros.
#
# Day 475: purchase of 110.76 units for total of 10097.72 euros
#
# Day 483:
# Went neutral. Long position closed - sold 110.76 units for 10009.65 euros.
#
# Day 485: purchase of 115.13 units for total of 10004.65 euros
#
# Day 487:
# Went neutral. Long position closed - sold 115.13 units for 10217.24 euros.
#
# Day 516: purchase of 105.11 units for total of 10212.24 euros
#
# Day 519:
# Went neutral. Long position closed - sold 105.11 units for 10396.44 euros.
#
# Day 523: purchase of 107.9 units for total of 10391.44 euros
#
# Day 527:
# Went neutral. Long position closed - sold 107.9 units for 10609.78 euros.
#
#
# End capital on day 544: 10609.78 euros
# Total return: 6.1%
# Shares held at end of period: 0
# Total fee spending: 300

# %%
results["Mean-Reversion Strategy"]["XSD test"] = str(round(return_test*100, 2))+"%"

# %% [markdown]
# # All results

# %%
results
# Out:
#           Buy&Hold SMA Strategy                SMA Parameter  \
# VGT train   369.0%       146.1%  SMA short: 40, SMA long: 90
# VGT test     50.0%       27.57%  SMA short: 40, SMA long: 90
# XSD train   461.0%      178.96%  SMA short: 20, SMA long: 90
# XSD test     51.0%        6.66%  SMA short: 20, SMA long: 90
#
#           Mean-Reversion Strategy       MR Parameter
# VGT train                  143.6%    SMA: 10, STD: 1
# VGT test                   -8.17%    SMA: 10, STD: 1
# XSD train                  226.0%  SMA: 10, STD: 0.5
# XSD test                     6.1%  SMA: 10, STD: 0.5

# %% [markdown]
# ----
